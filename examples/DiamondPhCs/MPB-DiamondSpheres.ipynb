# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo
# Out:
# Error: Lumpy and/or the Lumerical API were not found.

# %% [markdown]
# Let's compare the primitive cell version of the diamond lattice of spheres with the cubic supercell version. The structure is point group 227, which has a rhombohedral primitive cell and an FCC conventional cell.
#
# The MPB documentation has a tutorial for the rhombohedral version, which we will start by including below:

# %%
import math
import meep as mp
from meep import mpb

# Dielectric spheres in a diamond (fcc) lattice.  This file is used in
# the "Data Analysis Tutorial" section of the MPB manual.

sqrt_half = math.sqrt(0.5)
geometry_lattice = mp.Lattice(
    basis_size=mp.Vector3(sqrt_half, sqrt_half, sqrt_half),
    basis1=mp.Vector3(0, 1, 1),
    basis2=mp.Vector3(1, 0, 1),
    basis3=mp.Vector3(1, 1)
)

# Corners of the irreducible Brillouin zone for the fcc lattice,
# in a canonical order:
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]

k_points = mp.interpolate(4, vlist)

# define a couple of parameters (which we can set from the command_line)
eps = 11.56  # the dielectric constant of the spheres
r = 0.25  # the radius of the spheres

diel = mp.Medium(epsilon=eps)

# A diamond lattice has two "atoms" per unit cell:
geometry = [mp.Sphere(r, center=mp.Vector3(0.125, 0.125, 0.125), material=diel),
            mp.Sphere(r, center=mp.Vector3(-0.125, -0.125, -0.125), material=diel)]

# A simple fcc lattice would have only one sphere/object at the origin.

resolution = 16  # use a 16x16x16 grid
mesh_size = 2
num_bands = 10

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    geometry=geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)

ms.run()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 16 x 16 x 16.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 2.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      sphere, center = (0.125,0.125,0.125)
#           radius 0.25
#      sphere, center = (-0.125,-0.125,-0.125)
#           radius 0.25
# Geometric object tree has depth 4 and 35 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.525, 0.475>
#   Vector3<0.0, 0.55, 0.45>
#   Vector3<0.0, 0.575, 0.425>
#   Vector3<0.0, 0.6, 0.4>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.6, 0.3>
#   Vector3<0.0, 0.575, 0.225>
#   Vector3<0.0, 0.55, 0.15000000000000002>
#   Vector3<0.0, 0.525, 0.07500000000000001>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.3, 0.0>
#   Vector3<0.0, 0.19999999999999996, 0.0>
#   Vector3<0.0, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.1>
#   Vector3<0.0, 0.2, 0.2>
#   Vector3<0.0, 0.30000000000000004, 0.30000000000000004>
#   Vector3<0.0, 0.4, 0.4>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.05, 0.55, 0.5>
#   Vector3<0.1, 0.6, 0.5>
#   Vector3<0.15000000000000002, 0.65, 0.5>
#   Vector3<0.2, 0.7, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.275, 0.75, 0.475>
#   Vector3<0.3, 0.75, 0.45>
#   Vector3<0.325, 0.75, 0.425>
#   Vector3<0.35, 0.75, 0.4>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.031047344207763672
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 10 iterations.
#     iteration    1: trace = 17.91576321554376 (193.452% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 4.234093815245129 (123.537% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 3.293865458357105 (24.9796% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 3.023005457691518 (8.57576% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.929805076690998 (3.13131% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.898095404823222 (1.0882% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.883856039622705 (0.492545% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.877211384056418 (0.230674% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.87287645876539 (0.150778% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.869385395417518 (0.121592% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.867021764830238 (0.082408% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.865610635868979 (0.0492314% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.865151786809307 (0.0160135% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.865007816601167 (0.005025% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.864966944626077 (0.0014266% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 2.864955955320021 (0.000383576% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 2.864951827060108 (0.000144095% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.86495004752151 (6.21141e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.864948986907317 (3.70203e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.864948215310637 (2.69323e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.864947792780905 (1.47483e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.864947601231539 (6.68596e-06% change)
# Finished solving for bands 1 to 10 after 22 iterations.
# freqs:, 1, 0, 0.5, 0.5, 1, 0.380789, 0.382243, 0.496176, 0.498862, 0.541547, 0.54211, 0.568565, 0.569651, 0.647253, 0.651861
# elapsed time for k point: 0.33582139015197754
# solve_kpoint (0,0.525,0.475):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.870591761748604 (0.32095% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.867682533023947 (0.101397% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.866617769609673 (0.0371366% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.865885999600255 (0.0255306% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.865582840181139 (0.0105788% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.865354826017312 (0.00795731% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.865166471056958 (0.00657375% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.865094494592493 (0.00251215% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.865057833780988 (0.00127958% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.86505032090142 (0.000262225% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.865048523293335 (6.27427e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.865048069232906 (1.58483e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.865047969330321 (3.48694e-06% change)
# Finished solving for bands 1 to 10 after 13 iterations.
# freqs:, 2, 0, 0.525, 0.475, 1.0025, 0.381023, 0.383171, 0.496535, 0.499242, 0.537612, 0.54011, 0.568698, 0.570609, 0.647868, 0.65404
# elapsed time for k point: 0.15911531448364258
# solve_kpoint (0,0.55,0.45):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.870991933301756 (0.318792% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.868176525151238 (0.0981121% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.867158477740114 (0.0355009% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.866400689433775 (0.0264334% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.866045014855839 (0.0124092% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.865744011939819 (0.0105029% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.865524145072123 (0.00767254% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.865453957319176 (0.00244942% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.865421008702789 (0.00114986% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.865413973916231 (0.000245507% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.865412219961289 (6.12112e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.865411736424043 (1.6875e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.865411627797213 (3.79097e-06% change)
# Finished solving for bands 1 to 10 after 13 iterations.
# freqs:, 3, 0, 0.55, 0.45, 1.00995, 0.381602, 0.38584, 0.497616, 0.500385, 0.527053, 0.534305, 0.569421, 0.573452, 0.649673, 0.659154
# elapsed time for k point: 0.16399455070495605
# solve_kpoint (0,0.575,0.425):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2
change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 3.04089342132461 (0.000565482% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 3.040877250056214 (0.000531795% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 3.040862106474539 (0.000498002% change)
#     linmin: converged after 2 iterations.
#     iteration   57: trace = 3.040848082502844 (0.000461185% change)
#     linmin: converged after 2 iterations.
#     iteration   58: trace = 3.040835279742129 (0.000421027% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 3.040823714563083 (0.00038033% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 3.040813299014431 (0.000342525% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 3.040803905812309 (0.000308905% change)
#     linmin: converged after 2 iterations.
#     iteration   62: trace = 3.040795430727173 (0.000278712% change)
#     linmin: converged after 2 iterations.
#     iteration   63: trace = 3.040787790860522 (0.000251246% change)
#     linmin: converged after 2 iterations.
#     iteration   64: trace = 3.04078088798198 (0.00022701% change)
#     linmin: converged after 2 iterations.
#     iteration   65: trace = 3.040774597272089 (0.000206878% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 3.0407687903259 (0.000190969% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 3.04076335758297 (0.000178664% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 3.040758211269918 (0.000169244% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 3.040753284063484 (0.000162039% change)
#     resetting CG direction...
#     large trace change predicted (0.00113099%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 3.0407188932681 (0.001131% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 3.040701653310077 (0.000566971% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 3.04069530713009 (0.000208708% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 3.040691263958638 (0.000132969% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 3.040688985964632 (7.4917e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 3.040687542885778 (4.7459e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 3.040686392969286 (3.78177e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 3.040685551274463 (2.76811e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 3.040684723923321 (2.72094e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 3.040683876690353 (2.78632e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 3.040682896260408 (3.22437e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 3.040681829849619 (3.50714e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 3.040681079106548 (2.469e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 3.040680562058138 (1.70044e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 3.040680124359752 (1.43948e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 3.040679841655713 (9.2974e-06% change)
# Finished solving for bands 1 to 10 after 85 iterations.
# freqs:, 13, 0, 0.3, 0, 0.519615, 0.235546, 0.237164, 0.517957, 0.519299, 0.572514, 0.60263, 0.602853, 0.656739, 0.667964, 0.677608
# elapsed time for k point: 0.9971137046813965
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 3.124786243982042 (1.58157% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 3.109371636561869 (0.494521% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 3.104908147058483 (0.143653% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 3.102415818624521 (0.0803028% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.101779186643209 (0.0205226% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.101469374605717 (0.0099887% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.101293106346921 (0.00568354% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 3.101223262503131 (0.00225211% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 3.101173682908954 (0.00159872% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 3.101148722609766 (0.000804869% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.101131610822112 (0.00055179% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 3.10112245106403 (0.000295369% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 3.101117504506084 (0.000159509% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 3.101115039707503 (7.9481e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 3.101114030489111 (3.25437e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 3.10111356089014 (1.51429e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace =
change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 3.154145093601099 (4.21371e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 3.154144473022793 (1.9675e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 3.15414417433877 (9.46957e-06% change)
# Finished solving for bands 1 to 10 after 21 iterations.
# freqs:, 17, 0, 0.1, 0.1, 0.2, 0.0943265, 0.0948611, 0.585352, 0.58595, 0.591429, 0.628498, 0.629271, 0.629771, 0.671652, 0.679533
# elapsed time for k point: 0.2661149501800537
# ...
#     iteration   84: trace = 2.962466426220951 (0.000917595% change)
#     linmin: converged after 3 iterations.
#     iteration   85: trace = 2.962450903877758 (0.000523968% change)
#     linmin: converged after 2 iterations.
#     iteration   86: trace = 2.962443123756982 (0.000262625% change)
#     linmin: converged after 2 iterations.
#     iteration   87: trace = 2.962437242291845 (0.000198534% change)
#     linmin: converged after 2 iterations.
#     iteration   88: trace = 2.962432819167581 (0.000149307% change)
#     linmin: converged after 2 iterations.
#     iteration   89: trace = 2.962429656389419 (0.000106763% change)
#     linmin: converged after 2 iterations.
#     iteration   90: trace = 2.962427664280154 (6.72458e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   91: trace = 2.962426286877105 (4.64958e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   92: trace = 2.96242538951355 (3.02915e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   93: trace = 2.962424560001553 (2.80011e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   94: trace = 2.962423023986401 (5.18499e-05% change)
#     large trace change predicted (0.00011797%)
#     linmin: converged after 2 iterations.
#     iteration   95: trace = 2.962419528621151 (0.00011799% change)
#     linmin: converged after 2 iterations.
#     iteration   96: trace = 2.962415147497484 (0.00014789% change)
#     linmin: converged after 2 iterations.
#     iteration   97: trace = 2.962412299436403 (9.61399e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   98: trace = 2.962411036107266 (4.26453e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   99: trace = 2.962410484412446 (1.86232e-05% change)
#     linmin: converged after 2 iterations.
#     iteration  100: trace = 2.962410135628727 (1.17736e-05% change)
#     linmin: converged after 2 iterations.
#     iteration  101: trace = 2.962409803226856 (1.12207e-05% change)
#     linmin: converged after 2 iterations.
#     iteration  102: trace = 2.962409452493959 (1.18394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration  103: trace = 2.962409249007382 (6.86896e-06% change)
# Finished solving for bands 1 to 10 after 103 iterations.
# freqs:, 26, 0.25, 0.75, 0.5, 1.11803, 0.395229, 0.396852, 0.488571, 0.488955, 0.527265, 0.527435, 0.546316, 0.548099, 0.711746, 0.71364
# elapsed time for k point: 1.079383373260498
# solve_kpoint (0.275,0.75,0.475):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.970737254617679 (0.340019% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.96786727334417 (0.0966551% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.966996601434947 (0.0293409% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.966092935477334 (0.0304619% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.965493749544207 (0.0202032% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.964805636069562 (0.0232067% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.964269938640014 (0.0180702% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.963944349237479 (0.0109844% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.963379584948965 (0.0190563% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 2.962329229190388 (0.0354508% change)
#     large trace change predicted (0.124426%)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.959714101507038 (0.0883184% change)
#     linmin: converged after 5 iterations.
#     iteration   12: trace = 2.957292917770669 (0.0818381% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.955140798987237 (0.0727998% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 2.952969601648614 (0.0734989% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 2.951173735770428 (0.0608341% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 2.94947053985853 (0.0577292% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 2.947810166415823 (0.0563098% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 2.946423771144048 (0.0470424% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 2.945109653423184 (0.0446104% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 2.944187771191885 (0.031307% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 2.943668199536118 (0.0176489% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 2.943335012091185 (0.0113194% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 2.94310219433873 (0.00791031% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 2.942859010311925 (0.00826319% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace =

# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.885403925273406 (0.280041% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.883674781641102 (0.0599452% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 2.883313816718595 (0.0125183% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.883157194837647 (0.00543216% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.883087126015062 (0.00243031% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.883060751936378 (0.00091479% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.883042889093131 (0.000619581% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.883038370538336 (0.000156729% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.883036155817078 (7.6819e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.883035246929869 (3.15254e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.883034944881774 (1.04767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.883034829571963 (3.9996e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 31, 0.375, 0.75, 0.375, 1.06066, 0.380831, 0.396527, 0.479964, 0.506037, 0.50679, 0.507528, 0.577287, 0.591725, 0.665342, 0.673669
# elapsed time for k point: 0.17634940147399902
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3952289611074468 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3977891786250919 at Vector3<0.0, 0.625, 0.375>
# Band 3 range: 0.4430257042291404 at Vector3<0.0, 0.5, 0.0> to 0.5951255888622471 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.444892230432925 at Vector3<0.0, 0.5, 0.0> to 0.5955546128764149 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.5049685680091617 at Vector3<0.0, 0.6, 0.4> to 0.5955756529715781 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.5075279577613728 at Vector3<0.375, 0.75, 0.375> to 0.6372916044394469 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.5427054822191798 at Vector3<0.275, 0.75, 0.475> to 0.6373098374846797 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.5480986785714733 at Vector3<0.25, 0.75, 0.5> to 0.6591112606737671 at Vector3<0.0, 0.525, 0.07500000000000001>
# Band 9 range: 0.6472529758658319 at Vector3<0.0, 0.5, 0.5> to 0.7117457352205898 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 0.6518610487720073 at Vector3<0.0, 0.5, 0.5> to 0.7136396314676662 at Vector3<0.25, 0.75, 0.5>
# Gap from band 2 (0.3977891786250919) to band 3 (0.4430257042291404), 10.76016291493045%
# total elapsed time for run: 9.067500591278076
# done

# %% [markdown]
# And we'll plot the results:

# %%
### Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=6, resolution=64)
eps = ms.get_epsilon()
rhomb_converted_eps = md.convert(eps)
layer_slice = 13
plt.imshow(rhomb_converted_eps[:,layer_slice, :], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
x = range(len(crysfreqs))
figgy = plt.figure()
plt.plot(x,crysfreqs, color='blue')
plt.ylabel('frequency (c/a)', size=16)
plt.grid(True)
figax = plt.gca()

plt.show()
# Out:
# epsilon: 1-11.56, mean 6.21953, harm. mean 2.01398, 61.3426% > 1, 49.4274% "fill"
# real part range: 1 .. 11.56

# %% [markdown]
# This looks good, so let's try to reformat it as a cubic cell. There are a lot of positions in this unit cell (18 sites) so let's make it easier using the Bilbao server

# %%
import crystalbuilder.bilbao as bilbao

# Dielectric spheres in a diamond (fcc) lattice.  This file is used in
# the "Data Analysis Tutorial" section of the MPB manual.

geometry_lattice = mp.Lattice(
    basis_size=mp.Vector3(1, 1, 1),
    basis1=mp.Vector3(1,0,0),
    basis2=mp.Vector3(0, 1, 0),
    basis3=mp.Vector3(0, 0, 1)
)

# Corners of the irreducible Brillouin zone for the fcc lattice,
# in a canonical order:
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]

k_points = mp.interpolate(4, vlist)

# define a couple of parameters (which we can set from the command_line)
eps = 11.56  # the dielectric constant of the spheres
r = 0.2  # the radius of the spheres

diel = mp.Medium(epsilon=eps)

# A cubic diamond lattice is space group 227, with eight full "atoms" per unit cell in 18 sites:

diamond = bilbao.SpaceGroup(227)
point_list = diamond.calculate_points((0,0,0))

geometry = []
for point in point_list:
    sphere = mp.Sphere(radius=r, center=point, material=diel)
    geometry.append(sphere)

### manually add the corner spheres to the unit cell
corner_spheres = [
    mp.Sphere(radius=r, center=mp.Vector3(1,1,1), material=diel),
    mp.Sphere(radius=r, center=mp.Vector3(1, 0, 0), material=diel),
    mp.Sphere(radius=r, center=mp.Vector3(0,0,1), material=diel),
    mp.Sphere(radius=r, center=mp.Vector3(0, 1, 0), material=diel)
]
# geometry = geometry+corner_spheres

resolution = 24  # use a 16x16x16 grid
mesh_size = 1
num_bands = 30

ms = mpb.ModeSolver(
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    geometry=geometry,
    geometry_center=mp.Vector3(1/2, 1/2, 1/2),
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)

ms.run()
# Out:
# Initializing eigensolver data
# Computing 30 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 24 x 24 x 24.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      sphere, center = (0,0,0)
#           radius 0.2
#      sphere, center = (0,0.25,0.25)
#           radius 0.2
#      sphere, center = (0,0.5,0.5)
#           radius 0.2
#      sphere, center = (0,0.75,0.75)
#           radius 0.2
#      sphere, center = (0.25,0,0.25)
#           radius 0.2
#      sphere, center = (0.25,0.25,0)
#           radius 0.2
#      sphere, center = (0.25,0.5,0.75)
#           radius 0.2
#      sphere, center = (0.25,0.75,0.5)
#           radius 0.2
#      sphere, center = (0.5,0,0.5)
#           radius 0.2
#      sphere, center = (0.5,0.25,0.75)
#           radius 0.2
#      sphere, center = (0.5,0.5,0)
#           radius 0.2
#      sphere, center = (0.5,0.75,0.25)
#           radius 0.2
#      sphere, center = (0.75,0,0.75)
#           radius 0.2
#      sphere, center = (0.75,0.25,0.5)
#           radius 0.2
#      sphere, center = (0.75,0.5,0.25)
#           radius 0.2
#      sphere, center = (0.75,0.75,0)
#           radius 0.2
# Geometric object tree has depth 6 and 78 object nodes (vs. 16 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.525, 0.475>
#   Vector3<0.0, 0.55, 0.45>
#   Vector3<0.0, 0.575, 0.425>
#   Vector3<0.0, 0.6, 0.4>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.6, 0.3>
#   Vector3<0.0, 0.575, 0.225>
#   Vector3<0.0, 0.55, 0.15000000000000002>
#   Vector3<0.0, 0.525, 0.07500000000000001>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.3, 0.0>
#   Vector3<0.0, 0.19999999999999996, 0.0>
#   Vector3<0.0, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.1>
#   Vector3<0.0, 0.2, 0.2>
#   Vector3<0.0, 0.30000000000000004, 0.30000000000000004>
#   Vector3<0.0, 0.4, 0.4>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.05, 0.55, 0.5>
#   Vector3<0.1, 0.6, 0.5>
#   Vector3<0.15000000000000002, 0.65, 0.5>
#   Vector3<0.2, 0.7, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.275, 0.75, 0.475>
#   Vector3<0.3, 0.75, 0.45>
#   Vector3<0.325, 0.75, 0.425>
#   Vector3<0.35, 0.75, 0.4>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.11269378662109375
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10, band 11, band 12, band 13, band 14, band 15, band 16, band 17, band 18, band 19, band 20, band 21, band 22, band 23, band 24, band 25, band 26, band 27, band 28, band 29, band 30
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 12.12971141555803 (194.099% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 1.89455099610939 (145.964% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 1.454117246301106 (26.305% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 1.374181282922845 (5.65258% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.343451140682359 (2.26154% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.333725185079165 (0.726583% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 1.325798793014463 (0.596076% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 1.320165294407422 (0.425818% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 1.314631409119266 (0.420062% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.309746532073775 (0.372269% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 1.307379880644464 (0.180859% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 1.30609720403376 (0.0981586% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.305700616339183 (0.0303689% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.30555112202465 (0.01145% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.305465432813095 (0.00656367% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.305419150481406 (0.00354534% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 1.305378547926517 (0.00311036% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.305348687343298 (0.00228753% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 1.305331633238013 (0.00130649% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.305323457560488 (0.000626331% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.305320749183108 (0.000207487% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.305319551160472 (9.178e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.305318528114237 (7.83752e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.305317323698907 (9.22699e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.305315428054564 (0.000145225% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 1.305313170136076 (0.000172979% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 1.305310966846828 (0.000168794% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 1.30530822904366 (0.000209744% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 1.305303476129042 (0.000364123% change)
#     large trace change predicted (0.00105548%)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 1.305289765383145 (0.00105039% change)
#     large trace change predicted (0.00305137%)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 1.305251235412258 (0.00295188% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 1.305203020905238 (0.00369396% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 1.305169639718741 (0.00255758% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 1.305153166987685 (0.00126212% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 1.305144887064314 (0.000634404% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 1.305138614461847 (0.000480607% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 1.305133954422176 (0.000357054% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 1.305130728734044 (0.000247154% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 1.30512886268718 (0.000142978% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 1.305128094207675 (5.88815e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 1.305127785074863 (2.3686e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 1.305127648331431 (1.04774e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 1.305127572909601 (5.77889e-06% change)
# Finished solving for bands 1 to 10 after 43 iterations.
# Solving for bands 11 to 20...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 20.73031611478732 (190.069% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 4.708240042930093 (125.967% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 3.518877441669416 (28.9132% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 3.172118397903016 (10.3649% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 3.00588235820867 (5.38155% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.931386651152406 (2.50943% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.885592961739418 (1.57448% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.865526123885376 (0.697841% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 2.856256212130847 (0.324022% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 2.85124718234062 (0.175524% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 2.848988390367753 (0.0792526% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 2.847467258339546 (0.0534063% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.846509465576312 (0.0336423% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 2.845614025070482 (0.0314624% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 2.844734666509545 (0.030907% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 2.843978370964961 (0.0265893% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 2.84320302134993 (0.0272666% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 2.842479274634341 (0.0254586% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 2.841569678109602 (0.0320052% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 2.840530896929072 (0.0365633% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 2.839537707061182 (0.0349711% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 2.838750073086907 (0.027742% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 2.838346064846898 (0.0142329% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 2.838144509395119 (0.00710141% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 2.838034808695289 (0.0038653% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 2.837955949210857 (0.0027787% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 2.837870388071537 (0.00301493% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 2.837758922328046 (0.00392787% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 2.837587128234137 (0.00605405% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 2.837356272128398 (0.00813598% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 2.837124313679919 (0.0081755% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 2.836927700323861 (0.00693026% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 2.836781546511399 (0.00515197% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 2.836668596041148 (0.00398172% change)
#     linmin: converged after 4 iterations.
#     iteration   35: trace = 2.836570773567801 (0.00344856% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 2.836480568617714 (0.00318012% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 2.836386647524258 (0.00331124% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 2.8362944231398 (0.00325153% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 2.836197996279466 (0.00339981% change)
#     linmin: converged after 4 iterations.
#     iteration   40: trace = 2.836076515213373 (0.00428333% change)
#     linmin: converged after 4 iterations.
#     iteration   41: trace = 2.835914627976992 (0.0057083% change)
#     linmin: converged after 4 iterations.
#     iteration   42: trace = 2.835713927828588 (0.00707734% change)
#     linmin: converged after 4 iterations.
#     iteration   43: trace = 2.835530917067151 (0.00645399% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 2.835402644432415 (0.00452386% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 2.835330968123277 (0.00252794% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 2.835296595417516 (0.00121231% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 2.835275563089334 (0.000741806% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 2.835257068133088 (0.000652318% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 2.835234619852635 (0.000791758% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 2.835204880620081 (0.00104892% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 2.835170465984368 (0.00121384% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 2.835133234785802 (0.0013132% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 2.835097483639751 (0.00126101% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 2.835066953376709 (0.00107687% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 2.835040783449567 (0.000923084% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 2.835019438204299 (0.000752911% change)
#     linmin: converged after 2 iterations.
#     iteration   57: trace = 2.835002670916017 (0.000591436% change)
#     linmin: converged after 2 iterations.
#     iteration   58: trace = 2.83499067043399 (0.000423298% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 2.834981882874527 (0.000309968% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 2.834974195317456 (0.000271168% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 2.834966316457683 (0.000277917% change)
#     linmin: converged after 2 iterations.
#     iteration   62: trace = 2.8349564977732 (0.000346343% change)
#     linmin: converged after 2 iterations.
#     iteration   63: trace = 2.834943258573888 (0.000466999% change)
#     linmin: converged after 4 iterations.
#     iteration   64: trace = 2.834927894410394 (0.000541958% change)
#     linmin: converged after 2 iterations.
#     iteration   65: trace = 2.834914905719773 (0.000458168% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 2.834907536502777 (0.000259945% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 2.83490402491547 (0.00012387% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 2.834902195995115 (6.45144e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 2.834900968527594 (4.32984e-05% change)
#     resetting CG direction...
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 2.834900527913641 (1.55425e-05% change)
#     large trace change predicted (3.97283e-05%)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 2.834899401662057 (3.97281e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 2.83489830531157 (3.86734e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 2.834896718045153 (5.59903e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 2.834894737903212 (6.98488e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 2.834893162817522 (5.55607e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 2.834891678296059 (5.23661e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 2.834890626503149 (3.71017e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 2.834889632541317 (3.50617e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 2.834888664861416 (3.41347e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 2.834887902168451 (2.69038e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 2.834887346633427 (1.95964e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 2.834886949537575 (1.40075e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 2.834886680467465 (9.49139e-06% change)
# Finished solving for bands 11 to 20 after 83 iterations.
# Solving for bands 21 to 30...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 24.09975176639929 (188.517% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 6.047523838701402 (119.76% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 4.541476693762355 (28.4455% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.04502357628812 (11.5636% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 3.822356189073101 (5.66052% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 3.730083013847192 (2.44353% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.672967372311642 (1.54303% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 3.640533575293149 (0.886957% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 3.620049922252238 (0.564243% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 3.606564426283433 (0.373218% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 3.599263267978784 (0.202646% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 3.59441431099133 (0.134812% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 3.59139155373416 (0.0841313% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 3.589435923691708 (0.0544681% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 3.587766337577376 (0.0465247% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 3.586382463410984 (0.0385795% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 3.584674621916428 (0.0476315% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 3.582795238401621 (0.052442% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 3.580937990502151 (0.0518514% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 3.579297091866979 (0.0458337% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 3.578271032382923 (0.0286706% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 3.577636612897687 (0.0177313% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 3.577292368069461 (0.00962259% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 3.577105492632709 (0.00522407% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 3.576980768739489 (0.00348679% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 3.57690207571943 (0.00220001% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 3.576848066673783 (0.00150995% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 3.576808289864728 (0.00111207% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 3.576778366850676 (0.000836588% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 3.576749808665217 (0.000798436% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 3.576724892771374 (0.00069661% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 3.576704406601472 (0.000572765% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 3.576688845118252 (0.00043508% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 3.576678978988369 (0.000275846% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 3.576672597827886 (0.00017841% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 3.576668849076016 (0.000104811% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 3.576666879016032 (5.50809e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 3.576665801189707 (3.01349e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 3.576665198495852 (1.68507e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 3.576664746599894 (1.26346e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 3.576664305267566 (1.23392e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 3.576663871839082 (1.21182e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 3.57666341839742 (1.26778e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 3.576662961729593 (1.2768e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 3.576662475938324 (1.35822e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 3.576661966162547 (1.42528e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 3.576661509234333 (1.27753e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 3.576661100403141 (1.14305e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 3.57666072543731 (1.04837e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 3.576660333370438 (1.09618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 3.576659793295121 (1.51e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 3.576658917254124 (2.44933e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 3.576657187768234 (4.83548e-05% change)
#     large trace change predicted (9.69507e-05%)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 3.576653723717742 (9.68517e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 3.576647544358331 (0.000172769% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 3.576638303869145 (0.000258356% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 3.576627722983717 (0.000295834% change)
#     linmin: converged after 4 iterations.
#     iteration   58: trace = 3.576617534970575 (0.00028485% change)
#     linmin: converged after 4 iterations.
#     iteration   59: trace = 3.576608189384445 (0.000261297% change)
#     linmin: converged after 4 iterations.
#     iteration   60: trace = 3.576599890945641 (0.00023202% change)
#     linmin: converged after 4 iterations.
#     iteration   61: trace = 3.576592376966564 (0.000210087% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 3.576585703130236 (0.000186598% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 3.576579865770217 (0.000163211% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 3.576574246155453 (0.000157123% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 3.576568390132544 (0.000163733% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 3.576562013615763 (0.000178286% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 3.576556166142363 (0.000163494% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 3.576552158306655 (0.000112059% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 3.576549962711523 (6.13886e-05% change)
#     resetting CG direction...
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 3.576549420226278 (1.51678e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 3.576548580962465 (2.34657e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 3.576548192075649 (1.08732e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 3.576547974289496 (6.08928e-06% change)
# Finished solving for bands 21 to 30 after 73 iterations.
# Finished k-point with 66.3333 mean iterations/band.
# freqs:, 1, 0, 0.5, 0.5, 0.707107, 0.307313, 0.307361, 0.307578, 0.307613, 0.31728, 0.317289, 0.317304, 0.317323, 0.511937, 0.512046, 0.512073, 0.512407, 0.534713, 0.534751, 0.535023, 0.535038, 0.539741, 0.539766, 0.539807, 0.540053, 0.541495, 0.541619, 0.541767, 0.541786, 0.620048, 0.620091, 0.620153, 0.620176, 0.657545, 0.657564
# elapsed time for k point: 15.481217384338379
# solve_kpoint (0,0.525,0.475):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.310622355222278 (0.238149% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 1.309673942660467 (0.0723897% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 1.309042831442589 (0.0482% change)
#     large trace change predicted (0.211272%)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 1.306629090035617 (0.18456% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 1.30301171249238 (0.277232% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 1.300759944016812 (0.172962% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 1.299271121730806 (0.114523% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 1.298893748717705 (0.0290492% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.29875688995161 (0.0105371% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 1.298669545789795 (0.00672544% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.298618045431366 (0.0039657% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.298570744203305 (0.00364249% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 1.298513341093631 (0.00442058% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 1.298470376865076 (0.00330878% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 1.298444159605979 (0.00201911% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 1.298428744546693 (0.0011872% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 1.298418644450106 (0.000777874% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 1.298404817540342 (0.00106491% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 1.298388016289282 (0.001294% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 1.298378735583837 (0.000714789% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 1.298375149366377 (0.000276208% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 1.298373871844061 (9.8394e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 1.298373440569441 (3.32165e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 1.298373226509651 (1.64868e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 1.298373075657341 (1.16186e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 1.298372937227647 (1.06618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 1.298372799752217 (1.05883e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 1.298372703678366 (7.39956e-06% change)
# Finished solving for bands 1 to 10 after 28 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.845207345339845 (0.069619% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 2.844800698607283 (0.0142934% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 2.84464874968573 (0.00534143% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.844590751670892 (0.00203887% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.84455775215954 (0.00116009% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.84454733318496 (0.000366278% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.844541803945625 (0.00019438% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.844539468728013 (8.20947e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.844538292962856 (4.13341e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.844537202715137 (3.83278e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.844536376109029 (2.90594e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.844535775762929 (2.11052e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.844535399101286 (1.32416e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.844535207321744 (6.74203e-06% change)
# Finished solving for bands 11 to 20 after 14 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.579747912094062 (0.107051% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 3.577847343260923 (0.0531064% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 3.576466123183744 (0.0386122% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 3.575217619607781 (0.034915% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace =
change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 2.856483599144579 (0.00226889% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 2.856412060583147 (0.00250446% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 2.856332989571138 (0.00276823% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 2.856245631674038 (0.00305844% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 2.856148853588289 (0.00338835% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 2.856040699626529 (0.00378678% change)
#     linmin: converged after 4 iterations.
#     iteration   34: trace = 2.855918738835764 (0.00427037% change)
#     linmin: converged after 4 iterations.
#     iteration   35: trace = 2.855782469644457 (0.00477158% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 2.855637754304527 (0.00506758% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 2.855497176415516 (0.00492294% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 2.855371252077264 (0.00440999% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 2.855262545830901 (0.00380715% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 2.85516872072489 (0.0032861% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 2.855086385287599 (0.00288377% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 2.855012600390363 (0.00258436% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 2.854945140270948 (0.00236289% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 2.85488239844211 (0.00219768% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 2.854823243261851 (0.00207209% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 2.854766895166057 (0.00197381% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 2.854712832790869 (0.00189378% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 2.854660721792373 (0.00182545% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 2.854610359966787 (0.00176421% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 2.854561634674885 (0.00170691% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 2.854514490687073 (0.00165155% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 2.854468907540988 (0.00159689% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 2.854424885276442 (0.00154223% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 2.854382436519089 (0.00148713% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 2.85434158209077 (0.0014313% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 2.854302347331003 (0.00137457% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 2.85426475716215 (0.00131697% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 2.854228829365376 (0.00125875% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 2.854194566872564 (0.00120042% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 2.854161950657566 (0.00114275% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 2.854130934823755 (0.00108669% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 2.854101444868844 (0.00103324% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 2.854073379269129 (0.000983348% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 2.854046613785267 (0.000937804% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 2.8540210075017 (0.000897196% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 2.853996409567968 (0.000861873% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 2.853972665809173 (0.000831951% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 2.853949624662944 (0.000807339% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 2.853927142189515 (0.00078777% change)
#     resetting CG direction...
#     large trace change predicted (0.0825665%)
#     linmin: converged after 4 iterations.
#     iteration   70: trace = 2.85156557997418 (0.0827821% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 2.849429904867006 (0.0749229% change)
#     linmin: converged after 4 iterations.
#     iteration   72: trace = 2.847643921828212 (0.0626983% change)
#     linmin: converged after 4 iterations.
#     iteration   73: trace = 2.84594848893032 (0.0595558% change)
#     linmin: converged after 4 iterations.
#     iteration   74: trace = 2.844341139462625 (0.0564945% change)
#     linmin: converged after 4 iterations.
#     iteration   75: trace = 2.842790801783516 (0.0545209% change)
#     linmin: converged after 4 iterations.
#     iteration   76: trace = 2.841846739011328 (0.0332145% change)
#     linmin: converged after 4 iterations.
#     iteration   77: trace = 2.840874807422273 (0.0342066% change)
#     linmin: converged after 4 iterations.
#     iteration   78: trace = 2.840279918953628 (0.0209425% change)
#     linmin: converged after 4 iterations.
#     iteration   79: trace = 2.839989402152242 (0.010229% change)
#     linmin: converged after 4 iterations.
#     iteration   80: trace = 2.839759341447365 (0.00810109% change)
#     linmin: converged after 4 iterations.
#     iteration   81: trace = 2.839530010343651 (0.00807605% change)
#     linmin: converged after 4 iterations.
#     iteration   82: trace = 2.839286262348902 (0.00858446% change)
#     linmin: converged after 4 iterations.
#     iteration   83: trace = 2.839137341294525 (0.00524515% change)
#     linmin: converged after 4 iterations.
#     iteration   84: trace = 2.839060142953223 (0.00271911% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 2.83901869021306 (0.0014601% change)
#     linmin: converged after 4 iterations.
#     iteration   86: trace = 2.838967316131728 (0.00180959% change)
#     linmin: converged after 4 iterations.
#     iteration   87: trace = 2.838915569712554 (0.00182274% change)
#     linmin: converged after 4 iterations.
#     iteration   88: trace = 2.838876892921042 (0.00136239% change)
#     linmin: converged after 2 iterations.
#     iteration   89: trace = 2.838853298568961 (0.000831119% change)
#     linmin: converged after 2 iterations.
#     iteration   90: trace = 2.838836113243384 (0.000605363% change)
#     linmin: converged after 2 iterations.
#     iteration   91: trace = 2.838820903057568 (0.000535791% change)
#     linmin: converged after 2 iterations.
#     iteration   92: trace = 2.838798989193664 (0.000771938% change)
#     linmin: converged after 2 iterations.
#     iteration   93: trace = 2.838776600030399 (0.000788687% change)
#     linmin: converged after 4 iterations.
#     iteration   94: trace = 2.838751016926774 (0.000901206% change)
#     linmin: converged after 4 iterations.
#     iteration   95: trace = 2.838723873174155 (0.000956191% change)
#     linmin: converged after 4 iterations.
#     iteration   96: trace = 2.838693787020667 (0.00105985% change)
#     linmin: converged after 4 iterations.
#     iteration   97: trace = 2.838662246246439 (0.00111111% change)
#     linmin: converged after 2 iterations.
#     iteration   98: trace = 2.83863646790881 (0.00090812% change)
#     linmin: converged after 2 iterations.
#     iteration   99: trace = 2.838599838270651 (0.0012904% change)
#     linmin: converged after 3 iterations.
#     iteration  100: trace = 2.838540627474502 (0.00208594% change)
#     linmin: converged after 3 iterations.
#     iteration  101: trace = 2.838453194606384 (0.00308025% change)
#     linmin: converged after 4 iterations.
#     iteration  102: trace = 2.838349730262481 (0.00364516% change)
#     linmin: converged after 4 iterations.
# ...
#     iteration    2: trace = 3.778246367385066 (9.84926% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 3.657666143395308 (3.24319% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 3.60347535082016 (1.49262% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 3.581057133340269 (0.624069% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 3.571316913795419 (0.272363% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 3.567283447493042 (0.113004% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 3.566203269620962 (0.0302847% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 3.565890233668734 (0.00877823% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 3.56577169454601 (0.00332431% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.565718663247047 (0.00148724% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 3.565683483465633 (0.000986616% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 3.565659661128076 (0.000668102% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 3.565640482368718 (0.000537876% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 3.565625379089584 (0.000423579% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 3.565617785012106 (0.00021298% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 3.565614304782387 (9.76053e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 3.565612946052369 (3.81065e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 3.56561220224944 (2.08605e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 3.565611733879712 (1.31357e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 3.565611506639968 (6.37309e-06% change)
# Finished solving for bands 21 to 30 after 21 iterations.
# Finished k-point with 58.6667 mean iterations/band.
# freqs:, 3, 0, 0.55, 0.45, 0.710634, 0.282238, 0.28904, 0.30885, 0.308898, 0.318569, 0.318601, 0.330395, 0.34373, 0.497381, 0.512372, 0.512839, 0.526525, 0.528609, 0.531832, 0.533897, 0.534995, 0.535039, 0.540208, 0.540438, 0.541725, 0.541846, 0.545711, 0.548301, 0.550182, 0.613066, 0.615904, 0.615988, 0.627114, 0.648739, 0.649706
# elapsed time for k point: 14.261849164962769
# solve_kpoint (0,0.575,0.425):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1
-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 3.549348551385965 (9.25464e-06% change)
# Finished solving for bands 21 to 30 after 11 iterations.
# Finished k-point with 12 mean iterations/band.
# freqs:, 5, 0, 0.6, 0.4, 0.72111, 0.25489, 0.259493, 0.313363, 0.313413, 0.32234, 0.32237, 0.349897, 0.367319, 0.485747, 0.513597, 0.514045, 0.521043, 0.524603, 0.526602, 0.535831, 0.535892, 0.541203, 0.541388, 0.542376, 0.546337, 0.5425, 0.557384, 0.557864, 0.559047, 0.606241, 0.606457, 0.606525, 0.633827, 0.63781, 0.639444
# elapsed time for k point: 2.8262381553649902
# solve_kpoint (0,0.625,0.375):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 1.29773588601413 (0.221108% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 1.297147881831688 (0.0453203% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.297034331675475 (0.00875422% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.297001788570459 (0.00250907% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.296986691879604 (0.00116398% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.296982111023679 (0.000353193% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.296976583288433 (0.000426201% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.296973050407519 (0.000272394% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.296971153762264 (0.000146236% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.296970237106511 (7.06767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.296969907548336 (2.54099e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 1.296969792308094 (8.88534e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 2.847627555665394 (0.063234% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 2.847070025032377 (0.0195807% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 2.846830254485151 (0.00842201% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 2.846696770152065 (0.00468899% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.846630819968292 (0.00231675% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.846610986698382 (0.00069673% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.846599467922567 (0.00040465% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.846595122557073 (0.000152651% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.846593145913494 (6.94389e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.846591958868 (4.17006e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.846591375894822 (2.04797e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.846590923042446 (1.59086e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.846590544663204 (1.32924e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.846590320045931 (7.89075e-06% change)
# Finished solving for bands 11 to 20 after 14 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 3.542567075130263 (0.0757453% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 3.541758069254613 (0.0228393% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 3.541445676579478 (0.00882066% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 3.541303674805718 (0.00400979% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 3.541240140002069 (0.00179412% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 3.541222227701091 (0.000505821% change)
#     linmin: converged after 2 iterations.

# %%
### Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=2, resolution=64)
eps = ms.get_epsilon()
cube_converted_eps = md.convert(eps)
layer_slice = 30
plt.imshow(cube_converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
x = range(len(crysfreqs))
figgy = plt.figure()
plt.plot(x,crysfreqs, color='blue')
plt.ylabel('frequency (c/a)', size=16)
plt.grid(True)
figax = plt.gca()

plt.show()
# Out:
# epsilon: 1-11.56, mean 6.21953, harm. mean 2.01398, 61.3426% > 1, 49.4274% "fill"
# real part range: 1 .. 11.56

# %% [markdown]
# These don't agree, so let's look at the 3D models and see if we can find the problem.

# %%
import trimesh
import trimesh.voxel as tv

rhombmesh = tv.ops.matrix_to_marching_cubes(rhomb_converted_eps, threshold = 8)

cubemesh = tv.ops.matrix_to_marching_cubes(cube_converted_eps, threshold= 8)
xshift = 10
yshift = 0
zshift = 0
translate = np.array(([1,0,0,xshift], [0,1,0,yshift], [0,0,1,zshift], [0,0,0,1]))
scene = trimesh.scene.Scene(cubemesh)
# scene.add_geometry(cubemesh, transform=translate)
scene.show(viewer='gl')
# Out:
# SceneViewer(width=1800, height=1350)

# %%
scene = trimesh.scene.Scene(rhombmesh)
# scene.add_geometry(cubemesh, transform=translate)
scene.show(viewer='gl')
# Out:
# SceneViewer(width=1800, height=1350)
