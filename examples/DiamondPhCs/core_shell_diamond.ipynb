# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif and including a core-shell structure.. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_conv = 1
a_mag = np.sqrt(.5)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .12
rel_diam = (radius*2)/a_conv
cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# We then use the same vertices to build the shell, by passing a different value for the radius. Right now, these structures will be independent. When we convert them to MPB objects, one will overwrite the other and form the core-shell structure.

# %%
shell_radius = .035
rel_shell = (shell_radius/radius)
full_radius = shell_radius+radius
shell_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=full_radius)
shell_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=full_radius)
shell_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=full_radius)
shell_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=full_radius)

shell_cell = [shell_1, shell_2, shell_3, shell_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 2
a2_reps = 2
a3_reps = 2
core_crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )
shell_crystal = geo_lattice.tile_geogeometry(shell_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene. We want to render the core and shell in different colors, so we will use a visualize and "add to visualizer" combination.

# %%
# scene = viewer.visualize(core_crystal, c='white', res=5)
# viewer.add_to_visualizer(shell_crystal, scene, c='red', alpha=.5, res=5)
# scene.show().close()
# objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

febid_n = 2
si_n = 3.75

febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(unit_cell, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_cell, material=si_mat, lattice=mpb_lattice)

mpb_geometry = shell_geometry+core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(4, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 24  # use a 16x16x16 grid
mesh_size = 1
num_bands = 20

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)
ms.optimize_grid_size=True

ms.run()
# Out:
# Initializing eigensolver data
# Computing 20 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 18 x 18 x 18.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.155, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.155, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.155, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.155, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.12, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.12, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.12, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.12, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
# Geometric object tree has depth 8 and 484 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.525, 0.475>
#   Vector3<0.0, 0.55, 0.45>
#   Vector3<0.0, 0.575, 0.425>
#   Vector3<0.0, 0.6, 0.4>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.6, 0.3>
#   Vector3<0.0, 0.575, 0.225>
#   Vector3<0.0, 0.55, 0.15000000000000002>
#   Vector3<0.0, 0.525, 0.07500000000000001>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.3, 0.0>
#   Vector3<0.0, 0.19999999999999996, 0.0>
#   Vector3<0.0, 0.09999999999999998, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.1>
#   Vector3<0.0, 0.2, 0.2>
#   Vector3<0.0, 0.30000000000000004, 0.30000000000000004>
#   Vector3<0.0, 0.4, 0.4>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.05, 0.55, 0.5>
#   Vector3<0.1, 0.6, 0.5>
#   Vector3<0.15000000000000002, 0.65, 0.5>
#   Vector3<0.2, 0.7, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.275, 0.75, 0.475>
#   Vector3<0.3, 0.75, 0.45>
#   Vector3<0.325, 0.75, 0.425>
#   Vector3<0.35, 0.75, 0.4>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.09802126884460449
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10, band 11, band 12, band 13, band 14, band 15, band 16, band 17, band 18, band 19, band 20
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 35.27813670071767 (191.171% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 7.517805254361916 (129.733% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 5.704768642297986 (27.4234% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 5.091501661773377 (11.3607% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.895363745161141 (3.92792% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.808953634323123 (1.78086% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.768080039978519 (0.853575% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.746327392979514 (0.457257% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.734356204427097 (0.252539% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.727333883500185 (0.148437% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.722758024968718 (0.0968426% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 4.719476589596898 (0.0695055% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 4.717053008304456 (0.0513659% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 4.71539490529919 (0.0351574% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 4.71426515927827 (0.0239615% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 4.713368223285336 (0.0190278% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 4.712508938453031 (0.0182325% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 4.711535178831601 (0.0206654% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 4.710424416933123 (0.0235782% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 4.709331648772991 (0.0232016% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 4.708449681902365 (0.0187298% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 4.707857468400923 (0.0125785% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 4.707502058188694 (0.00754958% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 4.707308100826361 (0.00412026% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 4.707206791642487 (0.00215219% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 4.707151719847712 (0.00116995% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 4.707120534865299 (0.000662504% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 4.707102973436823 (0.000373083% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 4.707093589247727 (0.000199363% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 4.707088860698383 (0.000100456% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 4.707086374808854 (5.28116e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 4.707084897878545 (3.13767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 4.707083948941462 (2.01598e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 4.707083333473773 (1.30754e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 4.707082941722341 (8.32259e-06% change)
# Finished solving for bands 1 to 10 after 35 iterations.
# Solving for bands 11 to 20...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 59.64304152775747 (185.321% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 17.074018283351 (110.977% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 13.31378005370055 (24.7483% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 11.88889439390385 (11.3074% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace =
change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 10.29623253067964 (0.0016341% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 10.29612706523466 (0.00102432% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 10.29607249826052 (0.000529977% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 10.29604309585146 (0.00028557% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 10.2960246425677 (0.000179227% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 10.29601379837986 (0.000105324% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 10.29600666210396 (6.93111e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 10.29600154131552 (4.97357e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 10.29599775401489 (3.67842e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 10.2959946817688 (2.98392e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 10.29599217537514 (2.43434e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 10.2959899164406 (2.19399e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 10.29598756953559 (2.27944e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 10.29598510912765 (2.38968e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 10.29598191844851 (3.09896e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 10.29597705743852 (4.72127e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 10.29596864551543 (8.17011e-05% change)
#     large trace change predicted (0.000180294%)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 10.29595010640274 (0.000180062% change)
#     large trace change predicted (0.000564565%)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 10.29589329542491 (0.000551781% change)
#     large trace change predicted (0.00761623%)
#     linmin: converged after 6 iterations.
#     iteration   30: trace = 10.29563723177786 (0.00248708% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 10.29542132136249 (0.00209713% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 10.29522858790472 (0.00187205% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 10.29502622657733 (0.0019656% change)
#     linmin: converged after 4 iterations.
#     iteration   34: trace = 10.29478761783373 (0.00231774% change)
#     linmin: converged after 4 iterations.
#     iteration   35: trace = 10.29452774565513 (0.00252434% change)
#     linmin: converged after 4 iterations.
#     iteration   36: trace = 10.29427228027213 (0.0024816% change)
#     linmin: converged after 4 iterations.
#     iteration   37: trace = 10.29401933249003 (0.0024572% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 10.29378459563813 (0.00228035% change)
#     linmin: converged after 4 iterations.
#     iteration   39: trace = 10.29357998692606 (0.00198771% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 10.29339894126666 (0.00175884% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 10.29323644613744 (0.00157865% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 10.2930930585517 (0.00139304% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 10.29296788385731 (0.00121611% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 10.29285696411539 (0.00107763% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 10.2927563933781 (0.000977097% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 10.29266435134494 (0.000894245% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 10.29258064321873 (0.000813283% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 10.29250518953961 (0.000733091% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 10.29243716610216 (0.000660905% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 10.29237522155714 (0.000601847% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 10.29231812091541 (0.000554787% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 10.29226516371962 (0.000514533% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 10.29221617028163 (0.000476023% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 10.29217116959886 (0.000437231% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 10.29213007121351 (0.000399318% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 10.29209253375913 (0.000364721% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 10.29205804257274 (0.000335124% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 10.29202607411508 (0.000310613% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 10.29199622693308 (0.000290003% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 10.29196826336852 (0.000271702% change)
#     linmin: converged after 3 iterations.
#     iteration   61: trace = 10.29194206567006 (0.000254545% change)
#     linmin: converged after 3 iterations.
#     iteration   62: trace = 10.29191754866011 (0.000238216% change)
#     linmin: converged after 3 iterations.
#     iteration   63: trace = 10.29189458318803 (0.000223141% change)
#     linmin: converged after 3 iterations.
#     iteration   64: trace = 10.29187296620255 (0.000210039% change)
#     linmin: converged after 3 iterations.
#     iteration   65: trace = 10.29185243951188 (0.000199446% change)
#     linmin: converged after 3 iterations.
#     iteration   66: trace = 10.29183273542058 (0.000191453% change)
#     linmin: converged after 3 iterations.
#     iteration   67: trace = 10.29181362332325 (0.000185702% change)
#     linmin: converged after 3 iterations.
#     iteration   68: trace = 10.29179493906096 (0.000181545% change)
#     linmin: converged after 3 iterations.
#     iteration   69: trace = 10.29177658898043 (0.000178298% change)
#     resetting CG direction...
#     large trace change predicted (0.00510283%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 10.29125138472789 (0.00510327% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 10.29076895228796 (0.0046879% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 10.29041114630174 (0.00347702% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 10.29014046939591 (0.00263041% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 10.28994043299329 (0.00194398% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 10.28979532285438 (0.00141022% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 10.28967598076924 (0.00115982% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 10.28959001959221 (0.000835415% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 10.28953388948476 (0.000545505% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 10.28949662402107 (0.000362169% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 10.28946523186226 (0.00030509% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 10.28945213582037 (0.000127276% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 10.28944670602554 (5.27705e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 10.28944397705642 (2.6522e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 10.28944255379226 (1.38323e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 10.28944176560935 (7.66011e-06% change)
# Finished solving for bands 11 to 20 after 85 iterations.
# Finished k-point with 50 mean iterations/band.
# freqs:, 31, 0.375, 0.75, 0.375, 1.06066, 0.511876, 0.53508, 0.600322, 0.617913, 0.626731, 0.663104, 0.750186, 0.757981, 0.819756, 0.874531, 0.914511, 0.918026, 0.966638, 0.976124, 1.00619, 1.02304, 1.03997, 1.04479, 1.10351, 1.12838
# elapsed time for k point: 11.402700185775757
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.534081319089726 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5375439488844138 at Vector3<0.3, 0.75, 0.45>
# Band 3 range: 0.5297516742408238 at Vector3<0.0, 0.5, 0.0> to 0.8248333567754972 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5616577543620626 at Vector3<0.0, 0.5, 0.0> to 0.8251727730816923 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.6267311171860204 at Vector3<0.375, 0.75, 0.375> to 0.8322018187815384 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6469517376354834 at Vector3<0.0, 0.625, 0.375> to 0.8339653874014419 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.6800865573810201 at Vector3<0.25, 0.75, 0.5> to 0.8346485527912911 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.6967886344458211 at Vector3<0.25, 0.75, 0.5> to 0.8449330446566465 at Vector3<0.0, 0.09999999999999998, 0.0>
# Band 9 range: 0.7901149393382462 at Vector3<0.0, 0.5, 0.5> to 0.885977748160103 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 0.8169843799566381 at Vector3<0.0, 0.55, 0.45> to 0.9079609250895206 at Vector3<0.3, 0.75, 0.45>
# Band 11 range: 0.8310146815073105 at Vector3<0.0, 0.5, 0.5> to 0.926644712527383 at Vector3<0.0, 0.6, 0.3>
# Band 12 range: 0.8677000728514748 at Vector3<0.0, 0.5, 0.5> to 0.9437437338856679 at Vector3<0.0, 0.625, 0.375>
# Band 13 range: 0.9140317979175309 at Vector3<0.0, 0.1, 0.1> to 0.9841487815143095 at Vector3<0.0, 0.5, 0.5>
# Band 14 range: 0.9198346391058738 at Vector3<0.0, 0.0, 0.0> to 1.030950647437775 at Vector3<0.0, 0.5, 0.5>
# Band 15 range: 0.9487116410121438 at Vector3<0.0, 0.1, 0.1> to 1.039956510606197 at Vector3<0.0, 0.5, 0.5>
# Band 16 range: 0.9608657008994531 at Vector3<0.0, 0.1, 0.1> to 1.047141410879611 at Vector3<0.0, 0.55, 0.45>
# Band 17 range: 0.9686573701802264 at Vector3<0.0, 0.0, 0.0> to 1.0704740787980427 at Vector3<0.0, 0.4, 0.4>
# Band 18 range: 0.9688567424810692 at Vector3<0.0, 0.0, 0.0> to 1.0756876218641198 at Vector3<0.0, 0.5, 0.5>
# Band 19 range: 0.9700682767025297 at Vector3<0.0, 0.0, 0.0> to 1.1035063946876986 at Vector3<0.375, 0.75, 0.375>
# Band 20 range: 1.0653383229461384 at Vector3<0.0, 0.5, 0.0> to 1.1292291596638282 at Vector3<0.35, 0.75, 0.4>
# total elapsed time for run: 159.7404887676239
# done

# %% [markdown]
# First, lets's just plot the usual MPB outputs: a dielectric slice and a unitless band structure.

# %%
## Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 10
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()


unit_cell = 400

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
nonzero_freqs = np.where(crysfreqs > 0, crysfreqs, .01)
crysfreqs_scaled = (((unit_cell/1000)/nonzero_freqs)*1000)

freqlims = np.array([.6202, .6263])
wllims = (((unit_cell/1000)/freqlims)*1000)

x = range(len(crysfreqs))
figgy = plt.figure(figsize=(7,7))
plt.plot(x,crysfreqs_scaled, color='blue');
plt.fill_between(x, wllims[1], wllims[0], color='green', alpha=.65)
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs, size=18)
plt.xlabel("Direction", size=24)

plt.ylabel('wavelength (nm)', size=24)
plt.yticks(size=18)

plt.ylim((450,1100))
plt.xlim(0,35)

plt.grid(True)
figax = plt.gca()

plt.title(f"{unit_cell} nm Unit Cell \n FEBID n = {febid_n} | HPCVD n= {si_n} \n Diameter = {rel_diam*unit_cell:.0f} nm \n Shell Thickness = {rel_shell * (rel_diam*unit_cell/2):.0f} nm")
# plt.savefig("DiamondCoreShell-Unitless.png")

plt.figure()
plt.plot(x, crysfreqs, color='blue')
# Out:
# epsilon: 1-14.0625, mean 3.96993, harm. mean 1.69757, 55.5041% > 1, 22.7363% "fill"
# real part range: 1 .. 14.0625
# [<matplotlib.lines.Line2D at 0x759e3b5afb50>,
#  <matplotlib.lines.Line2D at 0x759e3b5af8d0>,
#  <matplotlib.lines.Line2D at 0x759e3b5afa10>,
#  <matplotlib.lines.Line2D at 0x759e3b358f50>,
#  <matplotlib.lines.Line2D at 0x759e3a3edcd0>,
#  <matplotlib.lines.Line2D at 0x759e3b5e8550>,
#  <matplotlib.lines.Line2D at 0x759e3b3e8190>,
#  <matplotlib.lines.Line2D at 0x759e3b5e9190>,
#  <matplotlib.lines.Line2D at 0x759e3b5e8910>,
#  <matplotlib.lines.Line2D at 0x759e3b5e8250>,
#  <matplotlib.lines.Line2D at 0x759e3b3eae50>,
#  <matplotlib.lines.Line2D at 0x759e3b3e9390>,
#  <matplotlib.lines.Line2D at 0x759e3b5b8150>,
#  <matplotlib.lines.Line2D at 0x759e3b5e8210>,
#  <matplotlib.lines.Line2D at 0x759e3b359450>,
#  <matplotlib.lines.Line2D at 0x759e3b359290>,
#  <matplotlib.lines.Line2D at 0x759e3b5ba110>,
#  <matplotlib.lines.Line2D at 0x759e3b5b9c10>,
#  <matplotlib.lines.Line2D at 0x759e3b5bb550>,
#  <matplotlib.lines.Line2D at 0x759e3b5bbe50>]

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
