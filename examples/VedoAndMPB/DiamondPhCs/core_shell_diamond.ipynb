# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo
# Out:
# Lumpy and/or the Lumerical API were not found.

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif and including a core-shell structure.. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_conv = 1
a_mag = np.sqrt(.5)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .11
rel_diam = (radius*2)/a_conv
cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# We then use the same vertices to build the shell, by passing a different value for the radius. Right now, these structures will be independent. When we convert them to MPB objects, one will overwrite the other and form the core-shell structure.

# %%
shell_radius = .02
rel_shell = (shell_radius/radius)
full_radius = shell_radius+radius
shell_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=full_radius)
shell_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=full_radius)
shell_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=full_radius)
shell_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=full_radius)

shell_cell = [shell_1, shell_2, shell_3, shell_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 2
a2_reps = 2
a3_reps = 2
core_crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )
shell_crystal = geo_lattice.tile_geogeometry(shell_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene. We want to render the core and shell in different colors, so we will use a visualize and "add to visualizer" combination.

# %%
# scene = viewer.visualize(core_crystal, c='white', res=5)
# viewer.add_to_visualizer(shell_crystal, scene, c='red', alpha=.5, res=5)
# scene.show().close()
# objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

febid_n = 1.8
si_n = 3.5
febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(unit_cell, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_cell, material=si_mat, lattice=mpb_lattice)

mpb_geometry = shell_geometry+core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(3, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 24  # use a 16x16x16 grid
mesh_size = 1
num_bands = 10

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)
ms.optimize_grid_size=True

ms.run()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 18 x 18 x 18.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.13, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.13, height 0.433013, axis (-0.408248, -0.408248, 1.22474)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.13, height 0.433013, axis (-0.408248, 1.22474, -0.408248)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.13, height 0.433013, axis (1.22474, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.11, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.11, height 0.433013, axis (-0.408248, -0.408248, 1.22474)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.11, height 0.433013, axis (-0.408248, 1.22474, -0.408248)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.11, height 0.433013, axis (1.22474, -0.408248, -0.408248)
# Geometric object tree has depth 7 and 240 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 25 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.53125, 0.46875>
#   Vector3<0.0, 0.5625, 0.4375>
#   Vector3<0.0, 0.59375, 0.40625>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.59375, 0.28125>
#   Vector3<0.0, 0.5625, 0.1875>
#   Vector3<0.0, 0.53125, 0.09375>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.375, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.125, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.125, 0.125>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.375, 0.375>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0625, 0.5625, 0.5>
#   Vector3<0.125, 0.625, 0.5>
#   Vector3<0.1875, 0.6875, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.28125, 0.75, 0.46875>
#   Vector3<0.3125, 0.75, 0.4375>
#   Vector3<0.34375, 0.75, 0.40625>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.04575920104980469
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 53.61985481934192 (189.167% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 11.39715520924968 (129.882% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 8.963392886796365 (23.9066% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 8.220210856674967 (8.6499% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 8.010422580741956 (2.58509% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.921725353476092 (1.11344% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.866320998849273 (0.701852% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.821725316468519 (0.568531% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 7.786983891785814 (0.445154% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 7.762335994792662 (0.317029% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 7.744528896463192 (0.229667% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 7.732554462799829 (0.154738% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 7.726301201969396 (0.080902% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 7.723702614709966 (0.0336387% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 7.722725794857307 (0.0126478% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 7.722316158325542 (0.00530444% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 7.722110466433467 (0.00266364% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 7.722001735894457 (0.00140805% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 7.721953164999644 (0.000628996% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 7.721933868118143 (0.000249897% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 7.721926169304275 (9.97006e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 7.721922940039414 (4.18194e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 7.721921515689421 (1.84455e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 7.721920890434937 (8.09714e-06% change)
# Finished solving for bands 1 to 10 after 24 iterations.
# freqs:, 1, 0, 0.5, 0.5, 1, 0.63225, 0.65062, 0.769875, 0.771741, 0.923394, 0.935411, 0.953568, 0.986138, 1.02151, 1.02844
# elapsed time for k point: 0.47382211685180664
# solve_kpoint (0,0.53125,0.46875):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 7.737791386967941 (0.396388% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 7.723727335209032 (0.181923% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 7.71684337773722 (0.0891671% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 7.713207071612478 (0.0471328% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 7.711608708155593 (0.0207246% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 7.710612742099007 (0.012916% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 7.709893258758734 (0.00933151% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 7.709546424046108 (0.00449867% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 7.709421047742392 (0.00162626% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 7.709388244159182 (0.000425501% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 7.709378588160394 (0.00012525% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 7.709374612559213 (5.15684e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 7.709372995111547 (2.09803e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 7
change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 9.063675251676585 (0.000337353% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 9.063647739635904 (0.000303542% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 9.063622750033108 (0.000275713% change)
#     linmin: converged after 2 iterations.
#     iteration   62: trace = 9.063599964398295 (0.000251397% change)
#     linmin: converged after 2 iterations.
#     iteration   63: trace = 9.063578953182921 (0.00023182% change)
#     linmin: converged after 2 iterations.
#     iteration   64: trace = 9.063558942116162 (0.000220786% change)
#     linmin: converged after 2 iterations.
#     iteration   65: trace = 9.063539429703287 (0.000215284% change)
#     linmin: converged after 2 iterations.
#     iteration   66: trace = 9.06352034651901 (0.000210549% change)
#     linmin: converged after 2 iterations.
#     iteration   67: trace = 9.063501903477921 (0.000203487% change)
#     linmin: converged after 2 iterations.
#     iteration   68: trace = 9.063484830641045 (0.000188369% change)
#     linmin: converged after 2 iterations.
#     iteration   69: trace = 9.0634698931361 (0.00016481% change)
#     resetting CG direction...
#     large trace change predicted (0.000516582%)
#     linmin: converged after 2 iterations.
#     iteration   70: trace = 9.063423074321058 (0.000516567% change)
#     linmin: converged after 2 iterations.
#     iteration   71: trace = 9.063383521330035 (0.000436403% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 9.063361865479086 (0.000238938% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 9.063349883063644 (0.000132207% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 9.063343661533466 (6.8645e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 9.063340296525611 (3.71277e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 9.063337746859013 (2.81316e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   77: trace = 9.063335731021668 (2.22417e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   78: trace = 9.063334167606641 (1.72499e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   79: trace = 9.063332848836653 (1.45506e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 9.063331616679983 (1.3595e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 9.063330316322237 (1.43475e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   82: trace = 9.063329006722734 (1.44494e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   83: trace = 9.063327819627233 (1.30978e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   84: trace = 9.06332674859688 (1.18172e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   85: trace = 9.063325888567499 (9.48911e-06% change)
# Finished solving for bands 1 to 10 after 85 iterations.
# freqs:, 12, 0, 0.125, 0, 0.216506, 0.15695, 0.160565, 0.997673, 1.00361, 1.04041, 1.05618, 1.06564, 1.09164, 1.09234, 1.13661
# elapsed time for k point: 1.6632003784179688
# solve_kpoint (0,0,0):
# Solving for bands 3 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 9.623037191555955 (7.13865% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 9.473910938771322 (1.56178% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 9.416111390769325 (0.611958% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 9.370098490369914 (0.489858% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 9.346768743276268 (0.249291% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.334680757842349 (0.129412% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 9.329364111916496 (0.0569721% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 9.326809793066538 (0.0273831% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 9.325292906496246 (0.016265% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 9.324483988515192 (0.00867483% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 9.324008908382453 (0.0050951% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 9.323701997382514 (0.00329167% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 9.323510766545782 (0.00205104% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 9.32338600111933 (0.00133819% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 9.323304201143886 (0.000877367% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 9.323245293876854 (0.00063183% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 9.323204995381825 (0.000432238% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 9.323183542033011 (0.000230107% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 9.323172201031895 (0.000121643% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 9.32316581247863 (6.85234e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 9.323162152455435 (3.92573e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 9.323159991973892 (2.31733e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 9.323159054449755 (1.00559e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 9.323158655252451 (4.28178e-06% change)
# Finished solving for bands 3 to 10 after 24 iterations.
# freqs:, 13, 0, 0, 0, 0, 0, 0, 1.05477, 1.05484, 1.05937, 1.0729, 1.08043, 1.08054, 1.1157, 1.11573
# elapsed time for k point: 0.3628835678100586
# solve_kpoint (0,0.125,0.125):
# Solving for bands 1 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 9.339985871929148 (3.5878% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 9.17457787217343 (1.78679% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 9.089079125258886 (0.936272% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 9.047336949380409 (0.460313% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 9.030437270671719 (0.186966% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 9.019893095711611 (0.116831% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 9.013675523810935 (0.0689555% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 9.009953079433071 (0.0413063% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 9.007519708318251 (0.0270112% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 9.006165893240096 (0.015031% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 9.005348972193028 (0.0090711% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 9.004831409343346 (0.00574745% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 9.00444814712368 (0.00425627% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 9.004066715563901 (0.00423612% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 9.003596940292478 (0.0052175% change)
#     large trace change predicted (0.0128828%)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 9.00246831584623 (0.012536% change)
#     large trace change predicted (0.0951102%)
#     linmin: converged after 7 iterations.
#     iteration   17: trace = 8.998689068618164 (0.0419889% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 8.995569346847542 (0.0346746% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 8.992530996776061 (0.0337818% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 8.988812155319462 (0.0413633% change)
#     linmin: converged after 5 iterations.
#     iteration   21: trace = 8.983774502822424 (0.0560593% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 8.978439806035068 (0.0593991% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 8.973179431597913 (0.0586061% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 8.96808985432971 (0.056736% change)
#     linmin: converged after 4 iterations.
#     iteration   25: trace = 8.962898767842386 (0.0579007% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 8.95780736797678 (0.0568214% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 8.952535962387453 (0.0588644% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 8.947075654560013 (0.0610103% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 8.941569082701706 (0.061565% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 8.936626601444345 (0.0552906% change)
#     linmin: converged after 4 iterations.
#     iteration   31: trace = 8.932492646801965 (0.0462693% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 8.929177800275387 (0.0371169% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 8.926709601773634 (0.0276458% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 8.924942878997507 (0.0197934% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 8.923714519755876 (0.0137642% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 8.922820325989639 (0.0100209% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 8.92213666859697 (0.00766219% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 8.92157408981749 (0.00630563% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 8.921124306496496 (0.00504165% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 8.920769761964268 (0.00397429% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 8.920502216412988 (0.00299918% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 8.920302095037597 (0.00224341% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 8.920151557320787 (0.0016876% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 8.920027554797402 (0.00139015% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 8.919924948601064 (0.0011503% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 8.919847099699711 (0.000872757% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 8.919792486250763 (0.000612271% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 8.91975244210119 (0.000448937% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 8.91972405373372 (0.000318265% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 8.919704038341102 (0.000224395% change)
#     linmin: converged after 2 iterations.
#     iteration   51: trace = 8.919688324422113 (0.000176171% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 8.919675176794238 (0.0001474% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 8.919665136802273 (0.00011256% change)
#     linmin: converged after 2 iterations.
#     iteration   54: trace = 8.919657770417041 (8.25859e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   55: trace = 8.919652554553297 (5.84761e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   56: trace = 8.919648952987767 (4.03779e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   57: trace = 8.919646377523881 (2.88741e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   58: trace = 8.919644476327131 (2.13147e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   59: trace = 8.919643058196291 (1.5899e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   60: trace = 8.919642021475065 (1.16229e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   61: trace = 8.919641306388172 (8.01699e-06% change)
# Finished solving for bands 1 to 10 after 61 iterations.
# freqs:, 14, 0, 0.125, 0.125, 0.25, 0.182234, 0.185423, 1.01329, 1.01875, 1.03143, 1.03188, 1.03467, 1.06939, 1.10251, 1.10866
# elapsed time for k point: 1.1693823337554932
# solve_kpoint (0,0.25,0.25):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 8.374023629727485 (2.73383% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 8.304118269215374 (0.838287% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 8.28613509596182 (0.216792% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 8
# Finished solving for bands 1 to 10 after 11 iterations.
# freqs:, 25, 0.375, 0.75, 0.375, 1.06066, 0.648745, 0.657091, 0.785605, 0.802227, 0.80428, 0.846808, 0.970022, 0.986879, 1.05095, 1.08792
# elapsed time for k point: 0.2662191390991211
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.6587221754302055 at Vector3<0.28125, 0.75, 0.46875>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.6756372859600379 at Vector3<0.25, 0.75, 0.5>
# Band 3 range: 0.690325364549382 at Vector3<0.0, 0.5, 0.0> to 1.0547713806859387 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.6945945714604239 at Vector3<0.0, 0.5, 0.0> to 1.0548448204800316 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.8042797463645489 at Vector3<0.375, 0.75, 0.375> to 1.0593722263444594 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8315842031131622 at Vector3<0.0, 0.625, 0.375> to 1.0729017526964992 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.8762816613088356 at Vector3<0.25, 0.75, 0.5> to 1.0804327431320595 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8885134802349611 at Vector3<0.25, 0.75, 0.5> to 1.0916396880918613 at Vector3<0.0, 0.125, 0.0>
# Band 9 range: 1.0215118507308079 at Vector3<0.0, 0.5, 0.5> to 1.160737786935356 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 1.0284382884163035 at Vector3<0.0, 0.5, 0.5> to 1.1756468879457964 at Vector3<0.25, 0.75, 0.5>
# Gap from band 2 (0.6756372859600379) to band 3 (0.690325364549382), 2.150582753322914%
# total elapsed time for run: 10.78615140914917
# done

# %% [markdown]
# First, lets's just plot the usual MPB outputs: a dielectric slice and a unitless band structure.

# %%
## Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=4, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 10
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()


unit_cell = 600

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
nonzero_freqs = np.where(crysfreqs > 0, crysfreqs, .01)
crysfreqs_scaled = (((unit_cell/1000)/nonzero_freqs)*1000)

freqlims = np.array([.6202, .6263])
wllims = (((unit_cell/1000)/freqlims)*1000)

x = range(len(crysfreqs))
figgy = plt.figure(figsize=(7,7))
plt.plot(x,crysfreqs_scaled, color='blue');
plt.fill_between(x, wllims[1], wllims[0], color='green', alpha=.65)
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs, size=18)
plt.xlabel("Direction", size=24)

plt.ylabel('wavelength (nm)', size=24)
plt.yticks(size=18)

plt.ylim((550, 1300))
plt.xlim(0,35)

plt.grid(True)
figax = plt.gca()

plt.title(f"{unit_cell} nm Unit Cell \n FEBID n = {febid_n} | HPCVD n= {si_n} \n Diameter = {rel_diam*unit_cell:.0f} nm \n Shell Thickness = {rel_shell * (rel_diam*unit_cell/2):.0f} nm")
# plt.savefig("DiamondCoreShell-Unitless.png")

plt.figure()
plt.plot(x, crysfreqs, color='blue')
# Out:
# epsilon: 1-12.25, mean 2.43068, harm. mean 1.31891, 36.1283% > 1, 12.7172% "fill"
# real part range: 1 .. 12.25
# [<matplotlib.lines.Line2D at 0x76831b1e3290>,
#  <matplotlib.lines.Line2D at 0x76831b313510>,
#  <matplotlib.lines.Line2D at 0x76831b1c37d0>,
#  <matplotlib.lines.Line2D at 0x76831b1e3b10>,
#  <matplotlib.lines.Line2D at 0x76831b1d7e90>,
#  <matplotlib.lines.Line2D at 0x76831b1ec210>,
#  <matplotlib.lines.Line2D at 0x76831b38c550>,
#  <matplotlib.lines.Line2D at 0x76831b354910>,
#  <matplotlib.lines.Line2D at 0x76831b34cc90>,
#  <matplotlib.lines.Line2D at 0x76831b1e3f50>]

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
