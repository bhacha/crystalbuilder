# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif and including a core-shell structure.. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_conv = 1
a_mag = np.sqrt(.5)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .075
rel_diam = (radius*2)/a_conv
cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# We then use the same vertices to build the shell, by passing a different value for the radius. Right now, these structures will be independent. When we convert them to MPB objects, one will overwrite the other and form the core-shell structure.

# %%
shell_radius = .05
rel_shell = (shell_radius/radius)
full_radius = shell_radius+radius
shell_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=full_radius)
shell_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=full_radius)
shell_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=full_radius)
shell_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=full_radius)

shell_cell = [shell_1, shell_2, shell_3, shell_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 2
a2_reps = 2
a3_reps = 2
core_crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )
shell_crystal = geo_lattice.tile_geogeometry(shell_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene. We want to render the core and shell in different colors, so we will use a visualize and "add to visualizer" combination.

# %%
# scene = viewer.visualize(core_crystal, c='white', res=5)
# viewer.add_to_visualizer(shell_crystal, scene, c='red', alpha=.5, res=5)
# scene.show().close()
# objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

febid_n = 2
si_n = 4

febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(unit_cell, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_cell, material=si_mat, lattice=mpb_lattice)

mpb_geometry = shell_geometry+core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(3, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 24  # use a 16x16x16 grid
mesh_size = 1
num_bands = 10

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)
ms.optimize_grid_size=True

ms.run()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 18 x 18 x 18.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.125, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.125, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.125, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.125, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.075, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.075, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.075, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.075, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
# Geometric object tree has depth 7 and 435 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 25 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0
change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 5.191916477351592 (0.000398042% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 5.191905361839499 (0.000214093% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 5.191898924064549 (0.000123996% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 5.191894478696895 (8.56213e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 5.191890818063615 (7.05067e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 5.191887735229725 (5.93779e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 5.191885229905798 (4.82546e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 5.191883266141716 (3.78237e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 5.191881630589441 (3.15021e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 5.191880171565966 (2.8102e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 5.191878825046348 (2.59351e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 5.191877696574037 (2.17353e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 5.191876806009067 (1.7153e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 5.191876038216919 (1.47883e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 5.191875294374288 (1.43271e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 5.191874554756868 (1.42457e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 5.191873913584468 (1.23495e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 5.191873429038399 (9.33278e-06% change)
# Finished solving for bands 1 to 10 after 49 iterations.
# freqs:, 14, 0, 0.125, 0.125, 0.25, 0.150521, 0.152158, 0.763087, 0.769324, 0.782366, 0.793303, 0.796514, 0.809708, 0.846005, 0.851288
# elapsed time for k point: 3.022773027420044
# solve_kpoint (0,0.25,0.25):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.113117871324502 (3.87546% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.04207910577462 (1.39906% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.019326905888901 (0.452267% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.998134193922254 (0.423115% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.982394583258291 (0.315406% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.974664463541486 (0.155269% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.968462200361226 (0.124755% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.964681228092129 (0.0761284% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.962714714627933 (0.0396179% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 64.8258%)
#     iteration   10: trace = 4.961548315057855 (0.023506% change)
#     iteration   11: trace = 4.960954784756559 (0.0119633% change)
#     iteration   12: trace = 4.960710364729689 (0.004927% change)
#     iteration   13: trace = 4.96059779035645 (0.00226935% change)
#     iteration   14: trace = 4.960545853792885 (0.00104699% change)
#     iteration   15: trace = 4.960519066496569 (0.000540008% change)
#     iteration   16: trace = 4.960503727629239 (0.000309219% change)
#     iteration   17: trace = 4.960495690612105 (0.00016202% change)
#     iteration   18: trace = 4.960491463601992 (8.52135e-05% change)
#     iteration   19: trace = 4.96048898971946 (4.98717e-05% change)
#     iteration   20: trace = 4.960487572445992 (2.85712e-05% change)
#     iteration   21: trace = 4.960486695787799 (1.76728e-05% change)
#     iteration   22: trace = 4.960486074012573 (1.25346e-05% change)
#     iteration   23: trace = 4.960485682779408 (7.88699e-06% change)
# Finished solving for bands 1 to 10 after 23 iterations.
# freqs:, 15, 0, 0.25, 0.25, 0.5, 0.293428, 0.299274, 0.723086, 0.728932, 0.740201, 0.76166, 0.766499, 0.798907, 0.818349, 0.840913
# elapsed time for k point: 1.3651814460754395
# solve_kpoint (0,0.375,0.375):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 4.893977700275168 (4.42844% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.828308214859325 (1.35091% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.814722069730279 (0.281782% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.808449744058757 (0.130359% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.804680339528576 (0.078422% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.803372592037495 (0.0272219% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.802740346360933 (0.0131634% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.80235087656259 (0.00810965% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.802102067657605 (0.00518112% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.80192103964818 (0.00376984% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.801800132179876 (0.00251793% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.80173752527007 (0.00130383% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.801705232742981 (0.00067252% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.801689617700548 (0.000325198% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.801682409912878 (0.00015011% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.801678836777654 (7.44143e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.801677191177845 (3.42713e-05% change)
#     linmin: converged after 2 iterations.
# ...
#     iteration   38: trace = 4.785621892797161 (0.000459601% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 4.78560353435482 (0.000383617% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace =
change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 4.76732816850317 (0.000534996% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 4.767311699066236 (0.000345465% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 4.767301442969449 (0.000215134% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 4.767295755931827 (0.000119293% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 4.767292434510334 (6.9671e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 4.767290448315385 (4.1663e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 4.767289146512955 (2.7307e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 4.767288192518655 (2.00113e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 4.767287517578715 (1.41577e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 4.767287084666017 (9.0809e-06% change)
# Finished solving for bands 1 to 10 after 30 iterations.
# freqs:, 23, 0.3125, 0.75, 0.4375, 1.07529, 0.486746, 0.527584, 0.61841, 0.634775, 0.665917, 0.695729, 0.732994, 0.74107, 0.840524, 0.86384
# elapsed time for k point: 2.78851056098938
# solve_kpoint (0.34375,0.75,0.40625):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.761327495994466 (0.43955% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.2085%)
#     iteration    2: trace = 4.754260484396987 (0.148535% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.752426910518396 (0.0385744% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.751325298540259 (0.0231827% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.750357976420753 (0.0203611% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.749771763547754 (0.0123412% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.749343160316432 (0.00902407% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.749068627694231 (0.0057806% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.74890992377198 (0.00334185% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.748801251493737 (0.00228839% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.748725589198521 (0.00159331% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.748677917117926 (0.0010039% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.74864422532294 (0.000709501% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.748623365604444 (0.000439278% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.748611692833712 (0.000245814% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.748603746370409 (0.000167343% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.748598325982474 (0.000114147% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.748595084822132 (6.82551e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 4.74859329513127 (3.76889e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 4.748592370283029 (1.94763e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 4.74859193584925 (9.14869e-06% change)
# Finished solving for bands 1 to 10 after 21 iterations.
# freqs:, 24, 0.34375, 0.75, 0.40625, 1.06434, 0.482099, 0.526799, 0.614296, 0.634693, 0.660045, 0.690847, 0.755359, 0.757252, 0.825126, 0.84894
# elapsed time for k point: 1.9045217037200928
# solve_kpoint (0.375,0.75,0.375):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.750955564506246 (0.423878% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.744464463011066 (0.136721% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 4.743007671421172 (0.0307098% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.742384911417555 (0.0131309% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 4.7419540860725 (0.00908498% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 4.741742132125762 (0.00446986% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.74161979665856 (0.00258% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.741554946423895 (0.00136769% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.741525140328418 (0.000628616% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.741509388934929 (0.000332202% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.74149980240519 (0.000202183% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.741494176404134 (0.000118655% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.741490166205788 (8.45767e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.741487477251675 (5.67112e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.741486066580335 (2.97517e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.74148525813818 (1.70504e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.741484709395898 (1.15732e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.741484325720184 (8.09189e-06% change)
# Finished solving for bands 1 to 10 after 18 iterations.
# freqs:, 25, 0.375, 0.75, 0.375, 1.06066, 0.480407, 0.526465, 0.612858, 0.634838, 0.657853, 0.689146, 0.761951, 0.769594, 0.815577, 0.842147
# elapsed time for k point: 1.5071744918823242
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.49760751155644956 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5280546663237466 at Vector3<0.28125, 0.75, 0.46875>
# Band 3 range: 0.5541572321925259 at Vector3<0.0, 0.5, 0.0> to 0.791889776148343 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5973473076538194 at Vector3<0.0, 0.5, 0.0> to 0.7950017588599739 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.6578525597507936 at Vector3<0.375, 0.75, 0.375> to 0.7951117833493794 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6720730942665206 at Vector3<0.0, 0.625, 0.375> to 0.8073325424270681 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.7019600351742379 at Vector3<0.25, 0.75, 0.5> to 0.8138073792817495 at Vector3<0.0, 0.125, 0.0>
# Band 8 range: 0.7258791560899148 at Vector3<0.25, 0.75, 0.5> to 0.8219694080740427 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 0.7852566652670121 at Vector3<0.0, 0.5, 0.5> to 0.8509506477566339 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 0.8072433216968552 at Vector3<0.0, 0.5, 0.5> to 0.8809840378839705 at Vector3<0.25, 0.75, 0.5>
# Gap from band 2 (0.5280546663237466) to band 3 (0.5541572321925259), 4.823928826612647%
# total elapsed time for run: 40.067564725875854
# done

# %% [markdown]
# First, lets's just plot the usual MPB outputs: a dielectric slice and a unitless band structure.

# %%
## Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=1, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 10
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()


unit_cell = 400

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
nonzero_freqs = np.where(crysfreqs > 0, crysfreqs, .01)
crysfreqs_scaled = (((unit_cell/1000)/nonzero_freqs)*1000)

freqlims = np.array([.6202, .6263])
wllims = (((unit_cell/1000)/freqlims)*1000)

x = range(len(crysfreqs))
figgy = plt.figure(figsize=(7,7))
plt.plot(x,crysfreqs_scaled, color='blue');
plt.fill_between(x, wllims[1], wllims[0], color='green', alpha=.65)
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs, size=18)
plt.xlabel("Direction", size=24)

plt.ylabel('wavelength (nm)', size=24)
plt.yticks(size=18)

plt.ylim((550, 1300))
plt.xlim(0,35)

plt.grid(True)
figax = plt.gca()

plt.title(f"{unit_cell} nm Unit Cell \n FEBID n = {febid_n} | HPCVD n= {si_n} \n Diameter = {rel_diam*unit_cell:.0f} nm \n Shell Thickness = {rel_shell * (rel_diam*unit_cell/2):.0f} nm")
# plt.savefig("DiamondCoreShell-Unitless.png")

plt.figure()
plt.plot(x, crysfreqs, color='blue')
# Out:
# epsilon: 1-16, mean 4.22964, harm. mean 1.47823, 41.4609% > 1, 21.5309% "fill"
# real part range: 1 .. 15.9959
# [<matplotlib.lines.Line2D at 0x7232b8303250>,
#  <matplotlib.lines.Line2D at 0x7232b89480d0>,
#  <matplotlib.lines.Line2D at 0x7232b86d81d0>,
#  <matplotlib.lines.Line2D at 0x7232b8840990>,
#  <matplotlib.lines.Line2D at 0x7232b87bab10>,
#  <matplotlib.lines.Line2D at 0x7232b895b090>,
#  <matplotlib.lines.Line2D at 0x7232b845a9d0>,
#  <matplotlib.lines.Line2D at 0x7232b8641790>,
#  <matplotlib.lines.Line2D at 0x7232b895b350>,
#  <matplotlib.lines.Line2D at 0x7232b895a6d0>]

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
