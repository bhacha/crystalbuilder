# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo
# Out:
# Error: Lumpy and/or the Lumerical API were not found.

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif and including a core-shell structure.. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_conv = 1
a_mag = np.sqrt(.5)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .11
rel_diam = (radius*2)/a_conv
cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# We then use the same vertices to build the shell, by passing a different value for the radius. Right now, these structures will be independent. When we convert them to MPB objects, one will overwrite the other and form the core-shell structure.

# %%
shell_radius = .02
rel_shell = (shell_radius/radius)
full_radius = shell_radius+radius
shell_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=full_radius)
shell_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=full_radius)
shell_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=full_radius)
shell_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=full_radius)

shell_cell = [shell_1, shell_2, shell_3, shell_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 2
a2_reps = 2
a3_reps = 2
core_crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )
shell_crystal = geo_lattice.tile_geogeometry(shell_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene. We want to render the core and shell in different colors, so we will use a visualize and "add to visualizer" combination.

# %%
# scene = viewer.visualize(core_crystal, c='white', res=5)
# viewer.add_to_visualizer(shell_crystal, scene, c='red', alpha=.5, res=5)
# scene.show().close()
# objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

febid_n = 1.8
si_n = 3.5
febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(unit_cell, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_cell, material=si_mat, lattice=mpb_lattice)

mpb_geometry = shell_geometry+core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(3, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 24  # use a 16x16x16 grid
mesh_size = 1
num_bands = 10

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)
ms.optimize_grid_size=True

ms.run()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 18 x 18 x 18.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.13, height 0.437343, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.13, height 0.437343, axis (-0.408248, -0.408248, 1.22474)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.13, height 0.437343, axis (-0.408248, 1.22474, -0.408248)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.13, height 0.437343, axis (1.22474, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.11, height 0.437343, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.11, height 0.437343, axis (-0.408248, -0.408248, 1.22474)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.11, height 0.437343, axis (-0.408248, 1.22474, -0.408248)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.11, height 0.437343, axis (1.22474, -0.408248, -0.408248)
# Geometric object tree has depth 7 and 240 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 25 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.53125, 0.46875>
#   Vector3<0.0, 0.5625, 0.4375>
#   Vector3<0.0, 0.59375, 0.40625>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.59375, 0.28125>
#   Vector3<0.0, 0.5625, 0.1875>
#   Vector3<0.0, 0.53125, 0.09375>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.375, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.125, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.125, 0.125>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.375, 0.375>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0625, 0.5625, 0.5>
#   Vector3<0.125, 0.625, 0.5>
#   Vector3<0.1875, 0.6875, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.28125, 0.75, 0.46875>
#   Vector3<0.3125, 0.75, 0.4375>
#   Vector3<0.34375, 0.75, 0.40625>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.04728960990905762
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10
# Solving for bands 1 to 10...
#     near maximum in trace
#     iteration    1: trace = 58.93748363584425 (188.44% change)
#     iteration    2: trace = 12.86158461522225 (128.347% change)
#     iteration    3: trace = 9.952470626532733 (25.5028% change)
#     iteration    4: trace = 8.972125477574334 (10.3605% change)
#     iteration    5: trace = 8.61679453546969 (4.0404% change)
#     iteration    6: trace = 8.472483862037196 (1.6889% change)
#     iteration    7: trace = 8.400527629982056 (0.852915% change)
#     iteration    8: trace = 8.3568826225933 (0.520904% change)
#     iteration    9: trace = 8.324322618166509 (0.39038% change)
#     iteration   10: trace = 8.304612687595807 (0.237056% change)
#     iteration   11: trace = 8.295231126715585 (0.113032% change)
#     iteration   12: trace = 8.291019421202495 (0.0507855% change)
#     iteration   13: trace = 8.289033234095083 (0.0239588% change)
#     iteration   14: trace = 8.288094276331734 (0.0113284% change)
#     iteration   15: trace = 8.287696113663261 (0.00480415% change)
#     iteration   16: trace = 8.287545990717526 (0.00181141% change)
#     iteration   17: trace = 8.287489215847826 (0.000685065% change)
#     iteration   18: trace = 8.287466153591483 (0.000278278% change)
#     iteration   19: trace = 8.287456160241311 (0.000120584% change)
#     iteration   20: trace = 8.287451795213798 (5.26703e-05% change)
#     iteration   21: trace = 8.287449947191808 (2.2299e-05% change)
#     iteration   22: trace = 8.287449277268248 (8.08359e-06% change)
# Finished solving for bands 1 to 10 after 22 iterations.
# freqs:, 1, 0, 0.5, 0.5, 1, 0.660962, 0.678353, 0.786592, 0.796641, 0.964515, 0.97143, 0.999989, 1.02122, 1.05091, 1.05632
# elapsed time for k point: 0.6734657287597656
# solve_kpoint (0,0.53125,0.46875):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.303840618667619 (0.389447% change)
#     iteration    2: trace = 8.286480986194695 (0.209274% change)
#     iteration    3: trace = 8.277579618835158 (0.107478% change)
#     iteration    4: trace = 8.273220816232229 (0.0526718% change)
#     iteration    5: trace = 8.271653249568585 (0.0189493% change)
#     iteration    6: trace = 8.270830550582046 (0.0099465% change)
#     iteration    7: trace = 8.270257739289764 (0.00692592% change)
#     iteration    8: trace = 8.269955721531492 (0.00365192% change)
#     iteration    9: trace = 8.269833588693199 (0.00147684% change)
#     iteration   10: trace = 8.269796696155568 (0.000446111% change)
#     iteration   11: trace = 8.269784298608359 (0.000149914% change)
#     iteration   12: trace = 8.269778407764726 (7.12334e-05% change)
#     iteration   13: trace = 8.269775771350398 (3.18801e-05% change)
#     iteration   14: trace = 8.269774766308423 (1.21532e-05% change)
#     iteration   15: trace = 8.269774331155606 (5.26197e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 2, 0, 0.53125, 0.46875, 1.0039, 0.661824, 0.680756, 0.789005, 0.798666, 0.941104, 0.962446, 0.998946, 1.02259, 1.05324, 1.06915
# elapsed time for k point: 0.424666166305542
# solve_kpoint (0,0.5625,0.4375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.259942066597469 (0.326878% change)
#     iteration    2: trace = 8.247490440949809 (0.150861% change)
#     iteration    3: trace = 8.241329630528929 (0.0747271% change)
#     iteration    4: trace = 8.23756515434407 (0.0456885% change)
#     iteration    5: trace = 8.235774548780476 (0.0217394% change)
#     iteration    6: trace = 8.234790851127057 (0.0119449% change)
#     iteration    7: trace = 8.234288482957451 (0.00610074% change)
#     iteration    8: trace = 8.234100907420645 (0.00227801% change)
#     iteration    9: trace = 8.234031212317458 (0.000846424% change)
#     iteration   10: trace = 8.234006701928843 (0.000297672% change)
#     iteration   11: trace = 8.233997094017411 (0.000116686% change)
#     iteration   12: trace = 8.233992651075907 (5.39585e-05% change)
#     iteration   13: trace = 8.233990823252702 (2.21985e-05% change)
#     iteration   14: trace = 8.233990057450354 (9.3005e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 3, 0, 0.5625, 0.4375, 1.0155, 0.663792, 0.687507, 0.796126, 0.804698, 0.898615, 0.9309, 1.00261, 1.02737, 1.05969, 1.08703
# elapsed time for k point: 0.40900683403015137
# solve_kpoint (0,0.59375,0.40625):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.228322779426039 (0.2592% change)
#     iteration    2: trace = 8.220346596281896 (0.0969827% change)
#     iteration    3: trace = 8.217091449227111 (0.0396065% change)
#     iteration    4: trace = 8.215088774356106 (0.024375% change)
#     iteration    5: trace = 8.214156170677548 (0.011353% change)
#     iteration    6: trace = 8.213762802958628 (0.00478901% change)
#     iteration    7: trace = 8.213610194965646 (0.00185797% change)
#     iteration    8: trace = 8.213561949175702 (0.00058739% change)
#     iteration    9: trace = 8.213544419113687 (0.000213428% change)
#     iteration   10: trace = 8.213537733624579 (8.13959e-05% change)
#     iteration   11: trace = 8.213535335576744 (2.91963e-05% change)
#     iteration   12: trace = 8.213534421550198 (1.11283e-05% change)
#     iteration   13: trace = 8.213534085846042 (4.08721e-06% change)
# Finished solving for bands 1 to 10 after 13 iterations.
# freqs:, 4, 0, 0.59375, 0.40625, 1.03456, 0.664623, 0.696765, 0.807602, 0.814609, 0.851724, 0.893688, 1.00955, 1.03563, 1.07005, 1.09986
# elapsed time for k point: 0.49427008628845215
# solve_kpoint (0,0.625,0.375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.241592854673172 (0.224765% change)
#     iteration    2: trace = 8.235847868509124 (0.0697315% change)
#     iteration    3: trace = 8.234129961365792 (0.0208611% change)
#     iteration    4: trace = 8.233266178768035 (0.0104908% change)
#     iteration    5: trace = 8.232893927832034 (0.00452141% change)
#     iteration    6: trace = 8.23274779362349 (0.00177502% change)
#     iteration    7: trace = 8.232691325841706 (0.000685895% change)
#     iteration    8: trace = 8.232674432049595 (0.000205204% change)
#     iteration    9: trace = 8.232669196785213 (6.35913e-05% change)
#     iteration   10: trace = 8.232667441036902 (2.13266e-05% change)
#     iteration   11: trace = 8.23266687083346 (6.92611e-06% change)
# Finished solving for bands 1 to 10 after 11 iterations.
# freqs:, 5, 0, 0.625, 0.375, 1.06066, 0.659545, 0.702271, 0.809619, 0.822828, 0.828653, 0.861451, 1.01892, 1.04705, 1.08382, 1.11086
# elapsed time for k point: 0.36524462699890137
# solve_kpoint (0,0.59375,0.28125):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.378418566854302 (0.899877% change)
#     iteration    2: trace = 8.359458942650031 (0.226548% change)
#     iteration    3: trace = 8.355612293038631 (0.0460261% change)
#     iteration    4: trace = 8.354172602806878 (0.0172317% change)
#     iteration    5: trace = 8.353615831211833 (0.00666482% change)
#     iteration    6: trace = 8.35341040008805 (0.00245922% change)
#     iteration    7: trace = 8.353328887555449 (0.000975804% change)
#     iteration    8: trace = 8.353299774439993 (0.000348522% change)
#     iteration    9: trace = 8.353289824423541 (0.000119115% change)
#     iteration   10: trace = 8.353286259231769 (4.26801e-05% change)
#     iteration   11: trace = 8.353285213669386 (1.25168e-05% change)
#     iteration   12: trace = 8.353284870043591 (4.11366e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 6, 0, 0.59375, 0.28125, 0.980274, 0.633506, 0.670771, 0.771282, 0.793286, 0.879847, 0.902665, 1.03335, 1.06518, 1.10257, 1.12731
# elapsed time for k point: 0.34005284309387207
# solve_kpoint (0,0.5625,0.1875):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.644134682959114 (1.05495% change)
#     iteration    2: trace = 8.617397604718477 (0.309788% change)
#     iteration    3: trace = 8.609244563919324 (0.0946562% change)
#     iteration    4: trace = 8.604512687433779 (0.0549778% change)
#     iteration    5: trace = 8.602168735290419 (0.0272447% change)
#     iteration    6: trace = 8.600963724369267 (0.0140092% change)
#     iteration    7: trace = 8.600314046040637 (0.00755384% change)
#     iteration    8: trace = 8.600041038719478 (0.00317444% change)
#     iteration    9: trace = 8.599934898336471 (0.00123419% change)
#     iteration   10: trace = 8.599894346587945 (0.000471537% change)
#     iteration   11: trace = 8.599878803684998 (0.000180734% change)
#     iteration   12: trace = 8.599871746988901 (8.20558e-05% change)
#     iteration   13: trace = 8.599868951190789 (3.25098e-05% change)
#     iteration   14: trace = 8.599867880288603 (1.24525e-05% change)
#     iteration   15: trace = 8.599867381694851 (5.79769e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 7, 0, 0.5625, 0.1875, 0.918559, 0.600899, 0.626906, 0.739514, 0.750905, 0.949343, 0.970276, 1.05385, 1.09458, 1.1257, 1.14737
# elapsed time for k point: 0.4458003044128418
# solve_kpoint (0,0.53125,0.09375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.948577537894694 (1.38182% change)
#     iteration    2: trace = 8.899733418361961 (0.547325% change)
#     iteration    3: trace = 8.874557489388501 (0.283285% change)
#     iteration    4: trace = 8.856283052378558 (0.206132% change)
#     iteration    5: trace = 8.847804603122164 (0.0957796% change)
#     iteration    6: trace = 8.843216991144505 (0.0518637% change)
#     iteration    7: trace = 8.840607036257808 (0.029518% change)
#     iteration    8: trace = 8.839326528589648 (0.0144854% change)
#     iteration    9: trace = 8.838639455999413 (0.00777321% change)
#     iteration   10: trace = 8.838261991335532 (0.00427071% change)
#     iteration   11: trace = 8.838026749206188 (0.00266167% change)
#     iteration   12: trace = 8.837863440698328 (0.00184781% change)
#     iteration   13: trace = 8.837758090663028 (0.00119204% change)
#     iteration   14: trace = 8.837686148602002 (0.000814034% change)
#     iteration   15: trace = 8.837647527412681 (0.000437007% change)
#     iteration   16: trace = 8.837632682750735 (0.000167971% change)
#     iteration   17: trace = 8.837626886154325 (6.55899e-05% change)
#     iteration   18: trace = 8.837624353575032 (2.86568e-05% change)
#     iteration   19: trace = 8.837623163530395 (1.34657e-05% change)
#     iteration   20: trace = 8.837622542077945 (7.0319e-06% change)
# Finished solving for bands 1 to 10 after 20 iterations.
# freqs:, 8, 0, 0.53125, 0.09375, 0.879453, 0.57725, 0.596281, 0.71694, 0.725032, 1.01468, 1.0192, 1.07446, 1.12282, 1.13342, 1.15802
# elapsed time for k point: 0.582974910736084
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 10...
#     iteration    1: trace = 9.047446902179111 (1.68968% change)
#     iteration    2: trace = 8.979634993907968 (0.752334% change)
#     iteration    3: trace = 8.943359602807538 (0.404792% change)
#     iteration    4: trace = 8.922095679262833 (0.238045% change)
#     iteration    5: trace = 8.91535141000681 (0.0756192% change)
#     iteration    6: trace = 8.912360410511498 (0.0335545% change)
#     iteration    7: trace = 8.910443333914984 (0.0215126% change)
#     iteration    8: trace = 8.909031213687618 (0.0158492% change)
#     iteration    9: trace = 8.907929761319778 (0.0123641% change)
#     iteration   10: trace = 8.907289500624072 (0.00718779% change)
#     iteration   11: trace = 8.906958307436939 (0.0037183% change)
#     iteration   12: trace = 8.90679675019021 (0.00181385% change)
#     iteration   13: trace = 8.906727955418054 (0.000772388% change)
#     iteration   14: trace = 8.906694149917978 (0.000379551% change)
#     iteration   15: trace = 8.906676373295946 (0.000199587% change)
#     iteration   16: trace = 8.906667588159308 (9.86355e-05% change)
#     iteration   17: trace = 8.906662769923889 (5.4097e-05% change)
#     iteration   18: trace = 8.906660163545219 (2.92633e-05% change)
#     iteration   19: trace = 8.906658760077466 (1.57575e-05% change)
#     iteration   20: trace = 8.906657981748058 (8.73874e-06% change)
# Finished solving for bands 1 to 10 after 20 iterations.
# freqs:, 9, 0, 0.5, 0, 0.866025, 0.56857, 0.58565, 0.708015, 0.717172, 1.03652, 1.06571, 1.08274, 1.0885, 1.14304, 1.16231
# elapsed time for k point: 0.6255214214324951
# solve_kpoint (0,0.375,0):
# Solving for bands 1 to 10...
#     iteration    1: trace = 9.071863929755295 (1.34329% change)
#     iteration    2: trace = 9.039544184466884 (0.356899% change)
#     iteration    3: trace = 9.030698287094559 (0.0979057% change)
#     iteration    4: trace = 9.026298962642528 (0.0487271% change)
#     iteration    5: trace = 9.024414256912019 (0.0208823% change)
#     iteration    6: trace = 9.023612411860363 (0.00888568% change)
#     iteration    7: trace = 9.023238943989787 (0.00413887% change)
#     iteration    8: trace = 9.023085743975553 (0.00169785% change)
#     iteration    9: trace = 9.023012351518329 (0.000813389% change)
#     iteration   10: trace = 9.022972043272869 (0.000446728% change)
#     iteration   11: trace = 9.022950243442015 (0.000241604% change)
#     iteration   12: trace = 9.022936998511806 (0.000146792% change)
#     iteration   13: trace = 9.022930271182794 (7.45581e-05% change)
#     iteration   14: trace = 9.022927493678495 (3.07827e-05% change)
#     iteration   15: trace = 9.022926269021445 (1.35727e-05% change)
#     iteration   16: trace = 9.022925722966731 (6.05186e-06% change)
# Finished solving for bands 1 to 10 after 16 iterations.
# freqs:, 10, 0, 0.375, 0, 0.649519, 0.471069, 0.48299, 0.797116, 0.810474, 1.04133, 1.07261, 1.08449, 1.08971, 1.14664, 1.16715
# elapsed time for k point: 0.43998193740844727
# solve_kpoint (0,0.25,0):
# Solving for bands 1 to 10...
#     iteration    1: trace = 9.410887984560043 (1.34189% change)
#     iteration    2: trace = 9.37485349521603 (0.383637% change)
#     iteration    3: trace = 9.364295169746017 (0.112687% change)
#     iteration    4: trace = 9.359438870395538 (0.0518732% change)
#     iteration    5: trace = 9.357476297637163 (0.0209711% change)
#     iteration    6: trace = 9.356548484462017 (0.0099157% change)
#     iteration    7: trace = 9.356060601212093 (0.00521449% change)
#     iteration    8: trace = 9.355805621493987 (0.00272533% change)
#     iteration    9: trace = 9.355626018814247 (0.00191971% change)
#     iteration   10: trace = 9.355506342780695 (0.0012792% change)
#     iteration   11: trace = 9.355437461237768 (0.00073627% change)
#     iteration   12: trace = 9.355393596494018 (0.00046887% change)
#     iteration   13: trace = 9.355371925538361 (0.000231642% change)
#     iteration   14: trace = 9.355362331467457 (0.000102552% change)
#     iteration   15: trace = 9.355357657707225 (4.99581e-05% change)
#     iteration   16: trace = 9.355355533692032 (2.27037e-05% change)
#     iteration   17: trace = 9.355354622553589 (9.73922e-06% change)
# Finished solving for bands 1 to 10 after 17 iterations.
# freqs:, 11, 0, 0.25, 0, 0.433013, 0.3208, 0.328408, 0.921836, 0.936997, 1.05537, 1.08772, 1.09657, 1.09748, 1.15237, 1.17687
# elapsed time for k point: 0.4577908515930176
# solve_kpoint (0,0.125,0):
# Solving for bands 1 to 10...
#     iteration    1: trace = 9.923495495189645 (1.4147% change)
#     iteration    2: trace = 9.875670118073336 (0.483105% change)
#     iteration    3: trace = 9.857981673405039 (0.179272% change)
#     iteration    4: trace = 9.848361122164814 (0.0976391% change)
#     iteration    5: trace = 9.843539172438502 (0.0489739% change)
#     iteration    6: trace = 9.840133057861664 (0.0346085% change)
#     iteration    7: trace = 9.837367103514248 (0.0281129% change)
#     iteration    8: trace = 9.835101024846233 (0.0230381% change)
#     iteration    9: trace = 9.833196903017182 (0.0193623% change)
#     iteration   10: trace = 9.832104508303642 (0.0111099% change)
#     iteration   11: trace = 9.831571043490223 (0.00542589% change)
#     iteration   12: trace = 9.831289437044042 (0.00286435% change)
#     iteration   13: trace = 9.831145551266605 (0.00146356% change)
#     iteration   14: trace = 9.831058364255686 (0.000886849% change)
#     iteration   15: trace = 9.831006033578499 (0.000532301% change)
#     iteration   16: trace = 9.830973499755649 (0.000330931% change)
#     iteration   17: trace = 9.830950632441823 (0.000232605% change)
#     iteration   18: trace = 9.830936534267368 (0.000143406% change)
#     iteration   19: trace = 9.830928657795781 (8.01193e-05% change)
#     iteration   20: trace = 9.830923798635862 (4.94273e-05% change)
#     iteration   21: trace = 9.830920626171231 (3.22703e-05% change)
#     iteration   22: trace = 9.830918538450378 (2.12363e-05% change)
#     iteration   23: trace = 9.830917104298699 (1.45882e-05% change)
#     iteration   24: trace = 9.830916353054425 (7.64165e-06% change)
# Finished solving for bands 1 to 10 after 24 iterations.
# freqs:, 12, 0, 0.125, 0, 0.216506, 0.161878, 0.165621, 1.03522, 1.04901, 1.07829, 1.1036, 1.11205, 1.13206, 1.14722, 1.17906
# elapsed time for k point: 0.654564619064331
# solve_kpoint (0,0,0):
# Solving for bands 3 to 10...
#     iteration    1: trace = 10.53125640979529 (6.52685% change)
#     iteration    2: trace = 10.37342825300554 (1.50998% change)
#     iteration    3: trace = 10.3179222021469 (0.536515% change)
#     iteration    4: trace = 10.27439353727314 (0.422766% change)
#     iteration    5: trace = 10.24680923542583 (0.268837% change)
#     iteration    6: trace = 10.22700603456804 (0.193449% change)
#     iteration    7: trace = 10.21632404544856 (0.104503% change)
#     iteration    8: trace = 10.21049657780017 (0.057057% change)
#     iteration    9: trace = 10.20653031924145 (0.0388525% change)
#     iteration   10: trace = 10.20407813821991 (0.0240285% change)
#     iteration   11: trace = 10.20252727576056 (0.0151996% change)
#     iteration   12: trace = 10.20130571762089 (0.0119738% change)
#     iteration   13: trace = 10.20035445000704 (0.00932539% change)
#     iteration   14: trace = 10.19977422365552 (0.00568846% change)
#     iteration   15: trace = 10.19948582155302 (0.00282757% change)
#     iteration   16: trace = 10.19928083644978 (0.00200978% change)
#     iteration   17: trace = 10.19910445536639 (0.00172936% change)
#     iteration   18: trace = 10.19898580374269 (0.00116336% change)
#     iteration   19: trace = 10.19890568370936 (0.000785572% change)
#     iteration   20: trace = 10.19884325682403 (0.000612096% change)
#     iteration   21: trace = 10.19879430443228 (0.000479981% change)
#     iteration   22: trace = 10.19874888080407 (0.000445383% change)
#     iteration   23: trace = 10.19871034740837 (0.000377825% change)
#     iteration   24: trace = 10.19867915020294 (0.000305894% change)
#     iteration   25: trace = 10.19865248224892 (0.000261485% change)
#     iteration   26: trace = 10.19863234301478 (0.00019747% change)
#     iteration   27: trace = 10.19862003505653 (0.000120683% change)
#     iteration   28: trace = 10.19861090586409 (8.9514e-05% change)
#     iteration   29: trace = 10.19860211605033 (8.61864e-05% change)
#     iteration   30: trace = 10.19859393961804 (8.01721e-05% change)
#     iteration   31: trace = 10.19858662248051 (7.17466e-05% change)
#     iteration   32: trace = 10.1985783750173 (8.08687e-05% change)
#     iteration   33: trace = 10.19856335670995 (0.000147259% change)
#     large trace change predicted (0.000404536%)
#     iteration   34: trace = 10.1985222244673 (0.000403315% change)
#     large trace change predicted (0.00237708%)
#     iteration   35: trace = 10.19831811003814 (0.00200143% change)
#     large trace change predicted (0.0110633%)
#     iteration   36: trace = 10.19793346885014 (0.00377169% change)
#     iteration   37: trace = 10.1977254880173 (0.00203946% change)
#     iteration   38: trace = 10.19752683600956 (0.00194802% change)
#     iteration   39: trace = 10.19730302335929 (0.0021948% change)
#     iteration   40: trace = 10.19705762449099 (0.00240654% change)
#     iteration   41: trace = 10.19678794309119 (0.00264473% change)
#     iteration   42: trace = 10.19647150347321 (0.00310337% change)
#     iteration   43: trace = 10.19614090111697 (0.00324237% change)
#     iteration   44: trace = 10.19583553892805 (0.00299492% change)
#     iteration   45: trace = 10.1955392200837 (0.00290632% change)
#     iteration   46: trace = 10.19526518813134 (0.0026878% change)
#     iteration   47: trace = 10.19503166989056 (0.00229048% change)
#     iteration   48: trace = 10.19482594553461 (0.00201791% change)
#     iteration   49: trace = 10.19463979450387 (0.00182595% change)
#     iteration   50: trace = 10.19447963213538 (0.00157106% change)
#     iteration   51: trace = 10.19434675972201 (0.00130338% change)
#     iteration   52: trace = 10.19423292432281 (0.00111666% change)
#     iteration   53: trace = 10.19413060802388 (0.00100367% change)
#     iteration   54: trace = 10.19403778378718 (0.00091057% change)
#     iteration   55: trace = 10.1939544238126 (0.000817736% change)
#     iteration   56: trace = 10.19387815611743 (0.000748169% change)
#     iteration   57: trace = 10.19380449590969 (0.000722595% change)
#     iteration   58: trace = 10.19372962380467 (0.000734489% change)
#     iteration   59: trace = 10.19365225546812 (0.000758983% change)
#     iteration   60: trace = 10.19357303471149 (0.000777161% change)
#     iteration   61: trace = 10.19349229296169 (0.000792088% change)
#     iteration   62: trace = 10.19340893067664 (0.000817802% change)
#     iteration   63: trace = 10.19332154889256 (0.000857242% change)
#     iteration   64: trace = 10.19323039804358 (0.000894225% change)
#     iteration   65: trace = 10.19313806017881 (0.000905879% change)
#     iteration   66: trace = 10.19304798847575 (0.000883654% change)
#     iteration   67: trace = 10.19296243863817 (0.000839299% change)
#     iteration   68: trace = 10.19288188442839 (0.000790296% change)
#     iteration   69: trace = 10.19280594717581 (0.000745006% change)
#     resetting CG direction...
#     large trace change predicted (0.0113469%)
#     iteration   70: trace = 10.19164931865245 (0.0113481% change)
#     iteration   71: trace = 10.19058769824649 (0.0104171% change)
#     iteration   72: trace = 10.19003777882366 (0.00539649% change)
#     iteration   73: trace = 10.18967752522599 (0.00353541% change)
#     iteration   74: trace = 10.18940294111999 (0.00269476% change)
#     iteration   75: trace = 10.18922918995696 (0.00170523% change)
#     iteration   76: trace = 10.18913068825452 (0.000966728% change)
#     iteration   77: trace = 10.1890636245618 (0.000658191% change)
#     iteration   78: trace = 10.1890054213523 (0.000571234% change)
#     iteration   79: trace = 10.18896007523593 (0.00044505% change)
#     iteration   80: trace = 10.18890765712661 (0.000514461% change)
#     iteration   81: trace = 10.1888734660154 (0.000335572% change)
#     iteration   82: trace = 10.18885925073214 (0.000139518% change)
#     iteration   83: trace = 10.18884944790296 (9.62113e-05% change)
#     iteration   84: trace = 10.18884163740485 (7.66573e-05% change)
#     iteration   85: trace = 10.18883618086063 (5.35541e-05% change)
#     iteration   86: trace = 10.1888333469593 (2.78138e-05% change)
#     iteration   87: trace = 10.18883192805605 (1.39261e-05% change)
#     iteration   88: trace = 10.18883096240742 (9.47752e-06% change)
# Finished solving for bands 3 to 10 after 88 iterations.
# freqs:, 13, 0, 0, 0, 0, 0, 0, 1.09131, 1.09131, 1.11227, 1.13015, 1.13237, 1.13237, 1.1679, 1.1679
# elapsed time for k point: 1.9583539962768555
# solve_kpoint (0,0.125,0.125):
# Solving for bands 1 to 10...
#     iteration    1: trace = 10.18769718312085 (3.63807% change)
#     iteration    2: trace = 9.98231561974811 (2.0365% change)
#     iteration    3: trace = 9.87321379244792 (1.09896% change)
#     iteration    4: trace = 9.821666157595354 (0.523462% change)
#     iteration    5: trace = 9.79974858443499 (0.223405% change)
#     iteration    6: trace = 9.784841891399793 (0.152229% change)
#     iteration    7: trace = 9.775123975939506 (0.0993654% change)
#     iteration    8: trace = 9.767956353960788 (0.073352% change)
#     iteration    9: trace = 9.762409442078411 (0.0568029% change)
#     iteration   10: trace = 9.759127463356398 (0.0336242% change)
#     iteration   11: trace = 9.757185457931669 (0.0199014% change)
#     iteration   12: trace = 9.755866601570474 (0.0135177% change)
#     iteration   13: trace = 9.754509717652903 (0.0139094% change)
#     large trace change predicted (0.0290386%)
#     iteration   14: trace = 9.751714367812379 (0.0286611% change)
#     large trace change predicted (0.101359%)
#     iteration   15: trace = 9.744596115303489 (0.0730215% change)
#     iteration   16: trace = 9.73653488310064 (0.0827594% change)
#     iteration   17: trace = 9.727740683211046 (0.0903625% change)
#     iteration   18: trace = 9.714318868264129 (0.13807% change)
#     iteration   19: trace = 9.696679712739865 (0.181744% change)
#     iteration   20: trace = 9.678489061549374 (0.187773% change)
#     iteration   21: trace = 9.665097408816724 (0.138461% change)
#     iteration   22: trace = 9.658248507915969 (0.0708873% change)
#     iteration   23: trace = 9.654188241729823 (0.0420482% change)
#     iteration   24: trace = 9.650998197295658 (0.0330486% change)
#     iteration   25: trace = 9.648762904143108 (0.0231639% change)
#     iteration   26: trace = 9.64725740085067 (0.0156043% change)
#     iteration   27: trace = 9.646265173567386 (0.0102856% change)
#     iteration   28: trace = 9.645664969494778 (0.00622233% change)
#     iteration   29: trace = 9.645330237653935 (0.00347034% change)
#     iteration   30: trace = 9.645156990834742 (0.00179619% change)
#     iteration   31: trace = 9.645061598756035 (0.00098902% change)
#     iteration   32: trace = 9.645003437948422 (0.000603013% change)
#     iteration   33: trace = 9.644963787819984 (0.000411096% change)
#     iteration   34: trace = 9.644935814920988 (0.000290026% change)
#     iteration   35: trace = 9.644916606108415 (0.00019916% change)
#     iteration   36: trace = 9.644904148939199 (0.000129158% change)
#     iteration   37: trace = 9.644896030708617 (8.41712e-05% change)
#     iteration   38: trace = 9.644890823770554 (5.39865e-05% change)
#     iteration   39: trace = 9.644887979445 (2.94905e-05% change)
#     iteration   40: trace = 9.644886495845324 (1.53822e-05% change)
#     iteration   41: trace = 9.644885681475893 (8.44354e-06% change)
# Finished solving for bands 1 to 10 after 41 iterations.
# freqs:, 14, 0, 0.125, 0.125, 0.25, 0.18799, 0.191231, 1.05399, 1.05549, 1.0713, 1.07943, 1.08221, 1.11399, 1.14023, 1.15017
# elapsed time for k point: 1.1638903617858887
# solve_kpoint (0,0.25,0.25):
# Solving for bands 1 to 10...
#     iteration    1: trace = 9.014703090999557 (2.44562% change)
#     iteration    2: trace = 8.941623169167595 (0.813974% change)
#     iteration    3: trace = 8.923695767041863 (0.200695% change)
#     iteration    4: trace = 8.917708791021292 (0.0671133% change)
#     iteration    5: trace = 8.916351938186509 (0.0152164% change)
#     iteration    6: trace = 8.916025177205018 (0.00366481% change)
#     iteration    7: trace = 8.915918138062327 (0.00120053% change)
#     iteration    8: trace = 8.915883690837829 (0.000386357% change)
#     iteration    9: trace = 8.915872256942436 (0.000128242% change)
#     iteration   10: trace = 8.915867930520225 (4.8525e-05% change)
#     iteration   11: trace = 8.915866673108564 (1.41031e-05% change)
#     iteration   12: trace = 8.915866278330169 (4.42782e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 15, 0, 0.25, 0.25, 0.5, 0.372393, 0.3791, 0.974799, 0.992453, 1.00987, 1.01632, 1.0404, 1.07032, 1.0904, 1.1084
# elapsed time for k point: 0.3035542964935303
# solve_kpoint (0,0.375,0.375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.533190964390549 (2.48177% change)
#     iteration    2: trace = 8.470207432883628 (0.740835% change)
#     iteration    3: trace = 8.456611485335628 (0.160644% change)
#     iteration    4: trace = 8.452368069198505 (0.0501913% change)
#     iteration    5: trace = 8.451390066654378 (0.0115714% change)
#     iteration    6: trace = 8.451165104746361 (0.00266187% change)
#     iteration    7: trace = 8.451090691566828 (0.000880512% change)
#     iteration    8: trace = 8.451063119934549 (0.00032625% change)
#     iteration    9: trace = 8.451053179536967 (0.000117623% change)
#     iteration   10: trace = 8.451049288009184 (4.60479e-05% change)
#     iteration   11: trace = 8.451048068669394 (1.44283e-05% change)
#     iteration   12: trace = 8.451047611556481 (5.40895e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 16, 0, 0.375, 0.375, 0.75, 0.546234, 0.557147, 0.874508, 0.890885, 0.97618, 0.983215, 1.01089, 1.03448, 1.05939, 1.0723
# elapsed time for k point: 0.40946507453918457
# solve_kpoint (0,0.5,0.5):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.364011501380761 (2.68792% change)
#     iteration    2: trace = 8.303365720341954 (0.727718% change)
#     iteration    3: trace = 8.292187916042369 (0.134708% change)
#     iteration    4: trace = 8.288961641036916 (0.038915% change)
#     iteration    5: trace = 8.288036175119453 (0.0111657% change)
#     iteration    6: trace = 8.28769495955996 (0.00411705% change)
#     iteration    7: trace = 8.287532028812192 (0.00196595% change)
#     iteration    8: trace = 8.287475969332588 (0.000676434% change)
#     iteration    9: trace = 8.287460878871634 (0.000182088% change)
#     iteration   10: trace = 8.287455392827907 (6.61969e-05% change)
#     iteration   11: trace = 8.287452504929091 (3.48466e-05% change)
#     iteration   12: trace = 8.287450352906561 (2.59672e-05% change)
#     iteration   13: trace = 8.287449264658189 (1.31313e-05% change)
#     iteration   14: trace = 8.287448966507569 (3.59762e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 17, 0, 0.5, 0.5, 1, 0.660962, 0.678353, 0.786592, 0.796641, 0.964515, 0.97143, 0.999989, 1.02122, 1.05091, 1.05632
# elapsed time for k point: 0.4468507766723633
# solve_kpoint (0.0625,0.5625,0.5):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.317104684228109 (0.72508% change)
#     iteration    2: trace = 8.282766660417662 (0.413714% change)
#     iteration    3: trace = 8.267484010228328 (0.184682% change)
#     iteration    4: trace = 8.261415125985838 (0.0734336% change)
#     iteration    5: trace = 8.259689567386555 (0.0208891% change)
#     iteration    6: trace = 8.259078419316976 (0.00739944% change)
#     iteration    7: trace = 8.25873437168632 (0.00416578% change)
#     iteration    8: trace = 8.258501830183027 (0.00281574% change)
#     iteration    9: trace = 8.258364890794986 (0.00165818% change)
#     iteration   10: trace = 8.258314390223989 (0.00061151% change)
#     iteration   11: trace = 8.258297574941141 (0.000203617% change)
#     iteration   12: trace = 8.258290021402331 (9.14661e-05% change)
#     iteration   13: trace = 8.258286337747665 (4.46055e-05% change)
#     iteration   14: trace = 8.258284735921631 (1.93966e-05% change)
#     iteration   15: trace = 8.258284095860889 (7.75053e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 18, 0.0625, 0.5625, 0.5, 1.00778, 0.664237, 0.681737, 0.790997, 0.800952, 0.938676, 0.94991, 0.988423, 1.00696, 1.06988, 1.07985
# elapsed time for k point: 0.4751746654510498
# solve_kpoint (0.125,0.625,0.5):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.275251095726681 (0.464467% change)
#     iteration    2: trace = 8.261160094078205 (0.170424% change)
#     iteration    3: trace = 8.25705050459835 (0.0497583% change)
#     iteration    4: trace = 8.255638061037841 (0.0171074% change)
#     iteration    5: trace = 8.25520059104069 (0.00529919% change)
#     iteration    6: trace = 8.255012075077934 (0.00228363% change)
#     iteration    7: trace = 8.254871850344633 (0.00169868% change)
#     iteration    8: trace = 8.254765869812493 (0.00128386% change)
#     iteration    9: trace = 8.25470852510024 (0.000694689% change)
#     iteration   10: trace = 8.254689493098343 (0.00023056% change)
#     iteration   11: trace = 8.254684283900257 (6.31059e-05% change)
#     iteration   12: trace = 8.254682407680024 (2.27292e-05% change)
#     iteration   13: trace = 8.254681538566849 (1.05287e-05% change)
#     iteration   14: trace = 8.254681073329142 (5.63605e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 19, 0.125, 0.625, 0.5, 1.03078, 0.672984, 0.69069, 0.803385, 0.812788, 0.902392, 0.913653, 0.954872, 0.971204, 1.11612, 1.12643
# elapsed time for k point: 0.39069390296936035
# solve_kpoint (0.1875,0.6875,0.5):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.353925775489207 (0.352686% change)
#     iteration    2: trace = 8.345253697106816 (0.103862% change)
#     iteration    3: trace = 8.343188721932657 (0.0247474% change)
#     iteration    4: trace = 8.342516662379852 (0.00805551% change)
#     iteration    5: trace = 8.342261093484293 (0.0030635% change)
#     iteration    6: trace = 8.342114855200375 (0.001753% change)
#     iteration    7: trace = 8.341997529126699 (0.00140644% change)
#     iteration    8: trace = 8.341927820160887 (0.000835642% change)
#     iteration    9: trace = 8.341898577259387 (0.000350554% change)
#     iteration   10: trace = 8.341888111029528 (0.000125466% change)
#     iteration   11: trace = 8.341883852980324 (5.10442e-05% change)
#     iteration   12: trace = 8.34188132542579 (3.02996e-05% change)
#     iteration   13: trace = 8.3418797754682 (1.85804e-05% change)
#     iteration   14: trace = 8.34187895087652 (9.88496e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 20, 0.1875, 0.6875, 0.5, 1.068, 0.683255, 0.701145, 0.820019, 0.82704, 0.877163, 0.886751, 0.92123, 0.934788, 1.16774, 1.17693
# elapsed time for k point: 0.5164530277252197
# solve_kpoint (0.25,0.75,0.5):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.541277183934449 (0.341467% change)
#     iteration    2: trace = 8.532063484419675 (0.107931% change)
#     iteration    3: trace = 8.529039582791794 (0.0354479% change)
#     iteration    4: trace = 8.527069263586695 (0.023104% change)
#     iteration    5: trace = 8.524955935415834 (0.0247868% change)
#     iteration    6: trace = 8.521446104021964 (0.0411797% change)
#     iteration    7: trace = 8.515947995533422 (0.0645417% change)
#     iteration    8: trace = 8.511211020185016 (0.0556402% change)
#     iteration    9: trace = 8.508397514611435 (0.0330619% change)
#     iteration   10: trace = 8.506984437615492 (0.0166094% change)
#     iteration   11: trace = 8.506163074810328 (0.00965562% change)
#     iteration   12: trace = 8.50556932067706 (0.00698053% change)
#     iteration   13: trace = 8.505140847348926 (0.00503769% change)
#     iteration   14: trace = 8.504885217792516 (0.00300563% change)
#     iteration   15: trace = 8.504767127702145 (0.00138851% change)
#     iteration   16: trace = 8.504717683420326 (0.000581373% change)
#     iteration   17: trace = 8.504688305294644 (0.000345434% change)
#     iteration   18: trace = 8.504663786589253 (0.000288297% change)
#     iteration   19: trace = 8.504644096890157 (0.000231517% change)
#     iteration   20: trace = 8.504628282010993 (0.000185956% change)
#     iteration   21: trace = 8.504614357235845 (0.000163732% change)
#     iteration   22: trace = 8.504603593114904 (0.000126568% change)
#     iteration   23: trace = 8.504594626972203 (0.000105427% change)
#     iteration   24: trace = 8.504585470597528 (0.000107664% change)
#     iteration   25: trace = 8.504576146322238 (0.000109638% change)
#     iteration   26: trace = 8.50456831635853 (9.20677e-05% change)
#     iteration   27: trace = 8.504563481118851 (5.68546e-05% change)
#     iteration   28: trace = 8.504560896042598 (3.03963e-05% change)
#     iteration   29: trace = 8.504559582149419 (1.54493e-05% change)
#     iteration   30: trace = 8.504558893780658 (8.09411e-06% change)
# Finished solving for bands 1 to 10 after 30 iterations.
# freqs:, 21, 0.25, 0.75, 0.5, 1.11803, 0.688238, 0.706107, 0.828946, 0.833193, 0.871758, 0.877362, 0.908123, 0.913014, 1.21213, 1.22216
# elapsed time for k point: 0.7810063362121582
# solve_kpoint (0.28125,0.75,0.46875):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.539406742962552 (0.366917% change)
#     iteration    2: trace = 8.517443169085002 (0.257534% change)
#     iteration    3: trace = 8.490117089356451 (0.32134% change)
#     iteration    4: trace = 8.455449576530405 (0.409163% change)
#     iteration    5: trace = 8.435136524262639 (0.240525% change)
#     iteration    6: trace = 8.426904763704222 (0.0976366% change)
#     iteration    7: trace = 8.424067295089028 (0.0336772% change)
#     iteration    8: trace = 8.423086401187648 (0.0116446% change)
#     iteration    9: trace = 8.4226025372159 (0.00574466% change)
#     iteration   10: trace = 8.422305635374425 (0.00352512% change)
#     iteration   11: trace = 8.422079479755791 (0.00268523% change)
#     iteration   12: trace = 8.421910297833916 (0.00200881% change)
#     iteration   13: trace = 8.421819429785106 (0.00107895% change)
#     iteration   14: trace = 8.421779851558913 (0.00046995% change)
#     iteration   15: trace = 8.421761236074307 (0.00022104% change)
#     iteration   16: trace = 8.421750521737474 (0.000127222% change)
#     iteration   17: trace = 8.421743025623254 (8.9009e-05% change)
#     iteration   18: trace = 8.421738542150617 (5.32369e-05% change)
#     iteration   19: trace = 8.4217365755402 (2.33516e-05% change)
#     iteration   20: trace = 8.421735648423816 (1.10086e-05% change)
#     iteration   21: trace = 8.421735079594864 (6.7543e-06% change)
# Finished solving for bands 1 to 10 after 21 iterations.
# freqs:, 22, 0.28125, 0.75, 0.46875, 1.0933, 0.689593, 0.69898, 0.820395, 0.832048, 0.862168, 0.89185, 0.903748, 0.938471, 1.18652, 1.20342
# elapsed time for k point: 0.601686954498291
# solve_kpoint (0.3125,0.75,0.4375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.341260157699907 (0.262763% change)
#     iteration    2: trace = 8.332709942913382 (0.102558% change)
#     iteration    3: trace = 8.328536133537705 (0.050102% change)
#     iteration    4: trace = 8.325382107437907 (0.0378773% change)
#     iteration    5: trace = 8.323762353208949 (0.0194575% change)
#     iteration    6: trace = 8.323099232749419 (0.00796691% change)
#     iteration    7: trace = 8.322867095361024 (0.00278911% change)
#     iteration    8: trace = 8.322790528777656 (0.000919959% change)
#     iteration    9: trace = 8.322756918384105 (0.000403836% change)
#     iteration   10: trace = 8.322739825141484 (0.00020538% change)
#     iteration   11: trace = 8.322731093154724 (0.000104917% change)
#     iteration   12: trace = 8.322726639317407 (5.35141e-05% change)
#     iteration   13: trace = 8.322724906894226 (2.08156e-05% change)
#     iteration   14: trace = 8.322724366060848 (6.49827e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 23, 0.3125, 0.75, 0.4375, 1.07529, 0.684942, 0.692639, 0.813449, 0.826032, 0.847366, 0.881302, 0.94409, 0.977684, 1.1471, 1.17135
# elapsed time for k point: 0.3816981315612793
# solve_kpoint (0.34375,0.75,0.40625):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.266265409233231 (0.237203% change)
#     iteration    2: trace = 8.259889465308515 (0.0771619% change)
#     iteration    3: trace = 8.257785550182419 (0.0254747% change)
#     iteration    4: trace = 8.256649001768119 (0.0137643% change)
#     iteration    5: trace = 8.256127756841668 (0.00631323% change)
#     iteration    6: trace = 8.255912864365813 (0.00260286% change)
#     iteration    7: trace = 8.255833674914115 (0.000959189% change)
#     iteration    8: trace = 8.255807625573226 (0.000315527% change)
#     iteration    9: trace = 8.255797853678031 (0.000118364% change)
#     iteration   10: trace = 8.255794072595123 (4.57991e-05% change)
#     iteration   11: trace = 8.255792789824584 (1.55378e-05% change)
#     iteration   12: trace = 8.255792278845162 (6.18934e-06% change)
# Finished solving for bands 1 to 10 after 12 iterations.
# freqs:, 24, 0.34375, 0.75, 0.40625, 1.06434, 0.679575, 0.689336, 0.809812, 0.821761, 0.836807, 0.873925, 0.985848, 1.01658, 1.10735, 1.13673
# elapsed time for k point: 0.28363609313964844
# solve_kpoint (0.375,0.75,0.375):
# Solving for bands 1 to 10...
#     iteration    1: trace = 8.240187383609015 (0.222863% change)
#     iteration    2: trace = 8.234752844300694 (0.0659734% change)
#     iteration    3: trace = 8.233344195303083 (0.0171076% change)
#     iteration    4: trace = 8.232782331740635 (0.00682448% change)
#     iteration    5: trace = 8.232578107597455 (0.00248065% change)
#     iteration    6: trace = 8.232506914545814 (0.000864776% change)
#     iteration    7: trace = 8.232482785996783 (0.000293089% change)
#     iteration    8: trace = 8.232475292229241 (9.10269e-05% change)
#     iteration    9: trace = 8.232472561050253 (3.31757e-05% change)
#     iteration   10: trace = 8.232471387588568 (1.42541e-05% change)
#     iteration   11: trace = 8.232470980495165 (4.94497e-06% change)
# Finished solving for bands 1 to 10 after 11 iterations.
# freqs:, 25, 0.375, 0.75, 0.375, 1.06066, 0.677498, 0.688231, 0.808752, 0.820459, 0.832811, 0.871433, 1.00918, 1.03828, 1.08401, 1.11717
# elapsed time for k point: 0.28759121894836426
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.6895932167294283 at Vector3<0.28125, 0.75, 0.46875>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.7061074776763853 at Vector3<0.25, 0.75, 0.5>
# Band 3 range: 0.708015395514216 at Vector3<0.0, 0.5, 0.0> to 1.0913102549266465 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.7171716156322654 at Vector3<0.0, 0.5, 0.0> to 1.0913103234320096 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.8286531955305442 at Vector3<0.0, 0.625, 0.375> to 1.1122747751740685 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8614505304880493 at Vector3<0.0, 0.625, 0.375> to 1.1301549126695838 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.9037477496097402 at Vector3<0.28125, 0.75, 0.46875> to 1.132372188161061 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.9130140338806277 at Vector3<0.25, 0.75, 0.5> to 1.1323722278913229 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 1.05090546962769 at Vector3<0.0, 0.5, 0.5> to 1.2121308760946854 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 1.0563192383687665 at Vector3<0.0, 0.5, 0.5> to 1.2221571431722176 at Vector3<0.25, 0.75, 0.5>
# Gap from band 2 (0.7061074776763853) to band 3 (0.708015395514216), 0.26983763207591843%
# total elapsed time for run: 13.964540004730225
# done

# %% [markdown]
# First, lets's just plot the usual MPB outputs: a dielectric slice and a unitless band structure.

# %%
## Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=4, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 10
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()


unit_cell = 600

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
nonzero_freqs = np.where(crysfreqs > 0, crysfreqs, .01)
crysfreqs_scaled = (((unit_cell/1000)/nonzero_freqs)*1000)

freqlims = np.array([.6202, .6263])
wllims = (((unit_cell/1000)/freqlims)*1000)

x = range(len(crysfreqs))
figgy = plt.figure(figsize=(7,7))
plt.plot(x,crysfreqs_scaled, color='blue');
plt.fill_between(x, wllims[1], wllims[0], color='green', alpha=.65)
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs, size=18)
plt.xlabel("Direction", size=24)

plt.ylabel('wavelength (nm)', size=24)
plt.yticks(size=18)

plt.ylim((550, 1300))
plt.xlim(0,35)

plt.grid(True)
figax = plt.gca()

plt.title(f"{unit_cell} nm Unit Cell \n FEBID n = {febid_n} | HPCVD n= {si_n} \n Diameter = {rel_diam*unit_cell:.0f} nm \n Shell Thickness = {rel_shell * (rel_diam*unit_cell/2):.0f} nm")
# plt.savefig("DiamondCoreShell-Unitless.png")

plt.figure()
plt.plot(x, crysfreqs, color='blue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## Plotting Dielectric Map ###
# ----> 2 plt.figure()
#       3 md = mpb.MPBData(rectify=True, periods=4, resolution=64)
#       4 eps = ms.get_epsilon()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
