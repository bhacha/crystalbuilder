# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif and including a core-shell structure.. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_conv = 1
a_mag = np.sqrt(.5*a_conv)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .1
rel_diam = (radius*2)/a_conv
cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# We then use the same vertices to build the shell, by passing a different value for the radius. Right now, these structures will be independent. When we convert them to MPB objects, one will overwrite the other and form the core-shell structure.

# %%
shell_radius = .045
rel_shell = (shell_radius/radius)
full_radius = shell_radius+radius
shell_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=full_radius)
shell_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=full_radius)
shell_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=full_radius)
shell_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=full_radius)

shell_cell = [shell_1, shell_2, shell_3, shell_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 2
a2_reps = 2
a3_reps = 2
core_crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )
shell_crystal = geo_lattice.tile_geogeometry(shell_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene. We want to render the core and shell in different colors, so we will use a visualize and "add to visualizer" combination.

# %%
# scene = viewer.visualize(core_crystal, c='white', res=5)
# viewer.add_to_visualizer(shell_crystal, scene, c='red', alpha=.5, res=5)
# scene.show().close()
# objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

febid_n = 2.25
si_n = 3.75

febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(unit_cell, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_cell, material=si_mat, lattice=mpb_lattice)

mpb_geometry = shell_geometry+core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(5, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 16  # use a 16x16x16 grid
mesh_size = 2
num_bands = 6

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)
ms.optimize_grid_size=True

ms.run()
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 12 x 12 x 12.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 2.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.145, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.145, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.145, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.145, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.1, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.1, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.1, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.1, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
# Geometric object tree has depth 7 and 435 object nodes (vs. 8 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 37 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.5208333333333334, 0.4791666666666667>
#   Vector3<0.0, 0.5416666666666666, 0.4583333333333333>
#   Vector3<0.0, 0.5625, 0.4375>
#   Vector3<0.0, 0.5833333333333334, 0.4166666666666667>
#   Vector3<0.0, 0.6041666666666666, 0.39583333333333337>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.6041666666666666, 0.3125>
#   Vector3<0.0, 0.5833333333333334, 0.25>
#   Vector3<0.0, 0.5625, 0.1875>
#   Vector3<0.0, 0.5416666666666666, 0.125>
#   Vector3<0.0, 0.5208333333333334, 0.0625>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.4166666666666667, 0.0>
#   Vector3<0.0, 0.33333333333333337, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.16666666666666669, 0.0>
#   Vector3<0.0, 0.08333333333333337, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.08333333333333333, 0.08333333333333333>
#   Vector3<0.0, 0.16666666666666666, 0.16666666666666666>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.3333333333333333, 0.3333333333333333>
#   Vector3<0.0, 0.41666666666666663, 0.41666666666666663>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.041666666666666664, 0.5416666666666666, 0.5>
#   Vector3<0.08333333333333333, 0.5833333333333334, 0.5>
#   Vector3<0.125, 0.625, 0.5>
#   Vector3<0.16666666666666666, 0.6666666666666666, 0.5>
#   Vector3<0.20833333333333331, 0.7083333333333333, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.2708333333333333, 0.75, 0.4791666666666667>
#   Vector3<0.2916666666666667, 0.75, 0.4583333333333333>
#   Vector3<0.3125, 0.75, 0.4375>
#   Vector3<0.3333333333333333, 0.75, 0.4166666666666667>
#   Vector3<0.35416666666666663, 0.75, 0.39583333333333337>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.06587696075439453
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6
# Solving for bands 1 to 6...
#     near maximum in trace
#     linmin: converged after 10 iterations.
#     iteration    1: trace = 12.3209769400733 (188.849% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 3.233960963271378 (116.838% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 2.563504246982282 (23.1293% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.310657540712778 (10.375% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.212556267752653 (4.33768% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.164741602279364 (2.18467% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 2.14179948144169 (1.06545% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 2.130790939585894 (0.51531% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.124833103470006 (0.279998% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.121171134695827 (0.17249% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.118722166907903 (0.11552% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.117010699616707 (0.0808109% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.115741885499987 (0.0599522% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 2.114759765666692 (0.0464304% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 2.114102390093997 (0.03109% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 2.113649437233063 (0.0214276% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 2.113288948843032 (0.0170567% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 2.112974469954373 (0.0148821% change)
#     linmin: converged after 4 iterations.
#     iteration   19: trace = 2.112709832087535 (0.0125252% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 2.112507420397273 (0.00958113% change)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 2.112352949146068 (0.00731249% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 2.112233358270741 (0.00566166% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 2.112141682662918 (0.00434032% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 2.112080021039518 (0.00291943% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 2.112043024554205 (0.00175168% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 2.112022127828872 (0.000989413% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 2.112010304958004 (0.000559791% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 2.112003416155252 (0.000326173% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 2.111999305792218 (0.000194619% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace =
-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.118516574150921 (8.85028e-06% change)
# Finished solving for bands 1 to 6 after 21 iterations.
# freqs:, 15, 0, 0.333333, 0, 0.57735, 0.31688, 0.31851, 0.613147, 0.638037, 0.738286, 0.767169
# elapsed time for k point: 0.5259349346160889
# solve_kpoint (0,0.25,0):
# Solving for bands 1 to 6...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.206724867459478 (1.28752% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 2.201799752538324 (0.223436% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 2.200713669354725 (0.0493392% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.200119737921344 (0.0269918% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 2.199847735429199 (0.0123638% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 2.199688553533832 (0.0072363% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 2.199576271868425 (0.00510456% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.199490042276611 (0.00392036% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.199409774923172 (0.00364943% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.199350703855254 (0.00268581% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.199313087749996 (0.00171034% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.199287128305134 (0.00118035% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.199271198267105 (0.00072433% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.199259001402934 (0.000554588% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.199251108764201 (0.000358878% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 2.199246121787185 (0.000226758% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 2.199242936983257 (0.000144814% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60.4163%)
#     iteration   18: trace = 2.199241404377639 (6.96879e-05% change)
#     switching back to exact line minimization
#     iteration   19: trace = 2.199240590410401 (3.70113e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.199240147605455 (2.01344e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.199239878165613 (1.22515e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.199239723427866 (7.03597e-06% change)
# Finished solving for bands 1 to 6 after 22 iterations.
# freqs:, 16, 0, 0.25, 0, 0.433013, 0.242187, 0.243162, 0.668296, 0.691138, 0.747512, 0.773559
# elapsed time for k point: 0.682194709777832
# solve_kpoint (0,0.166667,0):
# Solving for bands 1 to 6...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 2.316853241587269 (1.27176% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 2.310949617074439 (0.255137% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 2.309027893487944 (0.0831919% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 2.307661804253365 (0.0591805% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 2.306988679724796 (0.0291734% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.306467934783911 (0.022575% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.306080907261921 (0.0167815% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 2.305747104220103 (0.014476% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 2.30539871187715 (0.0151109% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 2.305115855482684 (0.0122701% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 2.30490049211503 (0.00934328% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 2.304735226933551 (0.00717042% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 2.304612102903377 (0.00534236% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 2.304517769080754 (0.00409335% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.304466163228469 (0.00223936% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 2.304434524943606 (0.00137292% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 2.30441297309783 (0.000935238% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.304396826801483 (0.000700671% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.304384022029999 (0.000555668% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.304374206027801 (0.000425972% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.30436330980437 (0.000472851% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.304346284713161 (0.000738822% change)
#     large trace change predicted (0.00210851%)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 2.304297888281452 (0.00210025% change)
#     large trace change predicted (0.122956%)
#     linmin: converged after 6 iterations.
#     iteration   24: trace = 2.303919244372609 (0.0164334% change)
#     linmin: converged after 6 iterations.
#     iteration   25: trace = 2.30370740065675 (0.00919535% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 2.303566503298124 (0.0061163% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 2.303450193083189 (0.00504926% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 2.303343461882003 (0.00463364% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 2.303237307812153 (0.0046088% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 2.303125864166231 (0.00483868% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 2.30300650240315 (0.00518273% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 2.302879757063223 (0.00550362% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 2.302747433541931 (0.00574617% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 2.302609058331095 (0.00600932% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 2.302459922795467 (0.00647702% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 2.302293835940877 (0.00721371% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 2.302109438865602 (0.0080096% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 2.301912965574052 (0.00853485% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 2.301711173572047 (0.00876666% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 2.301505428241712 (0.0089392% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 2.3012970290248 (0.00905532% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 2.30109151316087 (0.00893084% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 2.300893001346377 (0.00862723% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 2.300699019709818 (0.00843107% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 2.300503114646484 (0.00851539% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 2.300300426789143 (0.00881098% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 2.300090806199839 (0.00911316% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 2.29987738462451 (0.00927926% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 2.299662723186841 (0.00933404% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 2.299446597471298 (0.00939859% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 2.299226710049651 (0.00956308% change)
#     linmin: converged after 4 iterations.
#     iteration   52: trace = 2.299000911107211 (0.00982113% change)
#     linmin: converged after 4 iterations.
#     iteration   53: trace = 2.298769005712398 (0.0100877% change)
#     linmin: converged after 4 iterations.
#     iteration   54: trace = 2.29853270633642 (0.0102799% change)
#     linmin: converged after 4 iterations.
#     iteration   55: trace = 2.298293846994909 (0.0103924% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 70.9182%)
#     iteration   56: trace = 2.298052747788732 (0.0104909% change)
#     iteration   57: trace = 2.297820250614738 (0.0101177% change)
#     iteration   58: trace = 2.297479857044642 (0.0148149% change)
#     iteration   59: trace = 2.297119764741644 (0.0156746% change)
# ...
# elapsed time for k point: 1.3639023303985596
# solve_kpoint (0.25,0.75,0.5):
# Solving for bands 1 to 6...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.062393018289087 (0.37339% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.060031439045512 (0.114572% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2.058418589219124 (0.0783231% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 2.056669996064742 (0.0849845% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.055402414595616 (0.0616517% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.054638323370292 (0.0371817% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.054208957351078 (0.0208996% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.054064478123103 (0.00703357% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.053992849750324 (0.00348721% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.053950615372881 (0.00205623% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.053924558916155 (0.00126861% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.053909120810308 (0.000751642% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.053901539079269 (0.000369137% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.053897040809801 (0.000219011% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.053893632693282 (0.000165934% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 2.053891430660278 (0.000107213% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 2.053890149738253 (6.23656e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.053889662087924 (2.37428e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.053889502231771 (7.78309e-06% change)
# Finished solving for bands 1 to 6 after 19 iterations.
# freqs:, 31, 0.25, 0.75, 0.5, 1.11803, 0.49084, 0.507233, 0.60289, 0.603542, 0.639858, 0.646934
# elapsed time for k point: 1.090266227722168
# solve_kpoint (0.270833,0.75,0.479167):
# Solving for bands 1 to 6...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.057574325104706 (0.255688% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.056151899821473 (0.0691551% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 57.817%)
#     iteration    3: trace = 2.05555999576012 (0.0287911% change)
#     switching back to exact line minimization
#     iteration    4: trace = 2.055062246256613 (0.0242177% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 2.054771275376632 (0.0141597% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 2.054591953612985 (0.00872747% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 2.054477229085802 (0.00558397% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 2.054430036260497 (0.0022971% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 2.054404555167998 (0.00124031% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 2.0543828305688 (0.00105747% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 2.054353558579455 (0.00142487% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 2.054320176043007 (0.00162498% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 2.054295945772302 (0.00117949% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 2.054280619002695 (0.000746087% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 2.054269900733538 (0.000521754% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 88.7628%)
#     iteration   16: trace = 2.05426073358456 (0.00044625% change)
#     switching back to exact line minimization
#     iteration   17: trace = 2.054253064541474 (0.000373324% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 2.054248449136357 (0.000224676% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 2.054245714674701 (0.000133113% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 2.054243811140568 (9.26635e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 2.054242354670152 (7.09006e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 2.054241415770297 (4.57054e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 2.054240965373296 (2.19252e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 2.054240770963681 (9.46382e-06% change)
# Finished solving for bands 1 to 6 after 24 iterations.
# freqs:, 32, 0.270833, 0.75, 0.479167, 1.10082, 0.487661, 0.508715, 0.597129, 0.603389, 0.634245, 0.659339
# elapsed time for k point: 1.3082513809204102
# solve_kpoint (0.291667,0.75,0.458333):
# Solving for bands 1 to 6...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 2.057930652065126 (0.242682% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 2.056518744397456 (0.0686317% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 2
-05% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 1.982986345886912 (3.81563e-06% change)
# Finished solving for bands 1 to 6 after 11 iterations.
# freqs:, 36, 0.354167, 0.75, 0.395833, 1.0623, 0.472571, 0.507778, 0.58358, 0.600723, 0.614264, 0.650439
# elapsed time for k point: 0.39539480209350586
# solve_kpoint (0.375,0.75,0.375):
# Solving for bands 1 to 6...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 1.979907282545497 (0.171023% change)
#     linmin: converged after 2 iterations.
#     iteration    2: trace = 1.979273704350197 (0.0320055% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 1.979081407118959 (0.00971602% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 1.979014458624918 (0.00338286% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 1.978991468845886 (0.00116168% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 1.978985316237509 (0.000310897% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 1.97898302473357 (0.000115792% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 1.978982228023953 (4.02585e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 1.978982012276534 (1.09019e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 1.978981937699544 (3.76845e-06% change)
# Finished solving for bands 1 to 6 after 10 iterations.
# freqs:, 37, 0.375, 0.75, 0.375, 1.06066, 0.471775, 0.507604, 0.582986, 0.600781, 0.613113, 0.649638
# elapsed time for k point: 0.4415254592895508
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.490839755185678 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5090878246351898 at Vector3<0.2916666666666667, 0.75, 0.4583333333333333>
# Band 3 range: 0.5248663337673438 at Vector3<0.0, 0.5, 0.0> to 0.7713992480753821 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5567934141648387 at Vector3<0.0, 0.5, 0.0> to 0.7804974017678029 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.6131133708612634 at Vector3<0.375, 0.75, 0.375> to 0.7805370148298295 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6362451255899673 at Vector3<0.0, 0.625, 0.375> to 0.786492564218838 at Vector3<0.0, 0.0, 0.0>
# Gap from band 2 (0.5090878246351898) to band 3 (0.5248663337673438), 3.0520713135932387%
# total elapsed time for run: 29.847820281982422
# done

# %%
### Plotting Dielectric Map ###
# plt.figure()
# md = mpb.MPBData(rectify=True, periods=7, resolution=64)
# eps = ms.get_epsilon()
# converted_eps = md.convert(eps)
# layer_slice = 22
# plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
# plt.axis('off')
# plt.show()

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
print(ms.all_freqs)
nonzero_freqs = np.where(crysfreqs > .2, crysfreqs, 3)
crysfreqs_scaled = ((.5/nonzero_freqs)*1000)
x = range(len(crysfreqs))
figgy = plt.figure(figsize=(7,7))
plt.plot(x,crysfreqs_scaled[::-1], color='blue');
plt.fill_between(x, .51, .5245, color='green', alpha=.65)
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs, size=18)
plt.xlabel("Direction", size=24)

plt.ylabel('wavelength, nm', size=24)
plt.yticks(size=18)

# plt.ylim((0,.75))

plt.grid(True)
figax = plt.gca()
plt.title(f"FEBID n = {febid_n} | HPCVD n= {si_n} \n Diameter = {rel_diam:.0%} of supercell $\it a $ \n Shell Thickness = {rel_shell:.0%} of FEBID diameter")
# plt.savefig("DiamondCoreShell-Unitless.png")
# Out:
# [[0.47107998 0.49120496 0.58192002 0.5972448  0.68105423 0.69973456]
#  [0.47188181 0.49139813 0.58244355 0.5978351  0.67937818 0.69482426]
#  [0.47421397 0.49188714 0.58400576 0.59959667 0.67416362 0.68164379]
