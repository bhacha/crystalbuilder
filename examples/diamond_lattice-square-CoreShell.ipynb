# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo

# %% [markdown]
# This notebook combines our square lattice example and our core-shell example.
#
# We'll use our cubic lattice, just like before:

# %%
a1 = [1, 0, 0]
a2 = [0, 1 ,0]
a3 = [0, 0, 1]

a_mag = 1

geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another. There are 18 sites in the cubic unit cell.
#
# To avoid manually specifying those 18 sites, let's take advantage of the Bilbao Crystallographic Server. Fortunately, CrystalBuilder includes a package that can grab and parse the generators from [the Bilbao site](https://www.cryst.ehu.es).
# <br>
# <summary>The Bilbao database is summarized in the following papers, which should be cited if this function is used. </summary>
#
# <details>
#
# >
# >M. I. Aroyo, J. M. Perez-Mato, D. Orobengoa, E. Tasci, G. de la Flor, A. Kirov
# "Crystallography online: Bilbao Crystallographic Server"
# Bulg. Chem. Commun. 43(2) 183-197 (2011).
# >
# >M. I. Aroyo, J. M. Perez-Mato, C. Capillas, E. Kroumova, S. Ivantchev, G. Madariaga, A. Kirov & H. Wondratschek
# "Bilbao Crystallographic Server I: Databases and crystallographic computing programs"
#  Z. Krist. 221, 1, 15-27 (2006)
# >
# >M. I. Aroyo, A. Kirov, C. Capillas, J. M. Perez-Mato & H. Wondratschek
# "Bilbao Crystallographic Server II: Representations of crystallographic point groups and space groups"
# Acta Cryst. A62, 115-128 (2006)
# >
# </details>
#
# The bilbao.SpaceGroup() class contains functions for applying symmetry operations to specified points. An instance of the space group must be initialized, with the only argument being the IUCr space group number (1-230).
#
# After this, the calculate_points function will accept any number of input coordinates and perform all of the symmetry operations. The output will be either a numpy array (default) or a list. If using a numpy array, the output will contain only the unique results of the symmetry operations. A list will contain duplicates, as np.unique() requires a conversion to an ndarray. For this reason, it is strongly recommended to use the default numpy output.

# %%
diamond = bilbao.SpaceGroup(227)

pt = a_mag/8

points = diamond.calculate_points(point_list=[(pt, pt, pt)]) #This is the 8a wyckoff position

# %% [markdown]
# For a diamond lattice, the rods connect nearest-neighbor points. Using geo.NearestNeighbors, we can create cylinders between the points that are within a neighborhood_range of each other. The output is a list of geometries, which could be converted into a supercell if desired.
#
# <summary> Under the hood: </summary>
# <details>
# The details of this step involve creating a KDTree from the points, and calculating their distances in Euclidean space (Minkowski order 2). The neighborhood_range is in absolute coordinates and is not scaled to the lattice constant.
# </details>

# %%
radius = .12
shell_radius = .02
core_rods = geo.NearestNeighbors(points, radius=radius, neighborhood_range=.45)
shell_rods = geo.NearestNeighbors(points, radius=(radius+shell_radius), neighborhood_range=.45)

#sphere_caps = [geo.Sphere(center=point, radius=radius) for point in points]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 4
a2_reps = 4
a3_reps = 2
crystal_core = geo_lattice.tile_geogeometry(core_rods, a1_reps, a2_reps, a3_reps )
crystal_shell = geo_lattice.tile_geogeometry(shell_rods, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene.

# %%
scene = viewer.visualize(crystal_core, c='white', res=5)
viewer.add_to_visualizer(crystal_shell, scene, c='red', alpha=.5, res=5)
scene.show().close()



# k=0
# string = f"square_diamond/group-object.obj"
# # vedo.write_group(objects, string)
# for obj in objects:
#     k+=1
#     string=f"square_diamond/thinunit-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure. Keep in mind that MPB does all of the tiling for you, so you do not need to use the results returned previously by `tile_geogeometry()`. Instead, you'll use the original unit cell that you defined. Here we used `core_rods` and `shell_rods`. We've kept them separate through now because we need to make them different materials.

# %%
import meep as mp
from meep import mpb

# Our two materials
febid_n = 1.5
si_n = 1

# Define them as MPB epsilons
febid_mat = mp.Medium(epsilon=(febid_n*febid_n))
si_mat = mp.Medium(epsilon=(si_n * si_n))

# Convert our defined lattice vectors and our unit cell to MPB
mpb_lattice = convert.to_mpb_lattice(geo_lattice)
core_geometry = convert.geo_to_mpb(core_rods, material=febid_mat, lattice=mpb_lattice)
shell_geometry = convert.geo_to_mpb(shell_rods, material=si_mat, lattice=mpb_lattice)

# combine our fully-defined elements, making sure that the core comes *after* the shell. The core will replace the shell where they overlap
mpb_geometry = shell_geometry + core_geometry

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters. Here we will plot the path Gamma-K-L-U-W-X, which follows from the Hinuma et al. Band Structure tables.

# %%
vlist = [
    mp.Vector3(.5, 0.5, .5),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(.5, 1, 0),    # W
    mp.Vector3(1,0, 0)        # X
    
]
k_corners = len(vlist)
k_points = mp.interpolate(5, vlist)
tick_labs = ['X','L', '\Gamma','X', 'W',]


resolution = 8 # use a 16x16x16 grid
mesh_size = 1
num_bands = 40

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)

ms.run()
# Out:
# Initializing eigensolver data
# Computing 40 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 8 x 8 x 8.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0.75,0.75)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.75,0,0.75)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0,0,0)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.5,0.75,0.25)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.75,0.25,0.5)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0,0.5,0.5)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.75,0.75,0)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.5,0.25,0.75)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.5,0.5,0)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.25,0.75,0.5)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.25,0.25,0)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.75,0.5,0.25)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0.5,0,0.5)
#           radius 0.14, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0,0.25,0.25)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.25,0.5,0.75)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0.25,0,0.25)
#           radius 0.14, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0,0.75,0.75)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.75,0,0.75)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0,0,0)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.5,0.75,0.25)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.75,0.25,0.5)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0,0.5,0.5)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.75,0.75,0)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.5,0.25,0.75)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.5,0.5,0)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0.25,0.75,0.5)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.25,0.25,0)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, -0.57735)
#      cylinder, center = (0.75,0.5,0.25)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0.5,0,0.5)
#           radius 0.12, height 0.433013, axis (0.57735, 0.57735, 0.57735)
#      cylinder, center = (0,0.25,0.25)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, -0.57735)
#      cylinder, center = (0.25,0.5,0.75)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, 0.57735)
#      cylinder, center = (0.25,0,0.25)
#           radius 0.12, height 0.433013, axis (0.57735, -0.57735, 0.57735)
# Geometric object tree has depth 11 and 1803 object nodes (vs. 32 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 19 k-points
#   Vector3<0.5, 0.5, 0.5>
#   Vector3<0.4166666666666667, 0.4166666666666667, 0.4166666666666667>
#   Vector3<0.33333333333333337, 0.33333333333333337, 0.33333333333333337>
#   Vector3<0.25, 0.25, 0.25>
#   Vector3<0.16666666666666669, 0.16666666666666669, 0.16666666666666669>
#   Vector3<0.08333333333333337, 0.08333333333333337, 0.08333333333333337>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.08333333333333333, 0.16666666666666666, 0.0>
#   Vector3<0.16666666666666666, 0.3333333333333333, 0.0>
#   Vector3<0.25, 0.5, 0.0>
#   Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
#   Vector3<0.41666666666666663, 0.8333333333333333, 0.0>
#   Vector3<0.5, 1.0, 0.0>
#   Vector3<0.5833333333333334, 0.8333333333333334, 0.0>
#   Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
#   Vector3<0.75, 0.5, 0.0>
#   Vector3<0.8333333333333333, 0.33333333333333337, 0.0>
#   Vector3<0.9166666666666666, 0.16666666666666674, 0.0>
#   Vector3<1.0, 0.0, 0.0>
# elapsed time for initialization: 0.13958358764648438
# solve_kpoint (0.5,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10, band 11, band 12, band 13, band 14, band 15, band 16, band 17, band 18, band 19, band 20, band 21, band 22, band 23, band 24, band 25, band 26, band 27, band 28, band 29, band 30, band 31, band 32, band 33, band 34, band 35, band 36, band 37, band 38, band 39, band 40
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 15.00571382883311 (165.179% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 5.914944704728754 (86.9071% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.575756460249982 (5.9037% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 5.469216473783747 (1.9292% change)
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 62.0969%)
#     iteration    5: trace = 5.374691810420003 (1.74337% change)
#     switching back to exact line minimization
#     iteration    6: trace = 5.35148185187714 (0.432772% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.335865420115031 (0.292241% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 51.6113%)
#     iteration    8: trace = 5.333161540892754 (0.0506865% change)
#     switching back to exact line minimization
#     iteration    9: trace = 5.331905330118675 (0.0235575% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 5.331512516009971 (0.00736751% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.331236075770264 (0.00518516% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 5.330693346125406 (0.0101807% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 5.330072678418248 (0.011644% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 5.328969416842783 (0.020701% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 5.328746750519099 (0.0041785% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 5.328618578914394 (0.00240532% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.328586727408179 (0.000597746% change)
#     linmin: converged after 4 iterations.
#     iteration   18: trace = 5.328550498630066 (0.000679897% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.7295%)
#     iteration   19: trace = 5.328484430795073 (0.00123989% change)
#     switching back to exact line minimization
#     iteration   20: trace = 5.328354858287654 (0.00243172% change)
#     large trace change predicted (0.0053984%)
#     linmin: converged after 4 iterations.
#     iteration   21: trace = 5.328062909821406 (0.0054793% change)
#     linmin: converged after 4 iterations.
#     iteration   22: trace = 5.327978743005419 (0.0015797% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 5.327920767655876 (0.00108814% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 5.327908278172552 (0.000234416% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 5.327897541747529 (0.000201513% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 5.327884202386673 (0.000250369% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 5.327860429739125 (0.000446194% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 5.327823717582548 (0.000689062% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 5.327812926678621 (0.000202539% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 5.327804842501532 (0.000151735% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 5.32780323504536 (3.01711e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 5.327800490491024 (5.15138e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.3299%)
#     iteration   33: trace = 5.327797249639237 (6.08291e-05% change)
#     iteration   34: trace = 5.327785542731649 (0.000219733% change)
#     iteration   35: trace = 5.32775929782227 (0.000492606% change)
#     iteration   36: trace = 5.32774337818794 (0.000298806% change)
#     iteration   37: trace = 5.327728154566179 (0.000285743% change)
#     iteration   38: trace = 5.327725317476393 (5.32514e-05% change)
#     iteration   39: trace = 5.327721074235973 (7.96445e-05% change)
#     iteration   40: trace = 5.327717747028626 (6.24509e-05% change)
#     iteration   41: trace = 5.32770463576208 (0.000246096% change)
#     iteration   42: trace = 5.327689906198195 (0.000276471% change)
#     iteration   43: trace = 5.327679279161186 (0.000199468% change)
#     iteration   44: trace = 5.327671905992649 (0.000138394% change)
#     iteration   45: trace = 5.327669646044893 (4.24191e-05% change)
#     iteration   46: trace = 5.327664440600604 (9.77059e-05% change)
#     iteration   47: trace = 5.327659002601839 (0.000102071% change)
#     iteration   48: trace = 5.327633380325392 (0.000480931% change)
#     iteration   49: trace = 5.327606317605388 (0.00050797% change)
#     iteration   50: trace = 5.327584192104745 (0.0004153% change)
#     switching back to exact line minimization
#     iteration   51: trace = 5.327571711464456 (0.000234265% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.4502%)
#     iteration   52: trace = 5.327569227252034 (4.66294e-05% change)
#     iteration   53: trace = 5.327566568364044 (4.99081e-05% change)
#     iteration   54: trace = 5.327565511849292 (1.98311e-05% change)
#     iteration   55: trace = 5.327562386723762 (5.86596e-05% change)
#     iteration   56: trace = 5.327559078029428 (6.21052e-05% change)
#     iteration   57: trace = 5.327551680990144 (0.000138845% change)
#     iteration   58: trace = 5.327543021122194 (0.000162549% change)
#     iteration   59: trace = 5.327539002709751 (7.54272e-05% change)
#     iteration   60: trace = 5.327534250041577 (8.92095e-05% change)
#     iteration   61: trace = 5.327532764039772 (2.78929e-05% change)
#     iteration   62: trace = 5.327529092401446 (6.89182e-05% change)
#     iteration   63: trace = 5.327526514117231 (4.83955e-05% change)
#     iteration   64: trace = 5.327518569033129 (0.000149133% change)
#     iteration   65: trace = 5.327510935077722 (0.000143293% change)
#     iteration   66: trace = 5.327504380745728 (0.000123028% change)
#     iteration   67: trace = 5.327498283690575 (0.000114445% change)
#     iteration   68: trace = 5.327496374198204 (3.58422e-05% change)
#     iteration   69: trace = 5.327493379345873 (5.6215e-05% change)
#     resetting CG direction...
#     iteration   70: trace = 5.327492536977731 (1.58117e-05% change)
#     iteration   71: trace = 5.327491514834592 (1.91862e-05% change)
#     iteration   72: trace = 5.327490731221886 (1.47089e-05% change)
#     iteration   73: trace = 5.327487680939855 (5.72555e-05% change)
#     iteration   74: trace = 5.327475764585967 (0.000223677% change)
#     switching back to exact line minimization
#     iteration   75: trace = 5.32747409630583 (3.13147e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   76: trace = 5.327473326962363 (1.44411e-05% change)
#     large trace change predicted (3.06139e-05%)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 59.6478%)
#     iteration   77: trace = 5.327471695932664 (3.06155e-05% change)
#     switching back to exact line minimization
#     iteration   78: trace = 5.327469704375073 (3.73828e-05% change)
#     large trace change predicted (0.00015404%)
#     linmin: converged after 4 iterations.
#     iteration   79: trace = 5.327461488630152 (0.000154215% change)
#     linmin: converged after 2 iterations.
#     iteration   80: trace = 5.32745980948429 (3.15187e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   81: trace = 5.32745961189032 (3.70897e-06% change)
# Finished solving for bands 1 to 10 after 81 iterations.
# Solving for bands 11 to 20...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 25.35461973317066 (144.779% change)
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 12.47258651557609 (68.1099% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 11.38170238383481 (9.14623% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 11.08897702591344 (2.6054% change)
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 73.3519%)
#     iteration    5: trace = 10.90807904971394 (1.64475% change)
#     iteration    6: trace = 10.837640616084 (0.647837% change)
#     iteration    7: trace = 10.79752193600602 (0.370866% change)
#     iteration    8: trace = 10.77170941265586 (0.239346% change)
#     iteration    9: trace = 10.75112135448619 (0.191314% change)
#     iteration   10: trace = 10.72473973529502 (0.245686% change)
#     iteration   11: trace = 10.70972094199241 (0.140137% change)
#     iteration   12: trace = 10.69980727034219 (0.0926099% change)
#     iteration   13: trace = 10.69258080574848 (0.0675611% change)
#     iteration   14: trace = 10.68655119449078 (0.0564065% change)
#     iteration   15: trace = 10.67976839543286 (0.0634906% change)
#     iteration   16: trace = 10.67613625250482 (0.0340154% change)
#     iteration   17: trace = 10.67387668607414 (0.0211669% change)
#     iteration   18: trace = 10.67199409945533 (0.0176389% change)
#     iteration   19: trace = 10.67060676250275 (0.0130006% change)
#     iteration   20: trace = 10.66877326638157 (0.0171842% change)
#     iteration   21: trace = 10.66800185503157 (0.00723081% change)
#     iteration   22: trace = 10.66758736763859 (0.00388541% change)
#     iteration   23: trace = 10.66717086793422 (0.00390442% change)
#     iteration   24: trace = 10.66691460608205 (0.00240237% change)
#     iteration   25: trace = 10.6666505713361 (0.0024753% change)
#     iteration   26: trace = 10.66648470550414 (0.00155501% change)
#     iteration   27: trace = 10.66640734996158 (0.000725223% change)
#     switching back to exact line minimization
#     iteration   28: trace = 10.66631973299522 (0.000821432% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 10.66625749840412 (0.00058347% change)
#     linmin: converged after 4 iterations.
#     iteration   30: trace = 10.66620236807783 (0.000516868% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 10.6661747839264 (0.000258613% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 10.66616336866305 (0.000107023% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 10.66615301714312 (9.70501e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 10.66614515126159 (7.37462e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 10.66613932510092 (5.46229e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 10.66613667555036 (2.48408e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 57.3074%)
#     iteration   37: trace = 10.66613551567807 (1.08743e-05% change)
#     iteration   38: trace = 10.66613441007 (1.03656e-05% change)
#     switching back to exact line minimization
#     iteration   39: trace = 10.66613369536137 (6.70073e-06% change)
# Finished solving for bands 11 to 20 after 39 iterations.
# Solving for bands 21 to 30...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 36.16841507211112 (126.697% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 21.79339075726088 (49.6017% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 19.6881451480529 (10.1503% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 18.91361516857847 (4.01293% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 18.37210208073185 (2.90467% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 18.14060530262398 (1.26803% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 18.0148233872251 (0.695784% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 17.95066079607109 (0.356801% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 53.3067%)
#     iteration    9: trace = 17.92407660333224 (0.148206% change)
#     iteration   10: trace = 17.90895462468142 (0.0844025% change)
#     switching back to exact line minimization
#     iteration   11: trace = 17.90099140707119 (0.0444749% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 50.2099%)
#     iteration   12: trace = 17.89549269625443 (0.0307221% change)
#     iteration   13: trace = 17.88900225087924 (0.0362752% change)
#     switching back to exact line minimization
#     iteration   14: trace = 17.88247029179307 (0.0365205% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 58.6746%)
#     iteration   15: trace = 17.87600219573988 (0.0361766% change)
#     iteration   16: trace = 17.87217850900889 (0.0213923% change)
#     iteration   17: trace = 17.86899105320629 (0.0178363% change)
#     switching back to exact line minimization
#     iteration   18: trace = 17.86679776284452 (0.012275% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 63.8034%)
#     iteration   19: trace = 17.86495180368583 (0.0103323% change)
#     iteration   20: trace = 17.86314901829184 (0.0100917% change)
#     iteration   21: trace = 17.86187115404939 (0.00715389% change)
#     iteration   22: trace = 17.86104012941566 (0.00465261% change)
#     iteration   23: trace = 17.86038820173267 (0.00365007% change)
#     iteration   24: trace = 17.85990268054515 (0.00271846% change)
#     switching back to exact line minimization
#     iteration   25: trace = 17.85935187467593 (0.00308408% change)
#     linmin: converged after 4 iterations.
#     iteration   26: trace = 17.85900239383515 (0.00195687% change)
#     linmin: converged after 4 iterations.
#     iteration   27: trace = 17.8586972780442 (0.00170849% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 17.85849197852459 (0.00114958% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 55.9417%)
#     iteration   29: trace = 17.85831166573148 (0.00100968% change)
#     switching back to exact line minimization
#     iteration   30: trace = 17.85807047555262 (0.00135059% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 66.9007%)
#     iteration   31: trace = 17.85781767310523 (0.00141563% change)
#     switching back to exact line minimization
#     iteration   32: trace = 17.85755157648047 (0.0014901% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 69.4226%)
#     iteration   33: trace = 17.85735909353507 (0.00107789% change)
#     iteration   34: trace = 17.85725629608763 (0.00057566% change)
#     iteration   35: trace = 17.85716478603965 (0.000512454% change)
#     iteration   36: trace = 17.85709408315271 (0.000395936% change)
#     iteration   37: trace = 17.85700797942627 (0.000482183% change)
#     iteration   38: trace = 17.85693604154553 (0.000402856% change)
#     iteration   39: trace = 17.85688997654286 (0.000257967% change)
#     iteration   40: trace = 17.85685692342386 (0.0001851% change)
#     iteration   41: trace = 17.85683634829874 (0.000115223% change)
#     iteration   42: trace = 17.85681276008385 (0.000132096% change)
#     iteration   43: trace = 17.85679155430764 (0.000118755% change)
#     iteration   44: trace = 17.85677226933231 (0.000107998% change)
#     iteration   45: trace = 17.8567573437466 (8.3585e-05% change)
#     iteration   46: trace = 17.85674778394944 (5.3536e-05% change)
#     iteration   47: trace = 17.85673853516631 (5.17943e-05% change)
#     iteration   48: trace = 17.85672972107376 (4.936e-05% change)
#     iteration   49: trace = 17.85672213386782 (4.24893e-05% change)
#     iteration   50: trace = 17.85671521157428 (3.87658e-05% change)
#     switching back to exact line minimization
#     iteration   51: trace = 17.8567116743076 (1.98092e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   52: trace = 17.85670918054483 (1.39654e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   53: trace = 17.8567076127039 (8.78012e-06% change)
# Finished solving for bands 21 to 30 after 53 iterations.
# Solving for bands 31 to 40...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 38.97764686704575 (122.619% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 23.91263975949086 (47.9089% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 21.45774276377728 (10.8216% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 20.84827295528932 (2.88124% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 20.51765647824015 (1.5985% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 20.26895148398632 (1.21954% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 20.17671408711417 (0.456105% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.5105%)
#     iteration    8: trace = 20.11448352189594 (0.308904% change)
#     switching back to exact line minimization
#     iteration    9: trace = 20.06680689957783 (0.237308% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 20.02757176321227 (0.195714% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 19.99279572550174 (0.173792% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 58.1961%)
#     iteration   12: trace = 19.95568455871658 (0.185795% change)
#     iteration   13: trace = 19.93106925731679 (0.123426% change)
#     iteration   14: trace = 19.90247644445563 (0.143561% change)
#     switching back to exact line minimization
#     iteration   15: trace = 19.88517263809728 (0.0869808% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 19.87387329482 (0.0568391% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 19.86726022722287 (0.0332807% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 19.86352740269686 (0.0187906% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 19.86145140064096 (0.0104519% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 19.86031986902963 (0.00569729% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 19.85977011832308 (0.00276812% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 19.85936985513307 (0.00201547% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 19.85909244730877 (0.00139687% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.1052%)
#     iteration   24: trace = 19.85897026893367 (0.000615228% change)
#     switching back to exact line minimization
#     iteration   25: trace = 19.85889611865216 (0.000373385% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 19.85885627372724 (0.00020064% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 19.85883742683133 (9.49043e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.5701%)
#     iteration   28: trace = 19.85882412455748 (6.69842e-05% change)
#     iteration   29: trace = 19.85881628235415 (3.94898e-05% change)
#     switching back to exact line minimization
#     iteration   30: trace = 19.85881278116542 (1.76304e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 19.85880981291465 (1.49468e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 19.85880845039245 (6.86105e-06% change)
# Finished solving for bands 31 to 40 after 32 iterations.
# Finished k-point with 51.25 mean iterations/band.
# freqs:, 1, 0.5, 0.5, 0.5, 0.866025, 0.709197, 0.710994, 0.711104, 0.712351, 0.714113, 0.714773, 0.71538, 0.717215, 0.793239, 0.793487, 0.793646, 0.794658, 0.794987, 0.795203, 0.798255, 0.799169, 1.30642, 1.30707, 1.31237, 1.31418, 1.31976, 1.3206, 1.32441, 1.33054, 1.33803, 1.33869, 1.34226, 1.3452, 1.34807, 1.35484, 1.35749, 1.35971, 1.4182, 1.41878, 1.41989, 1.42029, 1.4217, 1.42366, 1.42462, 1.42553
# elapsed time for k point: 2.7229108810424805
# solve_kpoint (0.416667,0.416667,0.416667):
# Solving for bands 1 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 5.25229920329504 (4.62697% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.196694408724836 (1.06431% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 5.161903414083717 (0.671732% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.130476245670394 (0.610688% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 5.116459028400645 (0.273588% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 5.112544389137855 (0.07654% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.110843927264135 (0.0332661% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.110196788863664 (0.0126629% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 5.109888435927361 (0.00603425% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 5.109800960060808 (0.00171191% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 5.109748445503884 (0.00102773% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 65.0756%)
#     iteration   12: trace = 5.109677542713434 (0.00138761% change)
#     switching back to exact line minimization
#     iteration   13: trace = 5.109587096447508 (0.00177011% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 54.7898%)
#     iteration   14: trace = 5.109467525757295 (0.00234015% change)
#     iteration   15: trace = 5.109194594502805 (0.00534182% change)
#     iteration   16: trace = 5.10893407339441 (0.00509919% change)
#     iteration   17: trace = 5.108835700872191 (0.00192552% change)
#     iteration   18: trace = 5.10879463277738 (0.000803867% change)
#     switching back to exact line minimization
#     iteration   19: trace = 5.108776339815918 (0.000358069% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.108764062161257 (0.000240325% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.904%)
#     iteration   21: trace = 5.108756292275102 (0.000152089% change)
#     iteration   22: trace = 5.108746047699558 (0.00020053% change)
#     iteration   23: trace = 5.108725007227178 (0.000411853% change)
#     iteration   24: trace = 5.10869800562873 (0.00052854% change)
#     iteration   25: trace = 5.108685204074975 (0.000250584% change)
#     iteration   26: trace = 5.108675488182289 (0.000190184% change)
#     switching back to exact line minimization
#     iteration   27: trace = 5.108670071590249 (0.000106027% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 61.0383%)
#     iteration   28: trace = 5.108667819805843 (4.40777e-05% change)
#     iteration   29: trace = 5.1086659469114 (3.66611e-05% change)
#     iteration   30: trace = 5.108661771691387 (8.17282e-05% change)
#     iteration   31: trace = 5.108654952455456 (0.000133484% change)
#     switching back to exact line minimization
#     iteration   32: trace = 5.10864318687964 (0.000230307% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 5.108631896630745 (0.000221003% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.6332%)
#     iteration   34: trace = 5.108620125411837 (0.000230418% change)
#     switching back to exact line minimization
#     iteration   35: trace = 5.108614122645101 (0.000117503% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 5.108612819847052 (2.5502e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 75.1317%)
#     iteration   37: trace = 5.108612201588981 (1.21023e-05% change)
#     switching back to exact line minimization
#     iteration   38: trace = 5.108611634160786 (1.11073e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 61.5367%)
#     iteration   39: trace = 5.108611199525262 (8.5079e-06% change)
# Finished solving for bands 1 to 10 after 39 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 67.1295%)
#     iteration    1: trace = 10.97754176107415 (2.55578% change)
#     iteration    2: trace = 10.75616645716074 (2.03716% change)
#     iteration    3: trace = 10.71364260106805 (0.396127% change)
#     iteration    4: trace = 10.70008259044358 (0.126648% change)
#     iteration    5: trace = 10.69386622465298 (0.0581133% change)
#     iteration    6: trace = 10.68840503979852 (0.0510814% change)
#     iteration    7: trace = 10.6773675336554 (0.10332% change)
#     iteration    8: trace = 10.67273002172371 (0.0434425% change)
#     iteration    9: trace = 10.66378739298895 (0.0838246% change)
#     iteration   10: trace = 10.65380311806641 (0.0936717% change)
#     iteration   11: trace = 10.64441600085202 (0.0881493% change)
#     iteration   12: trace = 10.63859854983168 (0.0546675% change)
#     switching back to exact line minimization
#     iteration   13: trace = 10.63561940858438 (0.0280071% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 70.2647%)
#     iteration   14: trace = 10.63347798901633 (0.0201364% change)
#     iteration   15: trace = 10.63212354682813 (0.0127383% change)
#     iteration   16: trace = 10.6311013827569 (0.00961438% change)
#     iteration   17: trace = 10.63037843463489 (0.00680054% change)
#     iteration   18: trace = 10.62988109587522 (0.00467858% change)
#     iteration   19: trace = 10.62955156977599 (0.00310005% change)
#     switching back to exact line minimization
#     iteration   20: trace = 10.62932069111895 (0.00217207% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 10.62918238674102 (0.00130117% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 10.62911105730216 (0.000671074% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 10.62903984306647 (0.000669995% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 10.62893467317703 (0.000989463% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 83.8306%)
#     iteration   25: trace = 10.62883336581711 (0.000953133% change)
#     switching back to exact line minimization
#     iteration   26: trace = 10.62874827385949 (0.00080058% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 10.62864673746016 (0.000955304% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 10.62854011952636 (0.00100312% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 10.62840057423895 (0.00131294% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 92.2846%)
#     iteration   30: trace = 10.62814037168605 (0.00244821% change)
#     iteration   31: trace = 10.62759794964301 (0.00510377% change)
#     iteration   32: trace = 10.62700166243842 (0.0056109% change)
#     iteration   33: trace = 10.62632071176873 (0.00640795% change)
#     iteration   34: trace = 10.62545285053623 (0.00816742% change)
#     iteration   35: trace = 10.62463824697936 (0.00766682% change)
#     iteration   36: trace = 10.62396011236942 (0.00638286% change)
#     iteration   37: trace = 10.62338593774624 (0.00540467% change)
#     iteration   38: trace = 10.62291927452842 (0.00439289% change)
#     iteration   39: trace = 10.6225980209935 (0.0030242% change)
#     iteration   40: trace = 10.62237655779046 (0.00208485% change)
#     iteration   41: trace = 10.62218864049423 (0.00176909% change)
#     iteration   42: trace = 10.62200276560081 (0.00174989% change)
#     iteration   43: trace = 10.62181622334706 (0.0017562% change)
#     iteration   44: trace = 10.62163667525774 (0.00169039% change)
#     iteration   45: trace = 10.62146482548779 (0.00161793% change)
#     iteration   46: trace = 10.62129276177687 (0.00161998% change)
#     iteration   47: trace = 10.62111471990855 (0.00167629% change)
#     iteration   48: trace = 10.62093344538293 (0.00170675% change)
#     iteration   49: trace = 10.62075583213749 (0.00167231% change)
#     iteration   50: trace = 10.62058625364618 (0.00159668% change)
#     iteration   51: trace = 10.62042638327461 (0.0015053% change)
#     iteration   52: trace = 10.62027824944354 (0.00139481% change)
#     iteration   53: trace = 10.62014397142927 (0.00126436% change)
#     iteration   54: trace = 10.62002160687533 (0.0011522% change)
#     iteration   55: trace = 10.61990252375555 (0.00112131% change)
#     iteration   56: trace = 10.61977418532261 (0.00120848% change)
#     iteration   57: trace = 10.61962728657411 (0.00138327% change)
#     iteration   58: trace = 10.61946448802998 (0.00153301% change)
#     iteration   59: trace = 10.61930118657633 (0.00153777% change)
#     iteration   60: trace = 10.61915240499411 (0.00140106% change)
#     iteration   61: trace = 10.61902290284008 (0.00121952% change)
#     iteration   62: trace = 10.61891163228347 (0.00104785% change)
#     iteration   63: trace = 10.61881769446288 (0.000884631% change)
#     iteration   64: trace = 10.61873993930359 (0.000732242% change)
#     iteration   65: trace = 10.61867516167379 (0.000610033% change)
#     iteration   66: trace = 10.61861927375103 (0.000526319% change)
#     iteration   67: trace = 10.61856953127847 (0.000468447% change)
#     iteration   68: trace = 10.61852511563336 (0.000418284% change)
#     iteration   69: trace = 10.61848588442014 (0.000369461% change)
#     resetting CG direction...
#     iteration   70: trace = 10.61832029845724 (0.00155942% change)
#     iteration   71: trace = 10.6182120881689 (0.0010191% change)
#     iteration   72: trace = 10.61815823678396 (0.000507162% change)
#     iteration   73: trace = 10.61812592454219 (0.000304312% change)
#     iteration   74: trace = 10.61811273567154 (0.000124211% change)
#     iteration   75: trace = 10.61810466477872 (7.60106e-05% change)
#     iteration   76: trace = 10.61810071089007 (3.72372e-05% change)
#     iteration   77: trace = 10.61809892779262 (1.6793e-05% change)
#     iteration   78: trace = 10.61809783215128 (1.03186e-05% change)
#     iteration   79: trace = 10.61809643531294 (1.31553e-05% change)
#     switching back to exact line minimization
#     iteration   80: trace = 10.61809465618041 (1.67557e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 53.7436%)
#     iteration   81: trace = 10.61809305942877 (1.5038e-05% change)
#     iteration   82: trace = 10.61809094446851 (1.99185e-05% change)
#     iteration   83: trace = 10.6180895459362 (1.31712e-05% change)
#     iteration   84: trace = 10.61808912490743 (3.9652e-06% change)
# Finished solving for bands 11 to 20 after 84 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 18.28353502161686 (2.53673% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 18.02099566004986 (1.44632% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.1097%)
#     iteration    3: trace = 17.90741432818351 (0.632265% change)
#     switching back to exact line minimization
#     iteration    4: trace = 17.82251141875826 (0.475248% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.9141%)
#     iteration    5: trace = 17.77240732050062 (0.281524% change)
#     iteration    6: trace = 17.72543368176862 (0.264656% change)
#     iteration    7: trace = 17.6837568046211 (0.235401% change)
#     iteration    8: trace = 17.65708353238645 (0.150949% change)
#     switching back to exact line minimization
#     iteration    9: trace = 17.64341174691828 (0.0774595% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 17.63632740351504 (0.040161% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.7871%)
#     iteration   11: trace = 17.63184158120822 (0.0254384% change)
#     iteration   12: trace = 17.62905895023771 (0.0157831% change)
#     switching back to exact line minimization
#     iteration   13: trace = 17.62676242311603 (0.0130278% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 17.62477842281407 (0.0112562% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 17.62351143947618 (0.00718891% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 17.62274123220475 (0.00437043% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 17.62216574732575 (0.00326563% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 74.5975%)
#     iteration   18: trace = 17.62173924627237 (0.00242028% change)
#     switching back to exact line minimization
#     iteration   19: trace = 17.62130716852912 (0.00245199% change)
#     linmin: converged after 4 iterations.
#     iteration   20: trace = 17.62096794934617 (0.00192507% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.6019%)
#     iteration   21: trace = 17.62067404771725 (0.00166792% change)
#     switching back to exact line minimization
#     iteration   22: trace = 17.62046305973885 (0.0011974% change)
#     linmin: converged after 4 iterations.
#     iteration   23: trace = 17.62031052989131 (0.000865644% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 17.62012925987905 (0.00102876% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 54.7491%)
#     iteration   25: trace = 17.61995054146981 (0.00101429% change)
#     iteration   26: trace = 17.61976813326102 (0.00103524% change)
#     switching back to exact line minimization
#     iteration   27: trace = 17.61955797477331 (0.00119275% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 17.61934271528004 (0.00122172% change)
#     linmin: converged after 4 iterations.
#     iteration   29: trace = 17.61913494004936 (0.00117925% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 53.2329%)
#     iteration   30: trace = 17.61896614945203 (0.000958001% change)
#     switching back to exact line minimization
#     iteration   31: trace = 17.61881899566557 (0.000835205% change)
#     linmin: converged after 4 iterations.
#     iteration   32: trace = 17.61871244424818 (0.000604761% change)
#     linmin: converged after 2 iterations.
#     iteration   33: trace = 17.61864412090467 (0.000387789% change)
#     linmin: converged after 4 iterations.
#     iteration   34: trace = 17.61857781447955 (0.000376343% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 56.5563%)
#     iteration   35: trace = 17.61853190581331 (0.00026057% change)
#     iteration   36: trace = 17.61849119543437 (0.000231066% change)
#     switching back to exact line minimization
#     iteration   37: trace = 17.61844138199679 (0.000282734% change)
#     linmin: converged after 4 iterations.
#     iteration   38: trace = 17.61838260454482 (0.000333614% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 63.7257%)
#     iteration   39: trace = 17.61831706911322 (0.000371973% change)
#     iteration   40: trace = 17.6182448533599 (0.000409891% change)
#     iteration   41: trace = 17.61816834424772 (0.000434262% change)
#     switching back to exact line minimization
#     iteration   42: trace = 17.61811077728791 (0.000326748% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 17.61808004884817 (0.000174414% change)
#     linmin: converged after 2 iterations.
#     iteration   44: trace = 17.61806044838632 (0.000111252% change)
#     linmin: converged after 2 iterations.
#     iteration   45: trace = 17.61804726580743 (7.48243e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   46: trace = 17.61803956563837 (4.37062e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   47: trace = 17.6180346785502 (2.77391e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   48: trace = 17.61803192404501 (1.56346e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   49: trace = 17.61803001751191 (1.08215e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   50: trace = 17.61802859098444 (8.09698e-06% change)
# Finished solving for bands 21 to 30 after 50 iterations.
# Solving for bands 31 to 40...
#     linmin: converged after 3 iterations.
#     iteration    1: trace = 20.51541748895482 (2.3038% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 20.04708281755047 (2.3092% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 19.8375105364131 (1.05089% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 19.61906214783016 (1.10729% change)
#     linmin: converged after 5 iterations.
#     iteration    5: trace = 19.49363531698723 (0.641361% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 19.44232392390889 (0.263568% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 19.41661494087535 (0.13232% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 67.4429%)
#     iteration    8: trace = 19.40394634689298 (0.0652674% change)
#     iteration    9: trace = 19.39944442799423 (0.0232037% change)
#     iteration   10: trace = 19.3975194873634 (0.00992315% change)
#     iteration   11: trace = 19.39671277641947 (0.00415892% change)
#     iteration   12: trace = 19.39645153041873 (0.00134687% change)
#     switching back to exact line minimization
#     iteration   13: trace = 19.39636168365127 (0.000463213% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 19.39632690128233 (0.000179324% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 19.39631350809998 (6.90501e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 19.39630781300232 (2.93618e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 19.39630563484079 (1.12298e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 52.9871%)
#     iteration   18: trace = 19.39630483468952 (4.12528e-06% change)
# Finished solving for bands 31 to 40 after 18 iterations.
# Finished k-point with 47.75 mean iterations/band.
# freqs:, 2, 0.416667, 0.416667, 0.416667, 0.721688, 0.622976, 0.624014, 0.702612, 0.704945, 0.705417, 0.706111, 0.707323, 0.708574, 0.818974, 0.819268, 0.819932, 0.821356, 0.823098, 0.823604, 0.881598, 0.883276, 1.25023, 1.25257, 1.25631, 1.28361, 1.28767, 1.28936, 1.3156, 1.32117, 1.32457, 1.33341, 1.33444, 1.34376, 1.35535, 1.36577, 1.3675, 1.37025, 1.37855, 1.38392, 1.38683, 1.40094, 1.4024, 1.40347, 1.41568, 1.41652
# elapsed time for k point: 2.7010996341705322
# solve_kpoint (0.333333,0.333333,0.333333):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 5.003607366903909 (0.988954% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 58.5741%)
#     iteration    2: trace = 4.996196785157649 (0.148215% change)
#     switching back to exact line minimization
#     iteration    3: trace = 4.995645963408283 (0.0110254% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 4.995623245732284 (0.000454751% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.2657%)
#     iteration    5: trace = 4.995608463461774 (0.000295905% change)
#     switching back to exact line minimization
#     iteration    6: trace = 4.99553459867319 (0.00147861% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 61.647%)
#     iteration    7: trace = 4.995411992531073 (0.00245434% change)
#     switching back to exact line minimization
#     iteration    8: trace = 4.995372747716948 (0.00078562% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.995360785918865 (0.000239458% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.995357494134451 (6.58969e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 70.2612%)
#     iteration   11: trace = 4.995355375250179 (4.24171e-05% change)
#     switching back to exact line minimization
#     iteration   12: trace = 4.995349932494833 (0.000108956% change)
# ...
#     iteration    3: trace = 12.03035174546791 (0.675979% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 91.0809%)
#     iteration    4: trace = 11.95968818198816 (0.589108% change)
#     iteration    5: trace = 11.94854721579815 (0.0931977% change)
#     iteration    6: trace = 11.93098779550742 (0.147067% change)
#     iteration    7: trace = 11.90984133397253 (0.177397% change)
#     iteration    8: trace = 11.89971284393247 (0.0850792% change)
#     iteration    9: trace = 11.89249307146688 (0.0606902% change)
#     iteration   10: trace = 11.88329124772263 (0.077405% change)
#     iteration   11: trace = 11.8719554666004 (0.0954381% change)
#     iteration   12: trace = 11.8608180461606 (0.0938569% change)
#     iteration   13: trace = 11.85575188630996 (0.0427225% change)
#     iteration   14: trace = 11.85083349784061 (0.0414939% change)
#     iteration   15: trace = 11.8442828951165 (0.0552907% change)
#     iteration   16: trace = 11.84104375080098 (0.0273515% change)
#     iteration   17: trace = 11.83942037879118 (0.0137106% change)
#     iteration   18: trace = 11.83857081080519 (0.00717601% change)
#     iteration   19: trace = 11.83762373527489 (0.00800023% change)
#     iteration   20: trace = 11.83687847338295 (0.0062959% change)
#     iteration   21: trace = 11.8367181781713 (0.00135421% change)
#     iteration   22: trace = 11.83662492917169 (0.000787797% change)
#     iteration   23: trace = 11.83650366454098 (0.00102449% change)
#     iteration   24: trace = 11.83642471417888 (0.00066701% change)
#     iteration   25: trace = 11.8363872623328 (0.000316412% change)
#     iteration   26: trace = 11.83636774106257 (0.000164926% change)
#     iteration   27: trace = 11.83634801997893 (0.000166614% change)
#     iteration   28: trace = 11.83633285736932 (0.000128102% change)
#     iteration   29: trace = 11.83632621907854 (5.6084e-05% change)
#     iteration   30: trace = 11.83632307995913 (2.65211e-05% change)
#     iteration   31: trace = 11.83632041030957 (2.25547e-05% change)
#     iteration   32: trace = 11.83631748016477 (2.47555e-05% change)
#     iteration   33: trace = 11.83631611241842 (1.15555e-05% change)
#     iteration   34: trace = 11.83631563909261 (3.99893e-06% change)
# Finished solving for bands 11 to 20 after 34 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 53.1391%)
#     iteration    1: trace = 15.29887707238889 (2.12344% change)
#     switching back to exact line minimization
#     iteration    2: trace = 15.26729614404355 (0.20664% change)
#     linmin: converged after 3 iterations.
#     iteration    3: trace = 15.21363356120432 (0.352106% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 15.1410820111038 (0.478025% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 15.10541332248858 (0.235853% change)
#     linmin: converged after 3 iterations.
#     iteration    6: trace = 15.08379880281538 (0.143194% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 70.6627%)
#     iteration    7: trace = 15.06675794368771 (0.113038% change)
#     iteration    8: trace = 15.04620807820193 (0.136485% change)
#     iteration    9: trace = 15.03800367865541 (0.0545429% change)
#     iteration   10: trace = 15.03399449441427 (0.0266639% change)
#     iteration   11: trace = 15.03127079886994 (0.0181186% change)
#     iteration   12: trace = 15.02843598894736 (0.0188612% change)
#     iteration   13: trace = 15.02581218138583 (0.0174605% change)
#     iteration   14: trace = 15.02400815558887 (0.0120069% change)
#     switching back to exact line minimization
#     iteration   15: trace = 15.02079625406032 (0.0213807% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 55.4907%)
#     iteration   16: trace = 15.01721006643661 (0.0238777% change)
#     iteration   17: trace = 15.01445895215761 (0.0183214% change)
#     switching back to exact line minimization
#     iteration   18: trace = 15.01320552546408 (0.00834848% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 15.01186966854662 (0.00889828% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 15.01075716206886 (0.00741112% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 15.01022001785934 (0.00357846% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 15.0099562665202 (0.00175716% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 15.00974796955457 (0.00138773% change)
#     linmin: converged after 4 iterations.
#     iteration   24: trace = 15.00941353445655 (0.00222814% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 15.00921795868238 (0.00130303% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 51.3613%)
#     iteration   26: trace = 15.00908453867526 (0.000888924% change)
#     switching back to exact line minimization
#     iteration   27: trace = 15.00901679459963 (0.000451355% change)
#     linmin: converged after 4 iterations.
#     iteration   28: trace = 15.00891403650031 (0.000684645% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 15.00883603871926 (0.000519678% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 15.00880688326752 (0.000194255% change)
#     linmin: converged after 2 iterations.
#     iteration   31: trace = 15.00878760284116 (0.000128461% change)
#     linmin: converged after 2 iterations.
#     iteration   32: trace = 15.00876781267015 (0.000131857% change)
#     linmin: converged after 4 iterations.
#     iteration   33: trace = 15.0087388406694 (0.000193034% change)
#     linmin: converged after 2 iterations.
#     iteration   34: trace = 15.0087294227022 (6.27499e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   35: trace = 15.00872415292305 (3.51114e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   36: trace = 15.00871909562741 (3.36957e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   37: trace = 15.00871356360204 (3.68588e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   38: trace = 15.00870986096638 (2.46699e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   39: trace = 15.00870831521102 (1.02991e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   40: trace = 15.00870665761266 (1.10442e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   41: trace = 15.00870478653646 (1.24666e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   42: trace = 15.00870286510887 (1.28021e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   43: trace = 15.00870218998447 (4.49822e-06% change)
# Finished solving for bands 21 to 30 after 43 iterations.
# Solving for bands 31 to 40...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 17.81483057425768 (8.77336% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 17.53942208188636 (1.55799% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 17.30442082517508 (1.34888% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 16.95053244984398 (2.0662% change)
#     linmin: converged after 6 iterations.
#     iteration    5: trace = 16.75711910017916 (1.14759% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 16.63136689582395 (0.753267% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 16.56823328067248 (0.380328% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 16.54497368957805 (0.140485% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 88.0797%)
#     iteration    9: trace = 16.52747645533055 (0.105812% change)
#     iteration   10: trace = 16.51424794982399 (0.0800715% change)
#     iteration   11: trace = 16.50183594653008 (0.0751876% change)
#     iteration   12: trace = 16.49148008184876 (0.0627755% change)
#     iteration   13: trace = 16.48293079336845 (0.0518541% change)
#     iteration   14: trace = 16.47739099933375 (0.0336149% change)
#     iteration   15: trace = 16.47426705685829 (0.0189608% change)
#     iteration   16: trace = 16.47236542616465 (0.0115437% change)
#     iteration   17: trace = 16.47145994965613 (0.00549709% change)
#     iteration   18: trace = 16.47094368749393 (0.00313433% change)
#     iteration   19: trace = 16.47071904110638 (0.0013639% change)
#     iteration   20: trace = 16.4705671167162 (0.000922395% change)
#     iteration   21: trace = 16.47048692895898 (0.000486856% change)
#     iteration   22: trace = 16.47043822844504 (0.000295684% change)
#     iteration   23: trace = 16.47037802816196 (0.000365506% change)
#     iteration   24: trace = 16.47030602834027 (0.000437148% change)
#     iteration   25: trace = 16.47015363453504 (0.000925268% change)
#     iteration   26: trace = 16.46989137593276 (0.00159234% change)
#     iteration   27: trace = 16.46944455603647 (0.00271299% change)
#     iteration   28: trace = 16.46890814763759 (0.00325704% change)
#     iteration   29: trace = 16.46849316001049 (0.00251986% change)
#     iteration   30: trace = 16.46810101270075 (0.00238123% change)
#     iteration   31: trace = 16.46785929810633 (0.00146779% change)
#     iteration   32: trace = 16.46769934308065 (0.000971321% change)
#     iteration   33: trace = 16.46759243532112 (0.000649199% change)
#     iteration   34: trace = 16.46753667437457 (0.000338611% change)
#     iteration   35: trace = 16.46750679167069 (0.000181464% change)
#     iteration   36: trace = 16.46749109605664 (9.53127e-05% change)
#     iteration   37: trace = 16.46747894765104 (7.37721e-05% change)
#     iteration   38: trace = 16.46747099573149 (4.82886e-05% change)
#     iteration   39: trace = 16.46746574474743 (3.1887e-05% change)
#     iteration   40: trace = 16.46746322357166 (1.531e-05% change)
#     iteration   41: trace = 16.4674619640758 (7.64839e-06% change)
# Finished solving for bands 31 to 40 after 41 iterations.
# Finished k-point with 38.75 mean iterations/band.
# freqs:, 19, 1, 0, 0, 1, 7.57826e-05, 8.94508e-05, 0.836327, 0.837036, 0.839315, 0.83997, 0.843174, 0.845162, 0.8824, 0.88386, 0.884704, 0.885059, 0.886232, 0.888009, 1.2002, 1.20126, 1.20271, 1.20546, 1.20577, 1.20801, 1.21836, 1.22041, 1.22165, 1.22386, 1.22475, 1.22647, 1.227, 1.22815, 1.22879, 1.23149, 1.23282, 1.23591, 1.26017, 1.26065, 1.26143, 1.26199, 1.26287, 1.26411, 1.38305, 1.39764
# elapsed time for k point: 10.64830207824707
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.7091969666205834 at Vector3<0.5, 0.5, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.7109940725945236 at Vector3<0.5, 0.5, 0.5>
# Band 3 range: 0.436528962548783 at Vector3<0.5, 1.0, 0.0> to 0.8366873676375046 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4369115017625712 at Vector3<0.5, 1.0, 0.0> to 0.8374217568808374 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.6466556049399381 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0> to 0.8864258188813331 at Vector3<0.5, 1.0, 0.0>
# Band 6 range: 0.6481538800020273 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0> to 0.8890704193849036 at Vector3<0.5, 1.0, 0.0>
# Band 7 range: 0.7037870180943465 at Vector3<0.33333333333333337, 0.33333333333333337, 0.33333333333333337> to 0.891603086750953 at Vector3<0.5, 1.0, 0.0>
# Band 8 range: 0.7052325804975854 at Vector3<0.33333333333333337, 0.33333333333333337, 0.33333333333333337> to 0.8977724901454754 at Vector3<0.5, 1.0, 0.0>
# Band 9 range: 0.7932393990105213 at Vector3<0.5, 0.5, 0.5> to 0.985853226981222 at Vector3<0.16666666666666669, 0.16666666666666669, 0.16666666666666669>
# Band 10 range: 0.7934868382892301 at Vector3<0.5, 0.5, 0.5> to 0.9875736483364238 at Vector3<0.16666666666666669, 0.16666666666666669, 0.16666666666666669>
# Band 11 range: 0.7936457759585179 at Vector3<0.5, 0.5, 0.5> to 0.9980671314049365 at Vector3<0.25, 0.5, 0.0>
# Band 12 range: 0.7946583741107743 at Vector3<0.5, 0.5, 0.5> to 1.0133186872552602 at Vector3<0.16666666666666669, 0.16666666666666669, 0.16666666666666669>
# Band 13 range: 0.7949874159398235 at Vector3<0.5, 0.5, 0.5> to 1.0509980833092891 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 14 range: 0.7952029073864529 at Vector3<0.5, 0.5, 0.5> to 1.0520526239337682 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 15 range: 0.7982554888823771 at Vector3<0.5, 0.5, 0.5> to 1.2002003892975006 at Vector3<1.0, 0.0, 0.0>
# Band 16 range: 0.7991692978479799 at Vector3<0.5, 0.5, 0.5> to 1.2012607810506646 at Vector3<1.0, 0.0, 0.0>
# Band 17 range: 1.0349511883979288 at Vector3<0.5, 1.0, 0.0> to 1.3064229339123592 at Vector3<0.5, 0.5, 0.5>
# Band 18 range: 1.0366905447122312 at Vector3<0.5, 1.0, 0.0> to 1.3070692126821561 at Vector3<0.5, 0.5, 0.5>
# Band 19 range: 1.037197665596107 at Vector3<0.5, 1.0, 0.0> to 1.3123681692769944 at Vector3<0.5, 0.5, 0.5>
# Band 20 range: 1.0413605285540095 at Vector3<0.5, 1.0, 0.0> to 1.3141769583365837 at Vector3<0.5, 0.5, 0.5>
# Band 21 range: 1.1338153055313824 at Vector3<0.25, 0.25, 0.25> to 1.31976029376398 at Vector3<0.5, 0.5, 0.5>
# Band 22 range: 1.1356849928917394 at Vector3<0.25, 0.25, 0.25> to 1.3206018850985495 at Vector3<0.5, 0.5, 0.5>
# Band 23 range: 1.160931706219619 at Vector3<0.75, 0.5, 0.0> to 1.3244133102622455 at Vector3<0.5, 0.5, 0.5>
# Band 24 range: 1.1650825322997544 at Vector3<0.25, 0.5, 0.0> to 1.3305412230333562 at Vector3<0.5, 0.5, 0.5>
# Band 25 range: 1.1668934064916219 at Vector3<0.25, 0.5, 0.0> to 1.3380274890999575 at Vector3<0.5, 0.5, 0.5>
# Band 26 range: 1.1702685953065435 at Vector3<0.25, 0.5, 0.0> to 1.338694699612521 at Vector3<0.5, 0.5, 0.5>
# Band 27 range: 1.1869549765669078 at Vector3<0.25, 0.5, 0.0> to 1.3422646039931012 at Vector3<0.5, 0.5, 0.5>
# Band 28 range: 1.1905111169725318 at Vector3<0.25, 0.5, 0.0> to 1.345202644014488 at Vector3<0.5, 0.5, 0.5>
# Band 29 range: 1.2281638433167046 at Vector3<0.0, 0.0, 0.0> to 1.3553471296348512 at Vector3<0.4166666666666667, 0.4166666666666667, 0.4166666666666667>
# Band 30 range: 1.2306550196385637 at Vector3<0.0, 0.0, 0.0> to 1.36577062596858 at Vector3<0.4166666666666667, 0.4166666666666667, 0.4166666666666667>
# Band 31 range: 1.2311887772317505 at Vector3<0.0, 0.0, 0.0> to 1.3675014487353143 at Vector3<0.4166666666666667, 0.4166666666666667, 0.4166666666666667>
# Band 32 range: 1.233858035043381 at Vector3<0.0, 0.0, 0.0> to 1.3702528030940981 at Vector3<0.4166666666666667, 0.4166666666666667, 0.4166666666666667>
# Band 33 range: 1.2601679843618063 at Vector3<1.0, 0.0, 0.0> to 1.4182007710018678 at Vector3<0.5, 0.5, 0.5>
# Band 34 range: 1.2606468956234134 at Vector3<1.0, 0.0, 0.0> to 1.4237289724905169 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 35 range: 1.2614339715382072 at Vector3<1.0, 0.0, 0.0> to 1.4405539908745764 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 36 range: 1.2619907738283243 at Vector3<1.0, 0.0, 0.0> to 1.441121189218997 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 37 range: 1.2628728777778273 at Vector3<1.0, 0.0, 0.0> to 1.4441739695003444 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# Band 38 range: 1.2641135367234806 at Vector3<1.0, 0.0, 0.0> to 1.4466575435037334 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Band 39 range: 1.3419942950498307 at Vector3<0.08333333333333337, 0.08333333333333337, 0.08333333333333337> to 1.4497785030018022 at Vector3<0.3333333333333333, 0.6666666666666666, 0.0>
# Band 40 range: 1.3428862259911438 at Vector3<0.08333333333333337, 0.08333333333333337, 0.08333333333333337> to 1.4536947488906686 at Vector3<0.6666666666666666, 0.6666666666666667, 0.0>
# total elapsed time for run: 134.2024519443512
# done

# %%
### Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=False, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 11
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
x = range(len(crysfreqs))
figgy = plt.figure()
plt.plot(x,crysfreqs, color='blue');
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs)
plt.ylabel('frequency (c/a)', size=16)
plt.grid(True)
figax = plt.gca()

plt.show()
# Out:
# epsilon: 1-2.25, mean 1.37259, harm. mean 1.21558, 56.25% > 1, 29.807% "fill"
# real part range: 1 .. 2.25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 19
#      16 points_in_between = (len(crysfreqs)-1) / (k_corners-1)
#      17 tick_locs = [i*points_in_between for i in range(k_corners)]
# ---> 19 plt.xticks(tick_locs,tick_labs)
#      20 plt.ylabel('frequency (c/a)', size=16)
#      21 plt.grid(True)
#
# File ~/miniconda3/envs/simulation/lib/python3.11/site-packages/matplotlib/pyplot.py:2239, in xticks(ticks, labels, minor, **kwargs)
#    2237         l._internal_update(kwargs)
#    2238 else:
# -> 2239     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2241 return locs, labels_out
#
# File ~/miniconda3/envs/simulation/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniconda3/envs/simulation/lib/python3.11/site-packages/matplotlib/axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (4), usually from a call to set_ticks, does not match the number of labels (5).

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
