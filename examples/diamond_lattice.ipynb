# %%
from crystalbuilder import *
import crystalbuilder.geometry as geo
import matplotlib.pyplot as plt
import numpy as np
import vedo

# %% [markdown]
# This notebook will walk through an example of creating a 3D photonic crystal based on the rod-connected diamond motif. The structure will be made using CrystalBuilder's geo package and then simulated using MPB.
#
# First, let's define our basis. This will be a rhombohedral primitive basis. By convention, the diamond unit cell is actually cubic, so our lattice vector will be _sqrt(a/2)_ instead of _a_ units long

# %%
a1 = [0, 1, 1]
a2 = [1, 0 ,1]
a3 = [1, 1, 0]

a_mag = np.sqrt(.5)


geo_lattice = lattice.Lattice(a1, a2, a3, magnitude = [a_mag, a_mag, a_mag])

# %% [markdown]
# We've now defined our lattice. It's important to note that this is a CrystalBuilder lattice and not an MPB one. They can be converted, as we will show later, but they are not the exact same.
#
# Let's get the positions of the "atoms" in the diamond lattice that our rods will connect.
#
# The square diamond lattice looks like 4 tetrahedra connected to one another, but our rhombohedral primitive cell will only include one of them. The tetrahedral rods will connect to one another at (1/4, 1/4, 1/4)*a.
#
# The other points will be:
# - (0,0,0)
# - (1/2, 1/2, 0)*a
# - (1/2, 0, 1/2)*a
# - (0, 1/2, 1/2)*a
#
#
# We'll make cylinders that connect these points. CrystalBuilder's Cylinder class features a way to define the objects based on their start/end positions and a radius. Let's set those now.

# %%
diamond_points = [
    (1/4, 1/4, 1/4),
    (0,0,0),
    (1/2, 1/2, 0),
    (1/2, 0, 1/2),
    (0,1/2, 1/2)
]


radius = .2*a_mag

cylinder_1 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[1]], radius=radius)
cylinder_2 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[2]], radius=radius)
cylinder_3 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[3]], radius=radius)
cylinder_4 = geo.Cylinder.from_vertices([diamond_points[0], diamond_points[4]], radius=radius)

unit_cell = [cylinder_1, cylinder_2, cylinder_3, cylinder_4]

# %% [markdown]
# Now lets use our previously defined lattice to tile these cylinders into a crystal.

# %%
a1_reps = 6
a2_reps = 6
a3_reps = 6
crystal = geo_lattice.tile_geogeometry(unit_cell, a1_reps, a2_reps, a3_reps )

# %% [markdown]
# We can visualize this using CrystalBuilder's viewer package, which builds the structure as a Vedo scene.

# %%
scene = viewer.visualize(crystal)
objects = scene.get_meshes()

# k=0
# for obj in objects:
#     k+=1
#     string=f"diamond/object-{k}.obj"
#     vedo.write(obj, string)

# %% [markdown]
# It looks good, so let's convert to MPB and simulate a band structure.

# %%
import meep as mp
from meep import mpb

material = mp.Medium(epsilon=9)

mpb_lattice = convert.to_mpb_lattice(geo_lattice)
mpb_geometry = convert.geo_to_mpb(unit_cell, material=material, lattice=mpb_lattice)

# %% [markdown]
# The above conversions are done by the CrystalBuilder convert module, and our output defines our mpb_lattice and our mpb_geometry
#
# We then define our k points and other simulation parameters like normal!

# %%
vlist = [
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0, 0.625, 0.375),    # U
    mp.Vector3(0, 0.5, 0),          # L
    mp.Vector3(0, 0, 0),            # Gamma
    mp.Vector3(0, 0.5, 0.5),        # X
    mp.Vector3(0.25, 0.75, 0.5),    # W
    mp.Vector3(0.375, 0.75, 0.375)  # K
]
k_corners = len(vlist)
k_points = mp.interpolate(1, vlist)
tick_labs = ['X', 'U', 'L', '$\Gamma$','X', 'W', 'K']


resolution = 16  # use a 16x16x16 grid
mesh_size = 1
num_bands = 10

ms = mpb.ModeSolver(
    geometry_lattice=mpb_lattice,
    k_points=k_points,
    geometry=mpb_geometry,
    resolution=resolution,
    num_bands=num_bands,
    mesh_size=mesh_size
)

ms.run()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 12 x 12 x 12.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 1.
# Lattice vectors:
#      (0, 0.5, 0.5)
#      (0.5, 0, 0.5)
#      (0.5, 0.5, 0)
# Cell volume = 0.25
# Reciprocal lattice vectors (/ 2 pi):
#      (-1, 1, 1)
#      (1, -1, 1)
#      (1, 1, -1)
# Geometric objects:
#      cylinder, center = (0.0883883,0.0883883,0.0883883)
#           radius 0.141421, height 0.433013, axis (-0.408248, -0.408248, -0.408248)
#      cylinder, center = (0.0883883,0.0883883,0.441942)
#           radius 0.141421, height 0.433013, axis (0.707107, 0.707107, -0.707107)
#      cylinder, center = (0.0883883,0.441942,0.0883883)
#           radius 0.141421, height 0.433013, axis (0.707107, -0.707107, 0.707107)
#      cylinder, center = (0.441942,0.0883883,0.0883883)
#           radius 0.141421, height 0.433013, axis (-0.707107, 0.707107, 0.707107)
# Geometric object tree has depth 7 and 259 object nodes (vs. 4 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: .
# Initializing fields to random numbers...
# 13 k-points
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.0, 0.5625, 0.4375>
#   Vector3<0.0, 0.625, 0.375>
#   Vector3<0.0, 0.5625, 0.1875>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.25, 0.25>
#   Vector3<0.0, 0.5, 0.5>
#   Vector3<0.125, 0.625, 0.5>
#   Vector3<0.25, 0.75, 0.5>
#   Vector3<0.3125, 0.75, 0.4375>
#   Vector3<0.375, 0.75, 0.375>
# elapsed time for initialization: 0.05442404747009277
# solve_kpoint (0,0.5,0.5):
# freqs:, k index, k1, k2, k3, kmag/2pi, band 1, band 2, band 3, band 4, band 5, band 6, band 7, band 8, band 9, band 10
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 8 iterations.
#     iteration    1: trace = 21.97348923661529 (188.166% change)
#     linmin: converged after 8 iterations.
#     iteration    2: trace = 6.611238822087792 (107.486% change)
#     linmin: converged after 6 iterations.
#     iteration    3: trace = 5.1375570647021 (25.0865% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 4.712399211997818 (8.63269% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.595652039896142 (2.50852% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.556164860909483 (0.862936% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.54120283587233 (0.328931% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 59.335%)
#     iteration    8: trace = 4.534981202590459 (0.137098% change)
#     iteration    9: trace = 4.532155206263478 (0.0623349% change)
#     iteration   10: trace = 4.530996535584967 (0.0255688% change)
#     iteration   11: trace = 4.530499039553809 (0.0109804% change)
#     switching back to exact line minimization
#     iteration   12: trace = 4.53031602969202 (0.00403959% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.530237293293512 (0.001738% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.530203708519558 (0.00074135% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.530189129311793 (0.000321823% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.530183371705407 (0.000127094% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.530181401883505 (4.34822e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.530180736155176 (1.46954e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 4.53018051772689 (4.82162e-06% change)
# Finished solving for bands 1 to 10 after 19 iterations.
# freqs:, 1, 0, 0.5, 0.5, 1, 0.462186, 0.499459, 0.588349, 0.626807, 0.672924, 0.721704, 0.74024, 0.753347, 0.780284, 0.793758
# elapsed time for k point: 0.35663294792175293
# solve_kpoint (0,0.5625,0.4375):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.573266341189869 (1.81807% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.54802474459832 (0.553465% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.539080979633772 (0.196845% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.533719967279105 (0.118178% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.531751619084644 (0.0434252% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.530611571889531 (0.02516% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 72.8424%)
#     iteration    7: trace = 4.529983491331533 (0.013864% change)
#     iteration    8: trace = 4.529703302391924 (0.0061854% change)
#     iteration    9: trace = 4.529599357591176 (0.00229476% change)
#     iteration   10: trace = 4.529574080781265 (0.000558038% change)
#     iteration   11: trace = 4.529567000874785 (0.000156304% change)
#     iteration   12: trace = 4.52956486646078 (4.71218e-05% change)
#     switching back to exact line minimization
#     iteration   13: trace = 4.529564045683173 (1.81205e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.529563606229555 (9.7019e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 2, 0, 0.5625, 0.4375, 1.0155, 0.468453, 0.499812, 0.592712, 0.631224, 0.664895, 0.689243, 0.729662, 0.757841, 0.790753, 0.813259
# elapsed time for k point: 0.2662053108215332
# solve_kpoint (0,0.625,0.375):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.584693761851916 (1.64226% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.565069424993265 (0.428958% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.558574302529824 (0.14238% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.553571527016242 (0.109805% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.551273990342398 (0.0504684% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.550031201983564 (0.0273101% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.549550070056379 (0.0105748% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.549404804305599 (0.00319302% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.549356398399775 (0.00106401% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.549344313734253 (0.000265635% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.549340623190112 (8.11226e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.549339290958054 (2.92841e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.549338802555447 (1.07357e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.549338625350615 (3.89518e-06% change)
# Finished solving for bands 1 to 10 after 14 iterations.
# freqs:, 3, 0, 0.625, 0.375, 1.06066, 0.476624, 0.495413, 0.605129, 0.622077, 0.644152, 0.661982, 0.726877, 0.771176, 0.807845, 0.833514
# elapsed time for k point: 0.292496919631958
# solve_kpoint (0,0.5625,0.1875):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.784470586883796 (7.19646% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.718502356404151 (1.38837% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.704031300862351 (0.307158% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.693810640454526 (0.217511% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.688358639184144 (0.11622% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.684458111707622 (0.0832306% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.681907723309716 (0.0544584% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.680365301766919 (0.0329497% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.679255520805732 (0.0237142% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.678316557149894 (0.0200685% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 76.5029%)
#     iteration   11: trace = 4.677275997272737 (0.0222447% change)
#     iteration   12: trace = 4.676222064705019 (0.0225356% change)
#     iteration   13: trace = 4.675331671086894 (0.0190427% change)
#     iteration   14: trace = 4.674797222761255 (0.0114319% change)
#     iteration   15: trace = 4.67444708415675 (0.0074902% change)
#     iteration   16: trace = 4.674180902295669 (0.00569457% change)
#     iteration   17: trace = 4.673982052361469 (0.00425431% change)
#     iteration   18: trace = 4.673844666903472 (0.00293941% change)
#     iteration   19: trace = 4.673774388021606 (0.00150367% change)
#     iteration   20: trace = 4.673737728743827 (0.000784364% change)
#     iteration   21: trace = 4.673718097495259 (0.000420034% change)
#     iteration   22: trace = 4.673707298374079 (0.000231061% change)
#     iteration   23: trace = 4.673700598228317 (0.000143358% change)
#     iteration   24: trace = 4.673696462604602 (8.84872e-05% change)
#     iteration   25: trace = 4.673693776094325 (5.74815e-05% change)
#     iteration   26: trace = 4.673692331662748 (3.09056e-05% change)
#     iteration   27: trace = 4.673691612078875 (1.53965e-05% change)
#     iteration   28: trace = 4.673691269141885 (7.3376e-06% change)
# Finished solving for bands 1 to 10 after 28 iterations.
# freqs:, 4, 0, 0.5625, 0.1875, 0.918559, 0.438369, 0.454898, 0.563591, 0.599086, 0.687474, 0.714537, 0.747416, 0.796163, 0.834075, 0.852456
# elapsed time for k point: 0.48906564712524414
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.920717904685532 (8.83107% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.80089469311736 (2.46509% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.739761171875163 (1.28154% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.698378836751743 (0.876917% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.683713521030397 (0.312624% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.673133293797061 (0.226149% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.667238727522671 (0.126217% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.664788063422423 (0.0525216% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.663965426053309 (0.0176366% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.663701463608049 (0.00565977% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.663595697315382 (0.00226789% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.663550380783478 (0.000971713% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 58.0248%)
#     iteration   13: trace = 4.663531037497684 (0.000414777% change)
#     iteration   14: trace = 4.66352359218646 (0.00015965% change)
#     iteration   15: trace = 4.663520497722923 (6.63546e-05% change)
#     iteration   16: trace = 4.663519224710134 (2.72973e-05% change)
#     switching back to exact line minimization
#     iteration   17: trace = 4.663518768990464 (9.77201e-06% change)
# Finished solving for bands 1 to 10 after 17 iterations.
# freqs:, 5, 0, 0.5, 0, 0.866025, 0.412573, 0.430719, 0.539468, 0.583491, 0.730187, 0.756578, 0.779655, 0.786822, 0.806869, 0.832301
# elapsed time for k point: 0.31422924995422363
# solve_kpoint (0,0.25,0):
# Solving for bands 1 to 10...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 4.972123211866589 (8.17045% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 4.888929067576272 (1.68733% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.865883635231058 (0.472494% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.852390287014686 (0.27769% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.847598130204437 (0.0988075% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.845367866205176 (0.0460182% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.844515983778761 (0.0175829% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 4.84423864627103 (0.00572494% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 4.844121108176351 (0.00242638% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.844069464113604 (0.00106612% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.84404146281045 (0.000578055% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.844027867231787 (0.000280666% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.844021463906439 (0.00013219% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 50.9656%)
#     iteration   14: trace = 4.844018873542244 (5.34755e-05% change)
#     iteration   15: trace = 4.844017821107025 (2.17265e-05% change)
#     iteration   16: trace = 4.844017377550191 (9.1568e-06% change)
# Finished solving for bands 1 to 10 after 16 iterations.
# freqs:, 6, 0, 0.25, 0, 0.433013, 0.246305, 0.250417, 0.671488, 0.706889, 0.744249, 0.770737, 0.789226, 0.799971, 0.818088, 0.83067
# elapsed time for k point: 0.3085055351257324
# solve_kpoint (0,0,0):
# Solving for bands 3 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 5.476739211107548 (16.8962% change)
#     linmin: converged after 3 iterations.
#     iteration    2: trace = 5.297610024560386 (3.3251% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 5.219981016099899 (1.47617% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 5.164843674442022 (1.06188% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 5.1426674752071 (0.430292% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 5.124422861304532 (0.3554% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 5.110281093279512 (0.276349% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 5.100591103730206 (0.189797% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 5.0952143343413 (0.10547% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 5.092624518171932 (0.0508413% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 5.091596087607182 (0.0201965% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 5.091166393409016 (0.00843964% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 5.090977188850699 (0.0037164% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 5.090906879691138 (0.00138106% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 5.090873668610252 (0.000652363% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 5.090858926573437 (0.000289578% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 5.090851344956395 (0.000148926% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 5.090847248880164 (8.04596e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 5.090845091341791 (4.23807e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 5.090844029325887 (2.08613e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 5.090843520142386 (1.00019e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 60%)
#     iteration   22: trace = 5.090843289796583 (4.52471e-06% change)
# Finished solving for bands 3 to 10 after 22 iterations.
# freqs:, 7, 0, 0, 0, 0, 0, 0, 0.7652, 0.766895, 0.772541, 0.781642, 0.80392, 0.805604, 0.840789, 0.840945
# elapsed time for k point: 0.36977624893188477
# solve_kpoint (0,0.25,0.25):
# Solving for bands 1 to 10...
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 5.28807697313902 (13.9247% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 5.023419356675882 (5.13325% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 51.3831%)
#     iteration    3: trace = 4.908391759400336 (2.31635% change)
#     iteration    4: trace = 4.839793459725431 (1.40741% change)
#     switching back to exact line minimization
#     iteration    5: trace = 4.798862854411126 (0.849301% change)
#     linmin: converged after 5 iterations.
#     iteration    6: trace = 4.771027952118926 (0.581718% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 4.761886751987249 (0.191782% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.757873876420642 (0.0843062% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.756522755650407 (0.0284016% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.755984978454913 (0.0113067% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.755777846842296 (0.00435527% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.755682763144105 (0.00199935% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.755642257072265 (0.000851744% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.755626927759973 (0.00032234% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.755620911358756 (0.000126511% change)
#     linmin: converged after 2 iterations.
#     iteration   16: trace = 4.755618763205879 (4.51708e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   17: trace = 4.755617851773851 (1.91654e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.755617465476722 (8.12296e-06% change)
# Finished solving for bands 1 to 10 after 18 iterations.
# freqs:, 8, 0, 0.25, 0.25, 0.5, 0.282034, 0.288462, 0.693726, 0.715053, 0.71968, 0.746708, 0.750103, 0.801065, 0.804267, 0.820726
# elapsed time for k point: 0.3551812171936035
# solve_kpoint (0,0.5,0.5):
# Solving for bands 1 to 10...
#     linmin: converged after 5 iterations.
#     iteration    1: trace = 4.7319454193931 (16.1233% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 56.5217%)
#     iteration    2: trace = 4.576836783965986 (3.33252% change)
#     iteration    3: trace = 4.546008969630398 (0.675838% change)
#     iteration    4: trace = 4.534947812892456 (0.243612% change)
#     iteration    5: trace = 4.532164922100966 (0.0613843% change)
#     iteration    6: trace = 4.531136002229253 (0.0227052% change)
#     iteration    7: trace = 4.530610646804909 (0.011595% change)
#     iteration    8: trace = 4.530374709745337 (0.00520776% change)
#     switching back to exact line minimization
#     iteration    9: trace = 4.530256157850261 (0.00261686% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.530208391715215 (0.00105439% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.530188783876946 (0.000432825% change)
#     linmin: converged after 2 iterations.
#     iteration   12: trace = 4.530183070397317 (0.00012612% change)
#     linmin: converged after 2 iterations.
#     iteration   13: trace = 4.530181375745311 (3.7408e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   14: trace = 4.530180805462541 (1.25885e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   15: trace = 4.530180569618719 (5.20606e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 9, 0, 0.5, 0.5, 1, 0.462186, 0.499459, 0.588349, 0.626807, 0.672924, 0.721704, 0.74024, 0.753347, 0.780284, 0.793758
# elapsed time for k point: 0.36342620849609375
# solve_kpoint (0.125,0.625,0.5):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.605611685197713 (3.02868% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 82.5188%)
#     iteration    2: trace = 4.55844199721434 (1.02945% change)
#     iteration    3: trace = 4.543204570937201 (0.334828% change)
#     iteration    4: trace = 4.53675891860094 (0.141975% change)
#     iteration    5: trace = 4.535102145508846 (0.0365255% change)
#     iteration    6: trace = 4.534553696117235 (0.0120942% change)
#     iteration    7: trace = 4.534264685389967 (0.00637372% change)
#     iteration    8: trace = 4.534105161170895 (0.00351826% change)
#     iteration    9: trace = 4.534019609332493 (0.00188687% change)
#     iteration   10: trace = 4.533992819014844 (0.000590875% change)
#     iteration   11: trace = 4.533985056368126 (0.00017121% change)
#     iteration   12: trace = 4.533982461375976 (5.72343e-05% change)
#     iteration   13: trace = 4.533981301692465 (2.55776e-05% change)
#     iteration   14: trace = 4.533980654965443 (1.4264e-05% change)
#     iteration   15: trace = 4.533980328060164 (7.21012e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 10, 0.125, 0.625, 0.5, 1.03078, 0.470307, 0.505136, 0.596086, 0.632753, 0.64922, 0.692841, 0.721363, 0.731907, 0.8118, 0.827856
# elapsed time for k point: 0.2600874900817871
# solve_kpoint (0.25,0.75,0.5):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.676716912542063 (2.38448% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.647400641547778 (0.628827% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.637532917540076 (0.212553% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.62990899293762 (0.164531% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.624528164745175 (0.116286% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.619980881580024 (0.098378% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.617217436557524 (0.059833% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.615801740562288 (0.0306659% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.614736441640421 (0.0230821% change)
#     linmin: converged after 4 iterations.
#     iteration   10: trace = 4.613836931252449 (0.019494% change)
#     linmin: converged after 4 iterations.
#     iteration   11: trace = 4.612880087152244 (0.0207407% change)
#     linmin: converged after 4 iterations.
#     iteration   12: trace = 4.612114589102139 (0.0165962% change)
#     linmin: converged after 4 iterations.
#     iteration   13: trace = 4.611601196909795 (0.011132% change)
#     linmin: converged after 4 iterations.
#     iteration   14: trace = 4.611246997684878 (0.00768091% change)
#     linmin: converged after 4 iterations.
#     iteration   15: trace = 4.610997585473542 (0.00540893% change)
#     linmin: converged after 4 iterations.
#     iteration   16: trace = 4.610826457300209 (0.00371137% change)
#     linmin: converged after 4 iterations.
#     iteration   17: trace = 4.610723067386171 (0.00224235% change)
#     linmin: converged after 2 iterations.
#     iteration   18: trace = 4.610664977555149 (0.00125989% change)
#     linmin: converged after 2 iterations.
#     iteration   19: trace = 4.610634782471328 (0.000654899% change)
#     linmin: converged after 2 iterations.
#     iteration   20: trace = 4.610613029347702 (0.000471804% change)
#     linmin: converged after 2 iterations.
#     iteration   21: trace = 4.610591840833822 (0.000459561% change)
#     linmin: converged after 2 iterations.
#     iteration   22: trace = 4.610568844692368 (0.000498769% change)
#     linmin: converged after 2 iterations.
#     iteration   23: trace = 4.610544330861028 (0.000531689% change)
#     linmin: converged after 2 iterations.
#     iteration   24: trace = 4.610525410908738 (0.000410364% change)
#     linmin: converged after 2 iterations.
#     iteration   25: trace = 4.610512287384672 (0.000284643% change)
#     linmin: converged after 2 iterations.
#     iteration   26: trace = 4.610504910710261 (0.000159997% change)
#     linmin: converged after 2 iterations.
#     iteration   27: trace = 4.610501443327036 (7.52062e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   28: trace = 4.610499819597279 (3.52181e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   29: trace = 4.610499020577077 (1.73304e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   30: trace = 4.61049856288807 (9.9271e-06% change)
# Finished solving for bands 1 to 10 after 30 iterations.
# freqs:, 11, 0.25, 0.75, 0.5, 1.11803, 0.480293, 0.51104, 0.607524, 0.615713, 0.662882, 0.669951, 0.694756, 0.709589, 0.848022, 0.881406
# elapsed time for k point: 0.6597609519958496
# solve_kpoint (0.3125,0.75,0.4375):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.651022791825491 (1.8691% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.619455078342745 (0.681037% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.600680501929538 (0.407252% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.582564723639003 (0.39454% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.57465782757993 (0.172692% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.570129158029233 (0.0990437% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 4.567821148072379 (0.0505148% change)
#     linmin: converged after 4 iterations.
#     iteration    8: trace = 4.566271835337054 (0.0339237% change)
#     linmin: converged after 4 iterations.
#     iteration    9: trace = 4.565128922559448 (0.0250326% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 87.627%)
#     iteration   10: trace = 4.564475501645031 (0.0143143% change)
#     iteration   11: trace = 4.564123645082169 (0.00770888% change)
#     iteration   12: trace = 4.563970236952854 (0.00336123% change)
#     iteration   13: trace = 4.563894816374517 (0.00165253% change)
#     iteration   14: trace = 4.563858002911721 (0.000806627% change)
#     iteration   15: trace = 4.563838924701836 (0.000418029% change)
#     iteration   16: trace = 4.563830201090961 (0.000191147% change)
#     iteration   17: trace = 4.563826912696201 (7.20534e-05% change)
#     iteration   18: trace = 4.563825641237823 (2.78595e-05% change)
#     iteration   19: trace = 4.563825182708178 (1.0047e-05% change)
#     switching back to exact line minimization
#     iteration   20: trace = 4.563825011007838 (3.7622e-06% change)
# Finished solving for bands 1 to 10 after 20 iterations.
# freqs:, 12, 0.3125, 0.75, 0.4375, 1.07529, 0.47008, 0.511855, 0.599317, 0.608093, 0.645808, 0.684568, 0.713937, 0.733755, 0.830653, 0.853293
# elapsed time for k point: 0.3647003173828125
# solve_kpoint (0.375,0.75,0.375):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     iteration    1: trace = 4.562983309006883 (1.57056% change)
#     linmin: converged after 4 iterations.
#     iteration    2: trace = 4.544369252797321 (0.40877% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 4.538985811164623 (0.118534% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 4.535892051412091 (0.068183% change)
#     linmin: converged after 4 iterations.
#     iteration    5: trace = 4.534827008157342 (0.0234831% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 4.534413955048348 (0.00910888% change)
#     linmin: converged after 2 iterations.
#     iteration    7: trace = 4.534226941977393 (0.00412439% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 69.6785%)
#     iteration    8: trace = 4.534130701339967 (0.00212256% change)
#     switching back to exact line minimization
#     iteration    9: trace = 4.534071165364093 (0.00131307% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 4.534048055497946 (0.000509695% change)
#     linmin: converged after 2 iterations.
#     iteration   11: trace = 4.534038767336292 (0.000204854% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 54.6161%)
#     iteration   12: trace = 4.534035072266849 (8.14962e-05% change)
#     iteration   13: trace = 4.534033497703496 (3.47276e-05% change)
#     iteration   14: trace = 4.534032900441781 (1.31729e-05% change)
#     iteration   15: trace = 4.534032673555406 (5.00407e-06% change)
# Finished solving for bands 1 to 10 after 15 iterations.
# freqs:, 13, 0.375, 0.75, 0.375, 1.06066, 0.463933, 0.51087, 0.594395, 0.60703, 0.63763, 0.678077, 0.748649, 0.758689, 0.802425, 0.830476
# elapsed time for k point: 0.40955352783203125
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.4802931350536191 at Vector3<0.25, 0.75, 0.5>
# Band 2 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5118552269794757 at Vector3<0.3125, 0.75, 0.4375>
# Band 3 range: 0.5394683682860161 at Vector3<0.0, 0.5, 0.0> to 0.7652002939262589 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.583490650357245 at Vector3<0.0, 0.5, 0.0> to 0.7668947858740435 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 0.6376298142820089 at Vector3<0.375, 0.75, 0.375> to 0.7725408905133336 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.6619815889820292 at Vector3<0.0, 0.625, 0.375> to 0.7816420377152253 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 0.6947562297007309 at Vector3<0.25, 0.75, 0.5> to 0.8039196670288962 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.709588911383249 at Vector3<0.25, 0.75, 0.5> to 0.8056040848050646 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 0.7802836811061442 at Vector3<0.0, 0.5, 0.5> to 0.8480222762726327 at Vector3<0.25, 0.75, 0.5>
# Band 10 range: 0.7937575625835734 at Vector3<0.0, 0.5, 0.5> to 0.8814059974532792 at Vector3<0.25, 0.75, 0.5>
# Gap from band 2 (0.5118552269794757) to band 3 (0.5394683682860161), 5.253024174648564%
# total elapsed time for run: 4.868635416030884
# done

# %%
### Plotting Dielectric Map ###
plt.figure()
md = mpb.MPBData(rectify=True, periods=7, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
layer_slice = 9
plt.imshow(converted_eps[:,:, layer_slice], interpolation='spline36', cmap='binary_r')
plt.axis('off')
plt.show()

### Plotting Band Structure ###
crysfreqs = ms.all_freqs
x = range(len(crysfreqs))
figgy = plt.figure()
plt.plot(x,crysfreqs, color='blue');
points_in_between = (len(crysfreqs)-1) / (k_corners-1)
tick_locs = [i*points_in_between for i in range(k_corners)]

plt.xticks(tick_locs,tick_labs)
plt.ylabel('frequency (c/a)', size=16)
plt.grid(True)
figax = plt.gca()

plt.show()
# Out:
# epsilon: 1-9, mean 4.08035, harm. mean 1.66907, 55.6134% > 1, 38.5044% "fill"
# real part range: 1 .. 9

# %% [markdown]
# Output the structure to an array for rebuilding via marching_cubes.

# %%
filename = "DiamondLattice_Rebuilt"

np.save(filename, converted_eps)
